# %% [markdown]
# # ALK Clean

# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 300)

alk_asm_df = pd.read_csv('Available Seat-Miles - All Airports - Alaska.csv')
alk_flight_vol_df = pd.read_csv('Flights - All Airports - Alaska.csv')
alk_fuel_df = pd.read_csv('Fuel - All Service - Alaska.csv')
alk_load_factor_df = pd.read_csv('Load Factor - All Airports - Alaska.csv')
alk_income_df = pd.read_csv('Net Income - All Regions - Alaska.csv')
alk_operating_revenue_df = pd.read_csv('Operating Revenue - All Regions - Alaska.csv')
alk_passenger_vol_df = pd.read_csv('Passengers - All Airports - Alaska.csv')
alk_rpm_df = pd.read_csv('Revenue Passager-Miles - All Airports - Alaska.csv')
alk_stock_df = pd.read_csv('ALK_stock_data.csv')
alk_baggage_df = pd.read_csv('Baggage Fees - All Airports - Alaska.csv')

display(alk_asm_df.head())
display(alk_flight_vol_df.head())
display(alk_fuel_df.head())
display(alk_load_factor_df.head())
display(alk_income_df.head())
display(alk_operating_revenue_df.head())
display(alk_passenger_vol_df.head())
display(alk_rpm_df.head())
display(alk_stock_df.tail())
# Out:
#    Year  Month Domestic (Thousands) International (Thousands)  \
# 0  2002     10            1,351,693                   224,607
# 1  2002     11            1,243,428                   294,520
# 2  2002     12            1,339,857                   304,832
# 3  2002  TOTAL           16,412,337                 2,933,267
# 4  2003      1            1,317,669                   294,826
#
#   Total (Thousands)
# 0         1,576,301
# 1         1,537,948
# 2         1,644,689
# 3        19,345,604
# 4         1,612,494
#    Year  Month DOMESTIC INTERNATIONAL    TOTAL
# 0  2002     10   12,931         1,482   14,413
# 1  2002     11   12,004         1,795   13,799
# 2  2002     12   12,627         1,865   14,492
# 3  2002  TOTAL  156,439        18,706  175,145
# 4  2003      1   12,421         1,799   14,220
#    Year     Month Domestic Consumption\n(thousand gallons)  \
# 0  2012  February                                   26,279
# 1  2012     March                                   29,466
# 2  2012     April                                   28,624
# 3  2012       May                                   30,137
# 4  2012      June                                   31,797
#
#   Domestic Cost (thousand dollars) Domestic Cost per Gallon (Dollars)  \
# 0                           94,038                               3.58
# 1                          111,245                               3.78
# 2                          106,756                               3.73
# 3                          106,701                               3.54
# 4                          100,900                               3.17
#
#   International Consumption\n(thousand gallons)  \
# 0                                         1,006
# 1                                         1,167
# 2                                         1,095
# 3                                           841
# 4                                           729
#
#   International Cost (thousand dollars)  \
# 0                                 3,500
# 1                                 4,167
# 2                                 3,872
# 3                                 2,844
# 4                                 2,237
#
#   International Cost per Gallon (Dollars)  \
# 0                                       3
# 1                                       4
# 2                                       4
# 3                                       3
# 4                                       3
#
#   Total Consumption\n(thousand gallons) Total Cost (thousand dollars)  \
# 0                                27,285                        97,538
# 1                                30,633                       115,412
# 2                                29,719                       110,628
# 3                                30,978                       109,545
# 4                                32,526                       103,137
#
#   Total Cost per Gallon (Dollars)
# 0                            3.57
# 1                            3.77
# 2                            3.72
# 3                            3.54
# 4                            3.17
#    Year  Month  DOMESTIC  INTERNATIONAL  TOTAL
# 0  2002     10     61.32          59.23  61.02
# 1  2002     11     65.06          63.64  64.79
# 2  2002     12     74.52          67.98  73.31
# 3  2002  TOTAL     67.61          70.95  68.12
# 4  2003      1     61.25          68.89  62.65
#    Year Quarter Domestic (Thousands) Latin America (Thousands)  \
# 0  2000       1              -61,472                    -3,707
# 1  2000       2                  NaN                      -786
# 2  2000       3               18,402                    -1,024
# 3  2000       4              -20,288                    -2,260
# 4  2000   TOTAL              -63,358                    -7,777
#
#    Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 0                   NaN                  NaN                        NaN
# 1                   NaN                  NaN                        NaN
# 2                   NaN                  NaN                        NaN
# 3                   NaN                  NaN                        NaN
# 4                   0.0                  0.0                        0.0
#
#   Total (Thousands)
# 0           -65,179
# 1              -786
# 2            17,378
# 3           -22,548
# 4           -71,135
#    Year Quarter Domestic (Thousands) Latin America (Thousands)  \
# 0  2000       1              360,535                    34,601
# 1  2000       2              411,879                    34,535
# 2  2000       3              465,351                    21,704
# 3  2000       4              393,650                    37,612
# 4  2000   TOTAL            1,631,415                   128,452
#
#    Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 0                   NaN                  NaN                        NaN
# 1                   NaN                  NaN                        NaN
# 2                   NaN                  NaN                        NaN
# 3                   NaN                  NaN                        NaN
# 4                   0.0                  0.0                        0.0
#
#   Total (Thousands)
# 0           395,136
# 1           446,414
# 2           487,055
# 3           431,262
# 4         1,759,867
#    Year  Month    DOMESTIC INTERNATIONAL       TOTAL
# 0  2002     10     931,774       122,764   1,054,538
# 1  2002     11     899,258       156,016   1,055,274
# 2  2002     12   1,082,705       173,780   1,256,485
# 3  2002  TOTAL  12,305,968     1,831,191  14,137,159
# 4  2003      1     878,763       170,253   1,049,016
#    Year  Month Domestic (Thousands) International (Thousands)  \
# 0  2002     10              828,901                   133,027
# 1  2002     11              808,997                   187,419
# 2  2002     12              998,526                   207,236
# 3  2002  TOTAL           11,096,319                 2,081,271
# 4  2003      1              807,069                   203,103
#
#   Total (Thousands)
# 0           961,928
# 1           996,416
# 2         1,205,762
# 3        13,177,590
# 4         1,010,172
#       timestamp    ALK  ALK_rolling_7_day_avg  ALK_rolling_14_day_avg  \
# 375  2018-04-02  57.75              61.375714               63.644286
# 376  2018-04-03  60.11              60.988571               63.024286
# 377  2018-04-04  61.22              60.894286               62.706429
# 378  2018-04-05  62.11              60.887143               62.434286
# 379  2018-04-06  61.44              60.880000               62.072143
#
#      ALK_rolling_30_day_avg  ALK_rolling_90_day_avg  ALK_7_days_ago  \
# 375               64.169667               67.395889           62.16
# 376               64.007667               67.329333           61.49
# 377               63.902000               67.274111           61.57
# 378               63.816000               67.235556           61.96
# 379               63.725000               67.191556             NaN
#
#      ALK_14_days_ago  ALK_30_days_ago  ALK_90_days_ago  ALK_log_price  \
# 375            65.10              NaN            75.01       4.056123
# 376            65.19              NaN            74.66       4.096176
# 377            64.21            63.62            73.85       4.114474
# 378            62.82            64.30            73.74       4.128907
# 379            61.88            64.00              NaN       4.118061
#
#      ALK_pct_change_7_days  ALK_pct_change_14_days  ALK_pct_change_30_days  \
# 375              -0.070946               -0.112903                     NaN
# 376              -0.022443               -0.077926                     NaN
# 377              -0.005685               -0.046566               -0.037724
# 378               0.002421               -0.011302               -0.034059
# 379                    NaN               -0.007111               -0.040000
#
#      ALK_pct_change_90_days
# 375               -0.230103
# 376               -0.194883
# 377               -0.171022
# 378               -0.157716
# 379                     NaN

# %%
# clean baggage

# dictionary to map quarters to their corresponding month and day
quarter_end_dates = {
    1: '03-31',
    2: '06-30',
    3: '09-30',
    4: '12-31'
}

# drop the total columns in order to convert to datetime. aggregation can easily replace total
alk_baggage_df = alk_baggage_df.loc[alk_baggage_df['Quarter'] != "TOTAL"].copy()

# convert quarter to numeric in order to use mapping 
alk_baggage_df['Quarter'] = pd.to_numeric(alk_baggage_df['Quarter'])

# convert to quarters, then resample to months
alk_baggage_df['date_str'] = alk_baggage_df['Year'].astype(str) + '-' + alk_baggage_df['Quarter'].map(quarter_end_dates)
alk_baggage_df['timestamp'] = pd.PeriodIndex(alk_baggage_df['date_str'], freq='Q')
alk_baggage_df.set_index('timestamp', inplace=True)
alk_baggage_df = alk_baggage_df.resample('M').ffill()


#drop placeholder date_str
alk_baggage_df.drop(columns=['date_str'], inplace=True)

# select the rows with dates corresponding to other data (October 2016-April 2018)
alk_baggage_df = alk_baggage_df.reset_index()
start_date = pd.Period('2016-10-01', freq = 'M')
end_date = pd.Period('2018-05-01', freq='M')
alk_baggage_df = alk_baggage_df.loc[(alk_baggage_df['timestamp'] >= start_date) & (alk_baggage_df['timestamp'] < end_date)]


# clean dtypes
alk_baggage_df['Total (Thousands)'] = alk_baggage_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# clean asm

# drop the total columns in order to convert to datetime. aggregation can easily replace total
alk_asm_df = alk_asm_df.loc[alk_asm_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
alk_asm_df['date_str'] = alk_asm_df['Year'].astype(str) + '-' + alk_asm_df['Month'].astype(str) + '-01'
alk_asm_df['timestamp'] = pd.to_datetime(alk_asm_df['date_str'])

# put time stamp as first column for clarity
alk_asm_df = alk_asm_df[['timestamp'] + [col for col in alk_asm_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
alk_asm_df['timestamp'] = alk_asm_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
alk_asm_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
alk_asm_df = alk_asm_df.loc[(alk_asm_df['timestamp'] >= start_date) & (alk_asm_df['timestamp'] < end_date)]

# convert dtypes
alk_asm_df['Domestic (Thousands)'] = alk_asm_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
alk_asm_df['International (Thousands)'] = alk_asm_df['International (Thousands)'].str.replace(",", "").astype(float)
alk_asm_df['Total (Thousands)'] = alk_asm_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# clean flight vol

# drop the total columns in order to convert to datetime. aggregation can easily replace total
alk_flight_vol_df = alk_flight_vol_df.loc[alk_flight_vol_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
alk_flight_vol_df['date_str'] = alk_flight_vol_df['Year'].astype(str) + '-' + alk_flight_vol_df['Month'].astype(str) + '-01'
alk_flight_vol_df['timestamp'] = pd.to_datetime(alk_flight_vol_df['date_str'])

# put time stamp as first column for clarity
alk_flight_vol_df = alk_flight_vol_df[['timestamp'] + [col for col in alk_flight_vol_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
alk_flight_vol_df['timestamp'] = alk_flight_vol_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
alk_flight_vol_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
alk_flight_vol_df = alk_flight_vol_df.loc[(alk_flight_vol_df['timestamp'] >= start_date) & (alk_flight_vol_df['timestamp'] < end_date)]

# clean dtypes
alk_flight_vol_df['DOMESTIC'] = alk_flight_vol_df['DOMESTIC'].str.replace(",", "").astype(float)
alk_flight_vol_df['INTERNATIONAL'] = alk_flight_vol_df['INTERNATIONAL'].str.replace(",", "").astype(float)
alk_flight_vol_df['TOTAL'] = alk_flight_vol_df['TOTAL'].str.replace(",", "").astype(float)

# %%
# clean fuel df 

alk_fuel_df.dtypes

month_name_to_number = {
    'January': 1,
    'February': 2,
    'March': 3,
    'April': 4,
    'May': 5,
    'June': 6,
    'July': 7,
    'August': 8,
    'September': 9,
    'October': 10,
    'November': 11,
    'December': 12
}

alk_fuel_df['Month'] = alk_fuel_df['Month'].astype(str)
alk_fuel_df = alk_fuel_df.loc[alk_fuel_df['Month'] != "nan"].copy()
alk_fuel_df['Month'] = alk_fuel_df['Month'].map(month_name_to_number)

# create datetime column to index compare to stock. 
alk_fuel_df['date_str'] = alk_fuel_df['Year'].astype(str) + '-' + alk_fuel_df['Month'].astype(str) + '-01'
alk_fuel_df['timestamp'] = pd.to_datetime(alk_fuel_df['date_str'])

# put time stamp as first column for clarity
alk_fuel_df = alk_fuel_df[['timestamp'] + [col for col in alk_fuel_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
alk_fuel_df['timestamp'] = alk_fuel_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
alk_fuel_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
alk_fuel_df = alk_fuel_df.loc[(alk_fuel_df['timestamp'] >= start_date) & (alk_fuel_df['timestamp'] < end_date)]

# clean dtypes
alk_fuel_df['Domestic Consumption\n(thousand gallons)'] = alk_fuel_df['Domestic Consumption\n(thousand gallons)'].str.replace(",", "").astype(float)
alk_fuel_df['Domestic Cost (thousand dollars)'] = alk_fuel_df['Domestic Cost (thousand dollars)'].str.replace(",", "").astype(float)
alk_fuel_df['Domestic Cost per Gallon (Dollars)'] = alk_fuel_df['Domestic Cost per Gallon (Dollars)'].str.replace(",", "").astype(float)
alk_fuel_df['International Consumption\n(thousand gallons)'] = alk_fuel_df['International Consumption\n(thousand gallons)'].str.replace(",", "").astype(float)
alk_fuel_df['International Cost (thousand dollars)'] = alk_fuel_df['International Cost (thousand dollars)'].str.replace(",", "").astype(float)
alk_fuel_df['International Cost per Gallon (Dollars)'] = alk_fuel_df['International Cost per Gallon (Dollars)'].str.replace(",", "").astype(float)
alk_fuel_df['Total Consumption\n(thousand gallons)'] = alk_fuel_df['Total Consumption\n(thousand gallons)'].str.replace(",", "").astype(float)
alk_fuel_df['Total Cost (thousand dollars)'] = alk_fuel_df['Total Cost (thousand dollars)'].str.replace(",", "").astype(float)
alk_fuel_df['Total Cost per Gallon (Dollars)'] = alk_fuel_df['Total Cost per Gallon (Dollars)'].str.replace(",", "").astype(float)

#rename certain columns
alk_fuel_df.rename(columns={'Domestic Consumption\n(thousand gallons)': 'Domestic Consumption (thousand gallons)'}, inplace=True)
alk_fuel_df.rename(columns={'International Consumption\n(thousand gallons)': 'International Consumption (thousand gallons)'}, inplace=True)
alk_fuel_df.rename(columns={'Total Consumption\n(thousand gallons)': 'Total Consumption (thousand gallons)'}, inplace=True)

# %%
# clean load factor 

# drop the total columns in order to convert to datetime. aggregation can easily replace total
alk_load_factor_df = alk_load_factor_df.loc[alk_load_factor_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
alk_load_factor_df['date_str'] = alk_load_factor_df['Year'].astype(str) + '-' + alk_load_factor_df['Month'].astype(str) + '-01'
alk_load_factor_df['timestamp'] = pd.to_datetime(alk_load_factor_df['date_str'])

# put time stamp as first column for clarity
alk_load_factor_df = alk_load_factor_df[['timestamp'] + [col for col in alk_load_factor_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
alk_load_factor_df['timestamp'] = alk_load_factor_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
alk_load_factor_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
alk_load_factor_df = alk_load_factor_df.loc[(alk_load_factor_df['timestamp'] >= start_date) & (alk_load_factor_df['timestamp'] < end_date)]

# dtypes came clean

# %%
# clean net income 

# dictionary to map quarters to their corresponding month and day
quarter_end_dates = {
    1: '03-31',
    2: '06-30',
    3: '09-30',
    4: '12-31'
}

# drop the total columns in order to convert to datetime. aggregation can easily replace total
alk_income_df = alk_income_df.loc[alk_income_df['Quarter'] != "TOTAL"].copy()

# convert quarter to numeric in order to use mapping 
alk_income_df['Quarter'] = pd.to_numeric(alk_income_df['Quarter'])

# convert to quarters, then resample to months
alk_income_df['date_str'] = alk_income_df['Year'].astype(str) + '-' + alk_income_df['Quarter'].map(quarter_end_dates)
alk_income_df['timestamp'] = pd.PeriodIndex(alk_income_df['date_str'], freq='Q')
alk_income_df.set_index('timestamp', inplace=True)
alk_income_df = alk_income_df.resample('M').ffill()

#drop placeholder date_str
alk_income_df.drop(columns=['date_str'], inplace=True)

# select the rows with dates corresponding to other data (October 2016-April 2018)
alk_income_df = alk_income_df.reset_index()
start_date = pd.Period('2016-10-01', freq = 'M')
end_date = pd.Period('2018-05-01', freq='M')
alk_income_df = alk_income_df.loc[(alk_income_df['timestamp'] >= start_date) & (alk_income_df['timestamp'] < end_date)]

# clean dtypes
alk_income_df['Domestic (Thousands)'] = alk_income_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
alk_income_df['Latin America (Thousands)'] = alk_income_df['Latin America (Thousands)'].str.replace(",", "").astype(float)
alk_income_df['Total (Thousands)'] = alk_income_df['Total (Thousands)'].str.replace(",", "").astype(float)

# dtypes came clean
display(alk_income_df)
# Out:
#     timestamp  Year  Quarter  Domestic (Thousands)  Latin America (Thousands)  \
# 201   2016-10  2016        4              159447.0                     5495.0
# 202   2016-11  2016        4              159447.0                     5495.0
# 203   2016-12  2016        4              159447.0                     5495.0
# 204   2017-01  2017        1              119652.0                     3013.0
# 205   2017-02  2017        1              119652.0                     3013.0
# 206   2017-03  2017        1              119652.0                     3013.0
# 207   2017-04  2017        2              263274.0                    10404.0
# 208   2017-05  2017        2              263274.0                    10404.0
# 209   2017-06  2017        2              263274.0                    10404.0
# 210   2017-07  2017        3              242512.0                     9220.0
# 211   2017-08  2017        3              242512.0                     9220.0
# 212   2017-09  2017        3              242512.0                     9220.0
# 213   2017-10  2017        4              413168.0                    12997.0
# 214   2017-11  2017        4              413168.0                    12997.0
# 215   2017-12  2017        4              413168.0                    12997.0
# 216   2018-01  2018        1               23052.0                    -7184.0
# 217   2018-02  2018        1               23052.0                    -7184.0
# 218   2018-03  2018        1               23052.0                    -7184.0
# 219   2018-04  2018        2              208737.0                     6428.0
#
#      Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 201                   NaN                  NaN                        NaN
# 202                   NaN                  NaN                        NaN
# 203                   NaN                  NaN                        NaN
# 204                   NaN                  NaN                        NaN
# 205                   NaN                  NaN                        NaN
# 206                   NaN                  NaN                        NaN
# 207                   NaN                  NaN                        NaN
# 208                   NaN                  NaN                        NaN
# 209                   NaN                  NaN                        NaN
# 210                   NaN                  NaN                        NaN
# 211                   NaN                  NaN                        NaN
# 212                   NaN                  NaN                        NaN
# 213                   NaN                  NaN                        NaN
# 214                   NaN                  NaN                        NaN
# 215                   NaN                  NaN                        NaN
# 216                   NaN                  NaN                        NaN
# 217                   NaN                  NaN                        NaN
# 218                   NaN                  NaN                        NaN
# 219                   NaN                  NaN                        NaN
#
#      Total (Thousands)
# 201           164942.0
# 202           164942.0
# 203           164942.0
# 204           122665.0
# 205           122665.0
# 206           122665.0
# 207           273678.0
# 208           273678.0
# 209           273678.0
# 210           251732.0
# 211           251732.0
# 212           251732.0
# 213           426165.0
# 214           426165.0
# 215           426165.0
# 216            15868.0
# 217            15868.0
# 218            15868.0
# 219           215165.0

# %%
# clean operating revenue

# drop the total columns in order to convert to datetime. aggregation can easily replace total
alk_operating_revenue_df = alk_operating_revenue_df.loc[alk_operating_revenue_df['Quarter'] != "TOTAL"].copy()

# convert quarter to numeric in order to use mapping 
alk_operating_revenue_df['Quarter'] = pd.to_numeric(alk_operating_revenue_df['Quarter'])

# convert to quarters, then resample to months
alk_operating_revenue_df['date_str'] = alk_operating_revenue_df['Year'].astype(str) + '-' + alk_operating_revenue_df['Quarter'].map(quarter_end_dates)
alk_operating_revenue_df['timestamp'] = pd.PeriodIndex(alk_operating_revenue_df['date_str'], freq='Q')
alk_operating_revenue_df.set_index('timestamp', inplace=True)
alk_operating_revenue_df = alk_operating_revenue_df.resample('M').ffill()

#drop placeholder date_str
alk_operating_revenue_df.drop(columns=['date_str'], inplace=True)

# select the rows with dates corresponding to other data (October 2016-April 2018)
alk_operating_revenue_df = alk_operating_revenue_df.reset_index()
start_date = pd.Period('2016-10-01', freq = 'M')
end_date = pd.Period('2018-05-01', freq='M')
alk_operating_revenue_df = alk_operating_revenue_df.loc[(alk_operating_revenue_df['timestamp'] >= start_date) & (alk_operating_revenue_df['timestamp'] < end_date)]

alk_operating_revenue_df['Domestic (Thousands)'] = alk_operating_revenue_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
alk_operating_revenue_df['Total (Thousands)'] = alk_operating_revenue_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# clean passenger volume df

# drop the total columns in order to convert to datetime. aggregation can easily replace total
alk_passenger_vol_df = alk_passenger_vol_df.loc[alk_passenger_vol_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
alk_passenger_vol_df['date_str'] = alk_passenger_vol_df['Year'].astype(str) + '-' + alk_passenger_vol_df['Month'].astype(str) + '-01'
alk_passenger_vol_df['timestamp'] = pd.to_datetime(alk_passenger_vol_df['date_str'])

# put time stamp as first column for clarity
alk_passenger_vol_df = alk_passenger_vol_df[['timestamp'] + [col for col in alk_passenger_vol_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
alk_passenger_vol_df['timestamp'] = alk_passenger_vol_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
alk_passenger_vol_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
alk_passenger_vol_df = alk_passenger_vol_df.loc[(alk_passenger_vol_df['timestamp'] >= start_date) & (alk_passenger_vol_df['timestamp'] < end_date)]

# clean dtypes
alk_passenger_vol_df['DOMESTIC'] = alk_passenger_vol_df['DOMESTIC'].str.replace(",", "").astype(float)
alk_passenger_vol_df['INTERNATIONAL'] = alk_passenger_vol_df['INTERNATIONAL'].str.replace(",", "").astype(float)
alk_passenger_vol_df['TOTAL'] = alk_passenger_vol_df['TOTAL'].str.replace(",", "").astype(float)

# %%
# clean rpm df 

# drop the total columns in order to convert to datetime. aggregation can easily replace total
alk_rpm_df = alk_rpm_df.loc[alk_rpm_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
alk_rpm_df['date_str'] = alk_rpm_df['Year'].astype(str) + '-' + alk_rpm_df['Month'].astype(str) + '-01'
alk_rpm_df['timestamp'] = pd.to_datetime(alk_rpm_df['date_str'])

# put time stamp as first column for clarity
alk_rpm_df = alk_rpm_df[['timestamp'] + [col for col in alk_rpm_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
alk_rpm_df['timestamp'] = alk_rpm_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
alk_rpm_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
alk_rpm_df = alk_rpm_df.loc[(alk_rpm_df['timestamp'] >= start_date) & (alk_rpm_df['timestamp'] < end_date)]

# clean dtypes
alk_rpm_df['Domestic (Thousands)'] = alk_rpm_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
alk_rpm_df['International (Thousands)'] = alk_rpm_df['International (Thousands)'].str.replace(",", "").astype(float)
alk_rpm_df['Total (Thousands)'] = alk_rpm_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# alk stock dtype clean
alk_stock_df['timestamp'] = pd.to_datetime(alk_stock_df['timestamp'])

# %%
display(alk_asm_df.head())
display(alk_flight_vol_df.head())
display(alk_fuel_df.head())
display(alk_load_factor_df.head())
display(alk_income_df.head())
display(alk_operating_revenue_df.head())
display(alk_passenger_vol_df.head())
display(alk_rpm_df.head())
display(alk_baggage_df.head())
display(alk_stock_df.tail())
# Out:
#      timestamp  Year Month  Domestic (Thousands)  International (Thousands)  \
# 182 2016-10-31  2016    10             2837525.0                   210139.0
# 183 2016-11-30  2016    11             2873148.0                   258688.0
# 184 2016-12-31  2016    12             3000939.0                   295733.0
# 186 2017-01-31  2017     1             3008207.0                   314637.0
# 187 2017-02-28  2017     2             2674635.0                   290123.0
#
#      Total (Thousands)
# 182          3047664.0
# 183          3131836.0
# 184          3296672.0
# 186          3322843.0
# 187          2964758.0
#      timestamp  Year Month  DOMESTIC  INTERNATIONAL    TOTAL
# 182 2016-10-31  2016    10   14059.0         1118.0  15177.0
# 183 2016-11-30  2016    11   13953.0         1230.0  15183.0
# 184 2016-12-31  2016    12   14409.0         1394.0  15803.0
# 186 2017-01-31  2017     1   14525.0         1399.0  15924.0
# 187 2017-02-28  2017     2   13108.0         1281.0  14389.0
#     timestamp  Year  Month  Domestic Consumption (thousand gallons)  \
# 64 2016-10-31  2016     10                                  35852.0
# 65 2016-11-30  2016     11                                  36846.0
# 66 2016-12-31  2016     12                                  39195.0
# 69 2017-01-31  2017      1                                  39098.0
# 70 2017-02-28  2017      2                                  35038.0
#
#     Domestic Cost (thousand dollars)  Domestic Cost per Gallon (Dollars)  \
# 64                           59295.0                                1.65
# 65                           59774.0                                1.62
# 66                           66505.0                                1.70
# 69                           68434.0                                1.75
# 70                           62679.0                                1.79
#
#     International Consumption (thousand gallons)  \
# 64                                         612.0
# 65                                         721.0
# 66                                         891.0
# 69                                         760.0
# 70                                         722.0
#
#     International Cost (thousand dollars)  \
# 64                                 1076.0
# 65                                 1229.0
# 66                                 1581.0
# 69                                 1406.0
# 70                                 1334.0
#
#     International Cost per Gallon (Dollars)  \
# 64                                      2.0
# 65                                      2.0
# 66                                      2.0
# 69                                      2.0
# 70                                      2.0
#
#     Total Consumption (thousand gallons)  Total Cost (thousand dollars)  \
# 64                               36464.0                        60371.0
# 65                               37567.0                        61003.0
# 66                               40086.0                        68086.0
# 69                               39858.0                        69840.0
# 70                               35760.0                        64013.0
#
#     Total Cost per Gallon (Dollars)
# 64                             1.66
# 65                             1.62
# 66                             1.70
# 69                             1.75
# 70                             1.79
#      timestamp  Year Month  DOMESTIC  INTERNATIONAL  TOTAL
# 182 2016-10-31  2016    10     85.26          79.43  84.86
# 183 2016-11-30  2016    11     86.22          82.06  85.88
# 184 2016-12-31  2016    12     85.38          81.26  85.01
# 186 2017-01-31  2017     1     79.25          79.75  79.30
# 187 2017-02-28  2017     2     81.58          79.67  81.39
#     timestamp  Year  Quarter  Domestic (Thousands)  Latin America (Thousands)  \
# 201   2016-10  2016        4              159447.0                     5495.0
# 202   2016-11  2016        4              159447.0                     5495.0
# 203   2016-12  2016        4              159447.0                     5495.0
# 204   2017-01  2017        1              119652.0                     3013.0
# 205   2017-02  2017        1              119652.0                     3013.0
#
#      Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 201                   NaN                  NaN                        NaN
# 202                   NaN                  NaN                        NaN
# 203                   NaN                  NaN                        NaN
# 204                   NaN                  NaN                        NaN
# 205                   NaN                  NaN                        NaN
#
#      Total (Thousands)
# 201           164942.0
# 202           164942.0
# 203           164942.0
# 204           122665.0
# 205           122665.0
#     timestamp  Year  Quarter  Domestic (Thousands) Latin America (Thousands)  \
# 201   2016-10  2016        4             1346601.0                    76,913
# 202   2016-11  2016        4             1346601.0                    76,913
# 203   2016-12  2016        4             1346601.0                    76,913
# 204   2017-01  2017        1             1302611.0                    88,476
# 205   2017-02  2017        1             1302611.0                    88,476
#
#      Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 201                   NaN                  NaN                        NaN
# 202                   NaN                  NaN                        NaN
# 203                   NaN                  NaN                        NaN
# 204                   NaN                  NaN                        NaN
# 205                   NaN                  NaN                        NaN
#
#      Total (Thousands)
# 201          1423514.0
# 202          1423514.0
# 203          1423514.0
# 204          1391087.0
# 205          1391087.0
#      timestamp  Year Month   DOMESTIC  INTERNATIONAL      TOTAL
# 182 2016-10-31  2016    10  1799719.0       143925.0  1943644.0
# 183 2016-11-30  2016    11  1820053.0       163353.0  1983406.0
# 184 2016-12-31  2016    12  1868147.0       180499.0  2048646.0
# 186 2017-01-31  2017     1  1731548.0       181003.0  1912551.0
# 187 2017-02-28  2017     2  1625266.0       166695.0  1791961.0
#      timestamp  Year Month  Domestic (Thousands)  International (Thousands)  \
# 182 2016-10-31  2016    10             2419373.0                   166908.0
# 183 2016-11-30  2016    11             2477244.0                   212278.0
# 184 2016-12-31  2016    12             2562145.0                   240311.0
# 186 2017-01-31  2017     1             2384125.0                   250921.0
# 187 2017-02-28  2017     2             2181994.0                   231131.0
#
#      Total (Thousands)
# 182          2586282.0
# 183          2689522.0
# 184          2802456.0
# 186          2635046.0
# 187          2413125.0
#    timestamp  Year  Quarter  Total (Thousands)
# 9    2016-10  2016        4            30811.0
# 10   2016-11  2016        4            30811.0
# 11   2016-12  2016        4            30811.0
# 12   2017-01  2017        1            30602.0
# 13   2017-02  2017        1            30602.0
#      timestamp    ALK  ALK_rolling_7_day_avg  ALK_rolling_14_day_avg  \
# 375 2018-04-02  57.75              61.375714               63.644286
# 376 2018-04-03  60.11              60.988571               63.024286
# 377 2018-04-04  61.22              60.894286               62.706429
# 378 2018-04-05  62.11              60.887143               62.434286
# 379 2018-04-06  61.44              60.880000               62.072143
#
#      ALK_rolling_30_day_avg  ALK_rolling_90_day_avg  ALK_7_days_ago  \
# 375               64.169667               67.395889           62.16
# 376               64.007667               67.329333           61.49
# 377               63.902000               67.274111           61.57
# 378               63.816000               67.235556           61.96
# 379               63.725000               67.191556             NaN
#
#      ALK_14_days_ago  ALK_30_days_ago  ALK_90_days_ago  ALK_log_price  \
# 375            65.10              NaN            75.01       4.056123
# 376            65.19              NaN            74.66       4.096176
# 377            64.21            63.62            73.85       4.114474
# 378            62.82            64.30            73.74       4.128907
# 379            61.88            64.00              NaN       4.118061
#
#      ALK_pct_change_7_days  ALK_pct_change_14_days  ALK_pct_change_30_days  \
# 375              -0.070946               -0.112903                     NaN
# 376              -0.022443               -0.077926                     NaN
# 377              -0.005685               -0.046566               -0.037724
# 378               0.002421               -0.011302               -0.034059
# 379                    NaN               -0.007111               -0.040000
#
#      ALK_pct_change_90_days
# 375               -0.230103
# 376               -0.194883
# 377               -0.171022
# 378               -0.157716
# 379                     NaN

# %%
alk_asm_df.dtypes
# Out:
# timestamp                    datetime64[ns]
# Year                                  int64
# Month                                object
# Domestic (Thousands)                float64
# International (Thousands)           float64
# Total (Thousands)                   float64
# dtype: object

# %%
alk_flight_vol_df.dtypes
# Out:
# timestamp        datetime64[ns]
# Year                      int64
# Month                    object
# DOMESTIC                float64
# INTERNATIONAL           float64
# TOTAL                   float64
# dtype: object

# %%
alk_fuel_df.dtypes
# Out:
# timestamp                                       datetime64[ns]
# Year                                                    object
# Month                                                    int64
# Domestic Consumption (thousand gallons)                float64
# Domestic Cost (thousand dollars)                       float64
# Domestic Cost per Gallon (Dollars)                     float64
# International Consumption (thousand gallons)           float64
# International Cost (thousand dollars)                  float64
# International Cost per Gallon (Dollars)                float64
# Total Consumption (thousand gallons)                   float64
# Total Cost (thousand dollars)                          float64
# Total Cost per Gallon (Dollars)                        float64
# dtype: object

# %%
alk_load_factor_df.dtypes
# Out:
# timestamp        datetime64[ns]
# Year                      int64
# Month                    object
# DOMESTIC                float64
# INTERNATIONAL           float64
# TOTAL                   float64
# dtype: object

# %%
alk_income_df.dtypes
# Out:
# timestamp                    period[M]
# Year                             int64
# Quarter                          int64
# Domestic (Thousands)           float64
# Latin America (Thousands)      float64
# Atlantic (Thousands)           float64
# Pacific (Thousands)            float64
# International (Thousands)      float64
# Total (Thousands)              float64
# dtype: object

# %%
alk_operating_revenue_df.dtypes
# Out:
# timestamp                    period[M]
# Year                             int64
# Quarter                          int64
# Domestic (Thousands)           float64
# Latin America (Thousands)       object
# Atlantic (Thousands)           float64
# Pacific (Thousands)            float64
# International (Thousands)      float64
# Total (Thousands)              float64
# dtype: object

# %%
alk_passenger_vol_df.dtypes
# Out:
# timestamp        datetime64[ns]
# Year                      int64
# Month                    object
# DOMESTIC                float64
# INTERNATIONAL           float64
# TOTAL                   float64
# dtype: object

# %%
alk_rpm_df.dtypes
# Out:
# timestamp                    datetime64[ns]
# Year                                  int64
# Month                                object
# Domestic (Thousands)                float64
# International (Thousands)           float64
# Total (Thousands)                   float64
# dtype: object

# %%
alk_baggage_df.dtypes
# Out:
# timestamp            period[M]
# Year                     int64
# Quarter                  int64
# Total (Thousands)      float64
# dtype: object

# %%
alk_stock_df.dtypes
# Out:
# timestamp                 datetime64[ns]
# ALK                              float64
# ALK_rolling_7_day_avg            float64
# ALK_rolling_14_day_avg           float64
# ALK_rolling_30_day_avg           float64
# ALK_rolling_90_day_avg           float64
# ALK_7_days_ago                   float64
# ALK_14_days_ago                  float64
# ALK_30_days_ago                  float64
# ALK_90_days_ago                  float64
# ALK_log_price                    float64
# ALK_pct_change_7_days            float64
# ALK_pct_change_14_days           float64
# ALK_pct_change_30_days           float64
# ALK_pct_change_90_days           float64
# dtype: object

# %% [markdown]
# # Analysis

# %%
avail_seat_miles = alk_asm_df
baggage_fees = alk_baggage_df
fuel = alk_fuel_df
load_factor = alk_load_factor_df
net_income = alk_income_df
operating_revenue = alk_operating_revenue_df
passengers = alk_passenger_vol_df
revenue_passenger_miles = alk_rpm_df
flights = alk_flight_vol_df




prices = alk_stock_df[alk_stock_df['timestamp'].dt.day < 4]
prices = prices[['timestamp','ALK']]
prices.set_index('timestamp',inplace = True)
price = prices.resample('M').mean()
price = price.values
p = []
for i in range(len(price)):
    p.append(price[i][0])
price = numpy.array(p)

# %% [markdown]
# Correlation/Plots for Available Seat Miles

# %%
# time series plots for domestic, intl, and total asm
avail_seat_miles.set_index('timestamp', inplace = True)
avail_seat_miles['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Available Seat Miles (Thousands)')
plt.title('Time Series of Total Available Seat Miles')
plt.grid(True)
plt.show()

avail_seat_miles['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Available Seat Miles (Thousands)')
plt.title('Time Series of Domestic Available Seat Miles')
plt.grid(True)
plt.show()

avail_seat_miles['International (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Available Seat Miles (Thousands)')
plt.title('Time Series of International Available Seat Miles')
plt.grid(True)
plt.show()

# %%
# available seat miles versus stock price plots
total = avail_seat_miles['Total (Thousands)'].values
domestic = avail_seat_miles['Domestic (Thousands)'].values
intl = avail_seat_miles['International (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Available Seat Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Available Seat Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('International Available Seat Miles vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients for asm

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Available Seat Miles to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Available Seat Miles to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Available Seat Miles to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Available Seat Miles to Stock Price is :-0.24597060419540887
# The correlation coefficent for Domestic Available Seat Miles to Stock Price is :-0.23769501434617454
# The correlation coefficent for International Available Seat Miles to Stock Price is :-0.10969096300959985

# %% [markdown]
# Correlation/Plots for Baggage Fees

# %%
# time series plot of baggage fees
baggage_fees.set_index('timestamp', inplace = True)
baggage_fees['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Total Fees ($Thousands)')
plt.title('Time Series of Total Baggage Fees')
plt.grid(True)
plt.show()

# %%
# available seat miles versus stock price plots
fees = baggage_fees['Total (Thousands)'].values


plt.scatter(fees, price)
plt.xlabel('Baggage Fees ($Thousands)')
plt.ylabel('Stock Price')
plt.title('Baggage Fees vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficient for baggage fees

fee_r = numpy.corrcoef(fees,price)[0,1]
print("The correlation coefficent for Baggage Fees to Stock Price is :" + str(total_r))
# Out:
# The correlation coefficent for Baggage Fees to Stock Price is :-0.24597060419540887

# %% [markdown]
# Correlation/Plots for Fuel

# %%
# time series plots for domestic, intl, and total fuel
fuel.set_index('timestamp', inplace = True)
fuel['Domestic Consumption (thousand gallons)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Consumption (thousand gallons)')
plt.title('Time Series of Domestic Fuel Consumption')
plt.grid(True)
plt.show()

fuel['International Consumption (thousand gallons)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Consumption (thousand gallons)')
plt.title('Time Series of International Fuel Consumption')
plt.grid(True)
plt.show()

fuel['Total Consumption (thousand gallons)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Consumption (thousand gallons)')
plt.title('Time Series of Total Consumption')
plt.grid(True)
plt.show()

fuel['Domestic Cost (thousand dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Cost (thousand dollars)')
plt.title('Time Series of Domestic Fuel Cost')
plt.grid(True)
plt.show()

fuel['International Cost (thousand dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Cost (thousand dollars)')
plt.title('Time Series of International Fuel Cost')
plt.grid(True)
plt.show()

fuel['Total Cost (thousand dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Cost (thousand dollars)')
plt.title('Time Series of Total Fuel Cost')
plt.grid(True)
plt.show()

fuel['Domestic Cost per Gallon (Dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Cost per Gallon (Dollars)')
plt.title('Time Series of Domestic Cost per Gallon')
plt.grid(True)
plt.show()

fuel['International Cost per Gallon (Dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Cost per Gallon (Dollars)')
plt.title('Time Series of International Cost per Gallon')
plt.grid(True)
plt.show()

fuel['Total Cost per Gallon (Dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Cost per Gallon (Dollars)')
plt.title('Time Series of Cost per Gallon')
plt.grid(True)
plt.show()

# %%
# fuel versus stock price plots
total_consumption = fuel['Total Consumption (thousand gallons)'].values
domestic_consumption = fuel['Domestic Consumption (thousand gallons)'].values
intl_consumption = fuel['International Consumption (thousand gallons)'].values
total_cost =fuel['Total Cost (thousand dollars)'].values
domestic_cost = fuel['Domestic Cost (thousand dollars)'].values
intl_cost =fuel['International Cost (thousand dollars)'].values
total_cpg = fuel['Total Cost per Gallon (Dollars)'].values
domestic_cpg =fuel['Domestic Cost per Gallon (Dollars)'].values
intl_cpg =fuel['International Cost per Gallon (Dollars)'].values


plt.figure()
plt.scatter(total_consumption, price)
plt.xlabel('Consumption (thousand gallons)')
plt.ylabel('Stock Price')
plt.title('Total Fuel Consumption (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic_consumption, price)
plt.xlabel('Consumption (thousand gallons)')
plt.ylabel('Stock Price')
plt.title('Domestic Fuel Consumption (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl_consumption, price)
plt.xlabel('Consumption (thousand gallons)')
plt.ylabel('Stock Price')
plt.title('International Fuel Consumption (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(total_cost, price)
plt.xlabel('Cost (thousand dollars)')
plt.ylabel('Stock Price')
plt.title('Total Fuel Cost (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic_cost, price)
plt.xlabel('Cost (thousand dollars)')
plt.ylabel('Stock Price')
plt.title('Domestic Fuel Cost (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl_cost, price)
plt.xlabel('Cost (thousand dollars)')
plt.ylabel('Stock Price')
plt.title('International Fuel Cost (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(total_cpg, price)
plt.xlabel('Cost per Gallon (Dollars)')
plt.ylabel('Stock Price')
plt.title('Total Fuel Cost per Gallon (Dollars) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic_cpg, price)
plt.xlabel('Cost per Gallon (Dollars)')
plt.ylabel('Stock Price')
plt.title('Domestic Fuel Cost per Gallon (Dollars) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl_cpg, price)
plt.xlabel('Cost per Gallon (Dollars)')
plt.ylabel('Stock Price')
plt.title('International Fuel Cost per Gallon (Dollars) vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients for fuel

r1 = numpy.corrcoef(total_consumption, price)[0,1]
print("The correlation coefficent for Total Fuel Consumption (thousand gallons) vs Stock Price is :" + str(r1))
r2 = numpy.corrcoef(domestic_consumption ,price)[0,1]
print("The correlation coefficent for Domestic Fuel Consumption (thousand gallons) vs Stock Price is :" + str(r2))
r3 = numpy.corrcoef(intl_consumption,price)[0,1]
print("The correlation coefficent for International Fuel Consumption (thousand gallons) vs Stock Price is:" + str(r3))

r4 = numpy.corrcoef(total_cost, price)[0,1]
print("The correlation coefficent for Total Fuel Cost (thousand gallons) vs Stock Price is:" + str(r4))
r5 = numpy.corrcoef(domestic_cost ,price)[0,1]
print("The correlation coefficent for Domestic Fuel Cost (thousand gallons) vs Stock Price :" + str(r5))
r6 = numpy.corrcoef(intl_cost,price)[0,1]
print("The correlation coefficent for International Fuel Cost (thousand gallons) vs Stock Price:" + str(r6))

r7 = numpy.corrcoef(total_cpg, price)[0,1]
print("The correlation coefficent for Total Fuel Cost per Gallon (Dollars) vs Stock Price :" + str(r7))
r8 = numpy.corrcoef(domestic_cpg ,price)[0,1]
print("The correlation coefficent for Domestic Fuel Cost per Gallon (Dollars) vs Stock Price :" + str(r8))
r9 = numpy.corrcoef(intl_cpg,price)[0,1]
print("The correlation coefficent for International Fuel Cost per Gallon (Dollars) vs Stock Price :" + str(r9))
# Out:
# The correlation coefficent for Total Fuel Consumption (thousand gallons) vs Stock Price is :-0.46695184562663966
# The correlation coefficent for Domestic Fuel Consumption (thousand gallons) vs Stock Price is :-0.4515176001991987
# The correlation coefficent for International Fuel Consumption (thousand gallons) vs Stock Price is:-0.6502003222949613
# The correlation coefficent for Total Fuel Cost (thousand gallons) vs Stock Price is:-0.5880523107580322
# The correlation coefficent for Domestic Fuel Cost (thousand gallons) vs Stock Price :-0.5815129061351064
# The correlation coefficent for International Fuel Cost (thousand gallons) vs Stock Price:-0.6791008944696053
# The correlation coefficent for Total Fuel Cost per Gallon (Dollars) vs Stock Price :-0.6712417659382726
# The correlation coefficent for Domestic Fuel Cost per Gallon (Dollars) vs Stock Price :-0.6659287370450119
# The correlation coefficent for International Fuel Cost per Gallon (Dollars) vs Stock Price :nan
# /Users/liamoshaughnessy/anaconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/liamoshaughnessy/anaconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %% [markdown]
# Correlation/Plots for Load Factor

# %%
# time series plots for domestic, intl, and total load factor
load_factor.set_index('timestamp', inplace = True)
load_factor['DOMESTIC'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Load Factor')
plt.title('Time Series of Domestic Load Factor')
plt.grid(True)
plt.show()

load_factor['INTERNATIONAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Load Factor')
plt.title('Time Series of International Load Factor')
plt.grid(True)
plt.show()

load_factor['TOTAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Load Factor')
plt.title('Time Series of Total Load Factor')
plt.grid(True)
plt.show()

# %%
# load factor versus stock price plots
total = load_factor['TOTAL'].values
domestic = load_factor['DOMESTIC'].values
intl = load_factor['INTERNATIONAL'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Load Factor')
plt.ylabel('Stock Price')
plt.title('Total Load Factor vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Load Factor')
plt.ylabel('Stock Price')
plt.title('Domestic Load Factor vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Load Factor')
plt.ylabel('Stock Price')
plt.title('International Load Factor vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients
total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Load Factor to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Load Factor to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Load Factor to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Load Factor to Stock Price is :0.21827663813036974
# The correlation coefficent for Domestic Load Factor to Stock Price is :0.20968544000329264
# The correlation coefficent for International Load Factor to Stock Price is :0.14893232066318268

# %% [markdown]
# Correlation/Plots for Net Income

# %%
# time series plots for domestic and total net income
net_income.set_index('timestamp', inplace = True)
net_income['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Net Income (Thousands)')
plt.title('Time Series of Domestic Net Income')
plt.grid(True)
plt.show()

net_income['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Net Income (Thousands)')
plt.title('Time Series of Total Net Income')
plt.grid(True)
plt.show()

# %%
# net income versus stock price plots
total = net_income['Domestic (Thousands)'].values
domestic = net_income['Total (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Net Income (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Net Income vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Net Income (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Net Income vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Net Income to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Net Income to Stock Price is :" + str(domestic_r))
# Out:
# The correlation coefficent for Total Net Income to Stock Price is :-0.012431861482901995
# The correlation coefficent for Domestic Net Income to Stock Price is :-0.0012164798292167405

# %% [markdown]
# Correlation/Plots for Operating Revenue

# %%
# time series plots for domestic and total operating revenue
operating_revenue.set_index('timestamp', inplace = True)
operating_revenue['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Operating Revenue (Thousands)')
plt.title('Time Series of Total Operating Revenue')
plt.grid(True)
plt.show()


avail_seat_miles['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Operating Revenue (Thousands)')
plt.title('Time Series of Domestic Operating Revenue')
plt.grid(True)
plt.show()

# %%
# operating revenue versus stock price plots
total = operating_revenue['Total (Thousands)'].values
domestic = operating_revenue['Domestic (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Operating Revenue (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Operating Revenue vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Operating Revenue (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Operating Revenue vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Operating Revenue to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Operating Revenue to Stock Price is :" + str(domestic_r))
# Out:
# The correlation coefficent for Total Operating Revenue to Stock Price is :-0.4592569839275182
# The correlation coefficent for Domestic Operating Revenue to Stock Price is :-0.4503660118986358

# %% [markdown]
# Correlations/Plots for Passengers

# %%
# time series plots for domestic, intl, and total passengers
passengers.set_index('timestamp', inplace = True)
passengers['TOTAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.title('Time Series of Total Passengers')
plt.grid(True)
plt.show()

passengers['DOMESTIC'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.title('Time Series of Domestic Passengers')
plt.grid(True)
plt.show()

passengers['INTERNATIONAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.title('Time Series of International Passengers')
plt.grid(True)
plt.show()

# %%
# passengers versus stock price plots
total = passengers['TOTAL'].values
domestic = passengers['DOMESTIC'].values
intl = passengers['INTERNATIONAL'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Passengers')
plt.ylabel('Stock Price')
plt.title('Total Passengers vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Passengers')
plt.ylabel('Stock Price')
plt.title('Domestic Passengers vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Passengers')
plt.ylabel('Stock Price')
plt.title('International Passengers vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Passengers to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Passengers to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Passengers to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Passengers to Stock Price is :-0.1456156046266246
# The correlation coefficent for Domestic Passengers to Stock Price is :-0.15351861003476275
# The correlation coefficent for International Passengers to Stock Price is :0.06812139174481013

# %% [markdown]
# Correlations/Plots for Revenue Passenger-Miles

# %%
# time series plots for domestic, intl, and total rpm
revenue_passenger_miles.set_index('timestamp', inplace = True)
revenue_passenger_miles['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Revenue Passenger-Miles (Thousands)')
plt.title('Time Series of Total Revenue Passenger-Miles')
plt.grid(True)
plt.show()

revenue_passenger_miles['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Revenue Passenger-Miles (Thousands)')
plt.title('Time Series of Domestic Revenue Passenger-Miles')
plt.grid(True)
plt.show()

revenue_passenger_miles['International (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Revenue Passenger-Miles (Thousands)')
plt.title('Time Series of International Revenue Passenger-Miles')
plt.grid(True)
plt.show()

# %%
# revenue passenger miles versus stock price plots
total = revenue_passenger_miles['Total (Thousands)'].values
domestic = revenue_passenger_miles['Domestic (Thousands)'].values
intl = revenue_passenger_miles['International (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Revenue Passenger Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Revenue Passenger Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Revenue Passenger Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Revenue Passenger Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('International Revenue Passenger Miles vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients for rpm

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Revenue Passenger Miles to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Revenue Passenger Miless to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Revenue Passenger Miles to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Revenue Passenger Miles to Stock Price is :-0.16019479759844713
# The correlation coefficent for Domestic Revenue Passenger Miless to Stock Price is :-0.15627232545842373
# The correlation coefficent for International Revenue Passenger Miles to Stock Price is :-0.061916117514234946

# %% [markdown]
# Correlations/Plots for Flights

# %%
# time series plots for domestic, intl, and total flights
flights.set_index('timestamp', inplace = True)
flights['TOTAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Flights')
plt.title('Time Series of Total Flights')
plt.grid(True)
plt.show()

flights['DOMESTIC'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Flights')
plt.title('Time Series of Domestic Flights')
plt.grid(True)
plt.show()

flights['INTERNATIONAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Flights')
plt.title('Time Series of International Flights')
plt.grid(True)
plt.show()

# %%
# flights versus stock price plots
total = flights['TOTAL'].values
domestic = flights['DOMESTIC'].values
intl = flights['INTERNATIONAL'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('# of Flights')
plt.ylabel('Stock Price')
plt.title('Total # of Flights vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('# of Flights')
plt.ylabel('Stock Price')
plt.title('Domestic # of Flights vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('# of Flights')
plt.ylabel('Stock Price')
plt.title('International # of Flights vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total # of Flights to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic # of Flights to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International # of Flights to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total # of Flights to Stock Price is :-0.19579122633224688
# The correlation coefficent for Domestic # of Flights to Stock Price is :-0.19915665247290443
# The correlation coefficent for International # of Flights to Stock Price is :0.024780517869402257
