# %% [markdown]
# # DAL Clean

# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 300)

dal_asm_df = pd.read_csv('Available Seat-Miles - All Airports - Delta.csv')
dal_flight_vol_df = pd.read_csv('Flights - All Airports - Delta.csv')
dal_fuel_df = pd.read_csv('Fuel - All Service - Delta.csv')
dal_load_factor_df = pd.read_csv('Load Factor - All Airports - Delta.csv')
dal_income_df = pd.read_csv('Net Income - All Regions - Delta.csv')
dal_operating_revenue_df = pd.read_csv('Operating Revenue - All Regions - Delta.csv')
dal_passenger_vol_df = pd.read_csv('Passengers - All Airports - Delta.csv')
dal_rpm_df = pd.read_csv('Revenue Passager-Miles - All Airports - Delta.csv')
dal_stock_df = pd.read_csv('DAL_stock_data.csv')
dal_baggage_df = pd.read_csv('Baggage Fees - All Airports - Delta.csv')

display(dal_asm_df.head())
display(dal_flight_vol_df.head())
display(dal_fuel_df.head())
display(dal_load_factor_df.head())
display(dal_income_df.head())
display(dal_operating_revenue_df.head())
display(dal_passenger_vol_df.head())
display(dal_rpm_df.head())
display(dal_stock_df.tail())
# Out:
#    Year  Month Domestic (Thousands) International (Thousands)  \
# 0  2002     10            8,332,093                 2,766,881
# 1  2002     11            7,919,522                 2,505,819
# 2  2002     12            8,127,073                 2,405,204
# 3  2002  TOTAL           99,461,315                31,221,978
# 4  2003      1            8,152,502                 2,363,170
#
#   Total (Thousands)
# 0        11,098,974
# 1        10,425,340
# 2        10,532,277
# 3       130,683,293
# 4        10,515,672
#    Year  Month DOMESTIC INTERNATIONAL    TOTAL
# 0  2002     10   60,691         4,097   64,788
# 1  2002     11   57,316         3,822   61,138
# 2  2002     12   58,234         3,851   62,085
# 3  2002  TOTAL  771,371        51,890  823,261
# 4  2003      1   59,177         3,822   62,999
#    Year     Month Domestic Consumption\n(thousand gallons)  \
# 0  2012   January                                  115,997
# 1  2012  February                                  110,722
# 2  2012     March                                  130,412
# 3  2012     April                                  123,563
# 4  2012       May                                  127,988
#
#   Domestic Cost (thousand dollars) Domestic Cost per Gallon (Dollars)  \
# 0                          368,709                                  3
# 1                          359,564                                  3
# 2                          434,568                                  3
# 3                          423,220                                  3
# 4                          435,069                                  3
#
#   International Consumption\n(thousand gallons)  \
# 0                                       118,931
# 1                                       110,808
# 2                                       127,142
# 3                                       125,224
# 4                                       134,256
#
#   International Cost (thousand dollars)  \
# 0                               378,036
# 1                               359,841
# 2                               423,670
# 3                               428,908
# 4                               456,376
#
#   International Cost per Gallon (Dollars)  \
# 0                                       3
# 1                                       3
# 2                                       3
# 3                                       3
# 4                                       3
#
#   Total Consumption\n(thousand gallons) Total Cost (thousand dollars)  \
# 0                               234,928                       746,745
# 1                               221,530                       719,405
# 2                               257,554                       858,238
# 3                               248,787                       852,128
# 4                               262,245                       891,446
#
#   Total Cost per Gallon (Dollars)
# 0                            3.18
# 1                            3.25
# 2                            3.33
# 3                            3.43
# 4                             3.4
#    Year  Month  DOMESTIC  INTERNATIONAL  TOTAL
# 0  2002     10     70.86          72.20  71.19
# 1  2002     11     69.08          66.83  68.54
# 2  2002     12     75.88          71.27  74.83
# 3  2002  TOTAL     71.52          75.31  72.43
# 4  2003      1     66.25          67.95  66.63
#    Year Quarter Domestic (Thousands) Latin America (Thousands)  \
# 0  2000       1              274,235                    10,882
# 1  2000       2              426,971                     5,590
# 2  2000       3               21,392                     7,711
# 3  2000       4              -27,756                       116
# 4  2000   TOTAL              694,842                    24,299
#
#   Atlantic (Thousands) Pacific (Thousands)  International (Thousands)  \
# 0              -42,629             -10,024                        NaN
# 1               13,299             -11,372                        NaN
# 2               24,341               3,510                        NaN
# 3               -8,132              -1,671                        NaN
# 4              -13,121             -19,557                        0.0
#
#   Total (Thousands)
# 0           232,464
# 1           434,488
# 2            56,954
# 3           -37,443
# 4           686,463
#    Year Quarter Domestic (Thousands) Latin America (Thousands)  \
# 0  2000       1            3,012,104                   110,571
# 1  2000       2            3,239,904                   115,025
# 2  2000       3            3,142,200                   123,138
# 3  2000       4            3,012,894                   132,088
# 4  2000   TOTAL           12,407,102                   480,822
#
#   Atlantic (Thousands) Pacific (Thousands)  International (Thousands)  \
# 0              405,333              67,602                        NaN
# 1              554,970              63,557                        NaN
# 2              679,420              93,473                        NaN
# 3              492,586              75,985                        NaN
# 4            2,132,309             300,617                        0.0
#
#   Total (Thousands)
# 0         3,595,610
# 1         3,973,456
# 2         4,038,231
# 3         3,713,553
# 4        15,320,850
#    Year  Month    DOMESTIC INTERNATIONAL       TOTAL
# 0  2002     10   7,079,446       570,431   7,649,877
# 1  2002     11   6,612,595       502,136   7,114,731
# 2  2002     12   7,220,998       531,834   7,752,832
# 3  2002  TOTAL  83,700,730     7,019,169  90,719,899
# 4  2003      1   6,256,572       501,708   6,758,280
#    Year  Month Domestic (Thousands) International (Thousands)  \
# 0  2002     10            5,904,082                 1,997,636
# 1  2002     11            5,471,145                 1,674,572
# 2  2002     12            6,167,157                 1,714,144
# 3  2002  TOTAL           71,139,443                23,512,346
# 4  2003      1            5,401,199                 1,605,825
#
#   Total (Thousands)
# 0         7,901,718
# 1         7,145,717
# 2         7,881,300
# 3        94,651,789
# 4         7,007,024
#       timestamp    DAL  DAL_rolling_7_day_avg  DAL_rolling_14_day_avg  \
# 375  2018-04-02  51.95              54.082857               55.197143
# 376  2018-04-03  53.72              53.947143               54.992143
# 377  2018-04-04  53.86              53.941429               54.828571
# 378  2018-04-05  54.21              53.820000               54.676429
# 379  2018-04-06  53.67              53.735714               54.460714
#
#      DAL_rolling_30_day_avg  DAL_rolling_90_day_avg  DAL_7_days_ago  \
# 375               54.470667               54.640222           55.06
# 376               54.499667               54.683889           54.26
# 377               54.546000               54.719333           53.93
# 378               54.581000               54.761556           54.81
# 379               54.618333               54.801111             NaN
#
#      DAL_14_days_ago  DAL_30_days_ago  DAL_90_days_ago  DAL_log_price  \
# 375            55.96              NaN            56.74       3.950282
# 376            56.50              NaN            55.69       3.983785
# 377            55.95            53.79            55.69       3.986388
# 378            54.67            53.84            55.97       3.992865
# 379            53.90            53.53              NaN       3.982854
#
#      DAL_pct_change_7_days  DAL_pct_change_14_days  DAL_pct_change_30_days  \
# 375              -0.056484               -0.071658                     NaN
# 376              -0.009952               -0.049204                     NaN
# 377              -0.001298               -0.037355                0.001301
# 378              -0.010947               -0.008414                0.006872
# 379                    NaN               -0.004267                0.002615
#
#      DAL_pct_change_90_days
# 375               -0.084420
# 376               -0.035374
# 377               -0.032860
# 378               -0.031445
# 379                     NaN

# %%
# clean baggage

# dictionary to map quarters to their corresponding month and day
quarter_end_dates = {
    1: '03-31',
    2: '06-30',
    3: '09-30',
    4: '12-31'
}

# drop the total columns in order to convert to datetime. aggregation can easily replace total
dal_baggage_df = dal_baggage_df.loc[dal_baggage_df['Quarter'] != "TOTAL"].copy()

# convert quarter to numeric in order to use mapping 
dal_baggage_df['Quarter'] = pd.to_numeric(dal_baggage_df['Quarter'])

# convert to quarters, then resample to months
dal_baggage_df['date_str'] = dal_baggage_df['Year'].astype(str) + '-' + dal_baggage_df['Quarter'].map(quarter_end_dates)
dal_baggage_df['timestamp'] = pd.PeriodIndex(dal_baggage_df['date_str'], freq='Q')
dal_baggage_df.set_index('timestamp', inplace=True)
dal_baggage_df = dal_baggage_df.resample('M').ffill()


#drop placeholder date_str
dal_baggage_df.drop(columns=['date_str'], inplace=True)

# select the rows with dates corresponding to other data (October 2016-April 2018)
dal_baggage_df = dal_baggage_df.reset_index()
start_date = pd.Period('2016-10-01', freq = 'M')
end_date = pd.Period('2018-05-01', freq='M')
dal_baggage_df = dal_baggage_df.loc[(dal_baggage_df['timestamp'] >= start_date) & (dal_baggage_df['timestamp'] < end_date)]


# clean dtypes
dal_baggage_df['Total (Thousands)'] = dal_baggage_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# clean asm

# drop the total columns in order to convert to datetime. aggregation can easily replace total
dal_asm_df = dal_asm_df.loc[dal_asm_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
dal_asm_df['date_str'] = dal_asm_df['Year'].astype(str) + '-' + dal_asm_df['Month'].astype(str) + '-01'
dal_asm_df['timestamp'] = pd.to_datetime(dal_asm_df['date_str'])

# put time stamp as first column for clarity
dal_asm_df = dal_asm_df[['timestamp'] + [col for col in dal_asm_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
dal_asm_df['timestamp'] = dal_asm_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
dal_asm_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
dal_asm_df = dal_asm_df.loc[(dal_asm_df['timestamp'] >= start_date) & (dal_asm_df['timestamp'] < end_date)]

# convert dtypes
dal_asm_df['Domestic (Thousands)'] = dal_asm_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
dal_asm_df['International (Thousands)'] = dal_asm_df['International (Thousands)'].str.replace(",", "").astype(float)
dal_asm_df['Total (Thousands)'] = dal_asm_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# clean flight vol

# drop the total columns in order to convert to datetime. aggregation can easily replace total
dal_flight_vol_df = dal_flight_vol_df.loc[dal_flight_vol_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
dal_flight_vol_df['date_str'] = dal_flight_vol_df['Year'].astype(str) + '-' + dal_flight_vol_df['Month'].astype(str) + '-01'
dal_flight_vol_df['timestamp'] = pd.to_datetime(dal_flight_vol_df['date_str'])

# put time stamp as first column for clarity
dal_flight_vol_df = dal_flight_vol_df[['timestamp'] + [col for col in dal_flight_vol_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
dal_flight_vol_df['timestamp'] = dal_flight_vol_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
dal_flight_vol_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
dal_flight_vol_df = dal_flight_vol_df.loc[(dal_flight_vol_df['timestamp'] >= start_date) & (dal_flight_vol_df['timestamp'] < end_date)]

# clean dtypes
dal_flight_vol_df['DOMESTIC'] = dal_flight_vol_df['DOMESTIC'].str.replace(",", "").astype(float)
dal_flight_vol_df['INTERNATIONAL'] = dal_flight_vol_df['INTERNATIONAL'].str.replace(",", "").astype(float)
dal_flight_vol_df['TOTAL'] = dal_flight_vol_df['TOTAL'].str.replace(",", "").astype(float)

# %%
# clean fuel df 

dal_fuel_df.dtypes

month_name_to_number = {
    'January': 1,
    'February': 2,
    'March': 3,
    'April': 4,
    'May': 5,
    'June': 6,
    'July': 7,
    'August': 8,
    'September': 9,
    'October': 10,
    'November': 11,
    'December': 12
}

dal_fuel_df['Month'] = dal_fuel_df['Month'].astype(str)
dal_fuel_df = dal_fuel_df.loc[dal_fuel_df['Month'] != "nan"].copy()
dal_fuel_df['Month'] = dal_fuel_df['Month'].map(month_name_to_number)

# create datetime column to index compare to stock. 
dal_fuel_df['date_str'] = dal_fuel_df['Year'].astype(str) + '-' + dal_fuel_df['Month'].astype(str) + '-01'
dal_fuel_df['timestamp'] = pd.to_datetime(dal_fuel_df['date_str'])

# put time stamp as first column for clarity
dal_fuel_df = dal_fuel_df[['timestamp'] + [col for col in dal_fuel_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
dal_fuel_df['timestamp'] = dal_fuel_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
dal_fuel_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
dal_fuel_df = dal_fuel_df.loc[(dal_fuel_df['timestamp'] >= start_date) & (dal_fuel_df['timestamp'] < end_date)]

# clean dtypes
dal_fuel_df['Domestic Consumption\n(thousand gallons)'] = dal_fuel_df['Domestic Consumption\n(thousand gallons)'].str.replace(",", "").astype(float)
dal_fuel_df['Domestic Cost (thousand dollars)'] = dal_fuel_df['Domestic Cost (thousand dollars)'].str.replace(",", "").astype(float)
dal_fuel_df['Domestic Cost per Gallon (Dollars)'] = dal_fuel_df['Domestic Cost per Gallon (Dollars)'].str.replace(",", "").astype(float)
dal_fuel_df['International Consumption\n(thousand gallons)'] = dal_fuel_df['International Consumption\n(thousand gallons)'].str.replace(",", "").astype(float)
dal_fuel_df['International Cost (thousand dollars)'] = dal_fuel_df['International Cost (thousand dollars)'].str.replace(",", "").astype(float)
dal_fuel_df['International Cost per Gallon (Dollars)'] = dal_fuel_df['International Cost per Gallon (Dollars)'].str.replace(",", "").astype(float)
dal_fuel_df['Total Consumption\n(thousand gallons)'] = dal_fuel_df['Total Consumption\n(thousand gallons)'].str.replace(",", "").astype(float)
dal_fuel_df['Total Cost (thousand dollars)'] = dal_fuel_df['Total Cost (thousand dollars)'].str.replace(",", "").astype(float)
dal_fuel_df['Total Cost per Gallon (Dollars)'] = dal_fuel_df['Total Cost per Gallon (Dollars)'].str.replace(",", "").astype(float)

#rename certain columns
dal_fuel_df.rename(columns={'Domestic Consumption\n(thousand gallons)': 'Domestic Consumption (thousand gallons)'}, inplace=True)
dal_fuel_df.rename(columns={'International Consumption\n(thousand gallons)': 'International Consumption (thousand gallons)'}, inplace=True)
dal_fuel_df.rename(columns={'Total Consumption\n(thousand gallons)': 'Total Consumption (thousand gallons)'}, inplace=True)

# %%
# clean load factor 

# drop the total columns in order to convert to datetime. aggregation can easily replace total
dal_load_factor_df = dal_load_factor_df.loc[dal_load_factor_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
dal_load_factor_df['date_str'] = dal_load_factor_df['Year'].astype(str) + '-' + dal_load_factor_df['Month'].astype(str) + '-01'
dal_load_factor_df['timestamp'] = pd.to_datetime(dal_load_factor_df['date_str'])

# put time stamp as first column for clarity
dal_load_factor_df = dal_load_factor_df[['timestamp'] + [col for col in dal_load_factor_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
dal_load_factor_df['timestamp'] = dal_load_factor_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
dal_load_factor_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
dal_load_factor_df = dal_load_factor_df.loc[(dal_load_factor_df['timestamp'] >= start_date) & (dal_load_factor_df['timestamp'] < end_date)]

# dtypes came clean

# %%
# clean net income 

# dictionary to map quarters to their corresponding month and day
quarter_end_dates = {
    1: '03-31',
    2: '06-30',
    3: '09-30',
    4: '12-31'
}

# drop the total columns in order to convert to datetime. aggregation can easily replace total
dal_income_df = dal_income_df.loc[dal_income_df['Quarter'] != "TOTAL"].copy()

# convert quarter to numeric in order to use mapping 
dal_income_df['Quarter'] = pd.to_numeric(dal_income_df['Quarter'])

# convert to quarters, then resample to months
dal_income_df['date_str'] = dal_income_df['Year'].astype(str) + '-' + dal_income_df['Quarter'].map(quarter_end_dates)
dal_income_df['timestamp'] = pd.PeriodIndex(dal_income_df['date_str'], freq='Q')
dal_income_df.set_index('timestamp', inplace=True)
dal_income_df = dal_income_df.resample('M').ffill()

#drop placeholder date_str
dal_income_df.drop(columns=['date_str'], inplace=True)

# select the rows with dates corresponding to other data (October 2016-April 2018)
dal_income_df = dal_income_df.reset_index()
start_date = pd.Period('2016-10-01', freq = 'M')
end_date = pd.Period('2018-05-01', freq='M')
dal_income_df = dal_income_df.loc[(dal_income_df['timestamp'] >= start_date) & (dal_income_df['timestamp'] < end_date)]

# clean dtypes
dal_income_df['Domestic (Thousands)'] = dal_income_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
dal_income_df['Latin America (Thousands)'] = dal_income_df['Latin America (Thousands)'].str.replace(",", "").astype(float)
dal_income_df['Total (Thousands)'] = dal_income_df['Total (Thousands)'].str.replace(",", "").astype(float)

# dtypes came clean
display(dal_income_df)
# Out:
#     timestamp  Year  Quarter  Domestic (Thousands)  Latin America (Thousands)  \
# 201   2016-10  2016        4              469594.0                    12942.0
# 202   2016-11  2016        4              469594.0                    12942.0
# 203   2016-12  2016        4              469594.0                    12942.0
# 204   2017-01  2017        1              436046.0                    20744.0
# 205   2017-02  2017        1              436046.0                    20744.0
# 206   2017-03  2017        1              436046.0                    20744.0
# 207   2017-04  2017        2              889627.0                    51561.0
# 208   2017-05  2017        2              889627.0                    51561.0
# 209   2017-06  2017        2              889627.0                    51561.0
# 210   2017-07  2017        3              715427.0                    72736.0
# 211   2017-08  2017        3              715427.0                    72736.0
# 212   2017-09  2017        3              715427.0                    72736.0
# 213   2017-10  2017        4              425920.0                    14911.0
# 214   2017-11  2017        4              425920.0                    14911.0
# 215   2017-12  2017        4              425920.0                    14911.0
# 216   2018-01  2018        1              325483.0                    49136.0
# 217   2018-02  2018        1              325483.0                    49136.0
# 218   2018-03  2018        1              325483.0                    49136.0
# 219   2018-04  2018        2              547392.0                    65434.0
#
#     Atlantic (Thousands) Pacific (Thousands)  International (Thousands)  \
# 201              119,041              31,270                        NaN
# 202              119,041              31,270                        NaN
# 203              119,041              31,270                        NaN
# 204              110,446              48,677                        NaN
# 205              110,446              48,677                        NaN
# 206              110,446              48,677                        NaN
# 207              241,328              52,997                        NaN
# 208              241,328              52,997                        NaN
# 209              241,328              52,997                        NaN
# 210              304,635              98,600                        NaN
# 211              304,635              98,600                        NaN
# 212              304,635              98,600                        NaN
# 213              127,255              23,460                        NaN
# 214              127,255              23,460                        NaN
# 215              127,255              23,460                        NaN
# 216              159,206              50,030                        NaN
# 217              159,206              50,030                        NaN
# 218              159,206              50,030                        NaN
# 219              324,665              80,251                        NaN
#
#      Total (Thousands)
# 201           632847.0
# 202           632847.0
# 203           632847.0
# 204           615913.0
# 205           615913.0
# 206           615913.0
# 207          1235513.0
# 208          1235513.0
# 209          1235513.0
# 210          1191398.0
# 211          1191398.0
# 212          1191398.0
# 213           591546.0
# 214           591546.0
# 215           591546.0
# 216           583855.0
# 217           583855.0
# 218           583855.0
# 219          1017742.0

# %%
# clean operating revenue

# drop the total columns in order to convert to datetime. aggregation can easily replace total
dal_operating_revenue_df = dal_operating_revenue_df.loc[dal_operating_revenue_df['Quarter'] != "TOTAL"].copy()

# convert quarter to numeric in order to use mapping 
dal_operating_revenue_df['Quarter'] = pd.to_numeric(dal_operating_revenue_df['Quarter'])

# convert to quarters, then resample to months
dal_operating_revenue_df['date_str'] = dal_operating_revenue_df['Year'].astype(str) + '-' + dal_operating_revenue_df['Quarter'].map(quarter_end_dates)
dal_operating_revenue_df['timestamp'] = pd.PeriodIndex(dal_operating_revenue_df['date_str'], freq='Q')
dal_operating_revenue_df.set_index('timestamp', inplace=True)
dal_operating_revenue_df = dal_operating_revenue_df.resample('M').ffill()

#drop placeholder date_str
dal_operating_revenue_df.drop(columns=['date_str'], inplace=True)

# select the rows with dates corresponding to other data (October 2016-April 2018)
dal_operating_revenue_df = dal_operating_revenue_df.reset_index()
start_date = pd.Period('2016-10-01', freq = 'M')
end_date = pd.Period('2018-05-01', freq='M')
dal_operating_revenue_df = dal_operating_revenue_df.loc[(dal_operating_revenue_df['timestamp'] >= start_date) & (dal_operating_revenue_df['timestamp'] < end_date)]

dal_operating_revenue_df['Domestic (Thousands)'] = dal_operating_revenue_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
dal_operating_revenue_df['Latin America (Thousands)'] = dal_operating_revenue_df['Latin America (Thousands)'].str.replace(",", "").astype(float)
dal_operating_revenue_df['Atlantic (Thousands)'] = dal_operating_revenue_df['Atlantic (Thousands)'].str.replace(",", "").astype(float)
dal_operating_revenue_df['Pacific (Thousands)'] = dal_operating_revenue_df['Pacific (Thousands)'].str.replace(",", "").astype(float)
dal_operating_revenue_df['Total (Thousands)'] = dal_operating_revenue_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# clean passenger volume df

# drop the total columns in order to convert to datetime. aggregation can easily replace total
dal_passenger_vol_df = dal_passenger_vol_df.loc[dal_passenger_vol_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
dal_passenger_vol_df['date_str'] = dal_passenger_vol_df['Year'].astype(str) + '-' + dal_passenger_vol_df['Month'].astype(str) + '-01'
dal_passenger_vol_df['timestamp'] = pd.to_datetime(dal_passenger_vol_df['date_str'])

# put time stamp as first column for clarity
dal_passenger_vol_df = dal_passenger_vol_df[['timestamp'] + [col for col in dal_passenger_vol_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
dal_passenger_vol_df['timestamp'] = dal_passenger_vol_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
dal_passenger_vol_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
dal_passenger_vol_df = dal_passenger_vol_df.loc[(dal_passenger_vol_df['timestamp'] >= start_date) & (dal_passenger_vol_df['timestamp'] < end_date)]

# clean dtypes
dal_passenger_vol_df['DOMESTIC'] = dal_passenger_vol_df['DOMESTIC'].str.replace(",", "").astype(float)
dal_passenger_vol_df['INTERNATIONAL'] = dal_passenger_vol_df['INTERNATIONAL'].str.replace(",", "").astype(float)
dal_passenger_vol_df['TOTAL'] = dal_passenger_vol_df['TOTAL'].str.replace(",", "").astype(float)

# %%
# clean rpm df 

# drop the total columns in order to convert to datetime. aggregation can easily replace total
dal_rpm_df = dal_rpm_df.loc[dal_rpm_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
dal_rpm_df['date_str'] = dal_rpm_df['Year'].astype(str) + '-' + dal_rpm_df['Month'].astype(str) + '-01'
dal_rpm_df['timestamp'] = pd.to_datetime(dal_rpm_df['date_str'])

# put time stamp as first column for clarity
dal_rpm_df = dal_rpm_df[['timestamp'] + [col for col in dal_rpm_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
dal_rpm_df['timestamp'] = dal_rpm_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
dal_rpm_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
dal_rpm_df = dal_rpm_df.loc[(dal_rpm_df['timestamp'] >= start_date) & (dal_rpm_df['timestamp'] < end_date)]

# clean dtypes
dal_rpm_df['Domestic (Thousands)'] = dal_rpm_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
dal_rpm_df['International (Thousands)'] = dal_rpm_df['International (Thousands)'].str.replace(",", "").astype(float)
dal_rpm_df['Total (Thousands)'] = dal_rpm_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# dal stock dtype clean
dal_stock_df['timestamp'] = pd.to_datetime(dal_stock_df['timestamp'])

# %%
display(dal_asm_df.head())
display(dal_flight_vol_df.head())
display(dal_fuel_df.head())
display(dal_load_factor_df.head())
display(dal_income_df.head())
display(dal_operating_revenue_df.head())
display(dal_passenger_vol_df.head())
display(dal_rpm_df.head())
display(dal_baggage_df.head())
display(dal_stock_df.tail())
# Out:
#      timestamp  Year Month  Domestic (Thousands)  International (Thousands)  \
# 182 2016-10-31  2016    10            10603987.0                  7542379.0
# 183 2016-11-30  2016    11            10037897.0                  6046956.0
# 184 2016-12-31  2016    12            10377364.0                  6945446.0
# 186 2017-01-31  2017     1             9913916.0                  7040032.0
# 187 2017-02-28  2017     2             9237384.0                  6111291.0
#
#      Total (Thousands)
# 182         18146366.0
# 183         16084854.0
# 184         17322809.0
# 186         16953948.0
# 187         15348675.0
#      timestamp  Year Month  DOMESTIC  INTERNATIONAL    TOTAL
# 182 2016-10-31  2016    10   78599.0        10312.0  88911.0
# 183 2016-11-30  2016    11   74194.0         9061.0  83255.0
# 184 2016-12-31  2016    12   71642.0        11509.0  83151.0
# 186 2017-01-31  2017     1   69354.0        12069.0  81423.0
# 187 2017-02-28  2017     2   65129.0        10496.0  75625.0
#     timestamp  Year  Month  Domestic Consumption (thousand gallons)  \
# 65 2016-10-31  2016     10                                 162455.0
# 66 2016-11-30  2016     11                                 154389.0
# 67 2016-12-31  2016     12                                 161053.0
# 70 2017-01-31  2017      1                                 152284.0
# 71 2017-02-28  2017      2                                 141387.0
#
#     Domestic Cost (thousand dollars)  Domestic Cost per Gallon (Dollars)  \
# 65                          278374.0                                 2.0
# 66                          241917.0                                 2.0
# 67                          263321.0                                 2.0
# 70                          254461.0                                 2.0
# 71                          254906.0                                 2.0
#
#     International Consumption (thousand gallons)  \
# 65                                      116202.0
# 66                                       92210.0
# 67                                      105657.0
# 70                                      105903.0
# 71                                       91207.0
#
#     International Cost (thousand dollars)  \
# 65                               198363.0
# 66                               143989.0
# 67                               172011.0
# 70                               176244.0
# 71                               163806.0
#
#     International Cost per Gallon (Dollars)  \
# 65                                      2.0
# 66                                      2.0
# 67                                      2.0
# 70                                      2.0
# 71                                      2.0
#
#     Total Consumption (thousand gallons)  Total Cost (thousand dollars)  \
# 65                              278657.0                       476737.0
# 66                              246598.0                       385905.0
# 67                              266709.0                       435332.0
# 70                              258187.0                       430705.0
# 71                              232594.0                       418712.0
#
#     Total Cost per Gallon (Dollars)
# 65                             1.71
# 66                             1.56
# 67                             1.63
# 70                             1.67
# 71                             1.80
#      timestamp  Year Month  DOMESTIC  INTERNATIONAL  TOTAL
# 182 2016-10-31  2016    10     88.14          82.36  85.74
# 183 2016-11-30  2016    11     88.14          81.16  85.52
# 184 2016-12-31  2016    12     86.88          84.28  85.84
# 186 2017-01-31  2017     1     82.67          81.72  82.27
# 187 2017-02-28  2017     2     83.79          79.17  81.95
#     timestamp  Year  Quarter  Domestic (Thousands)  Latin America (Thousands)  \
# 201   2016-10  2016        4              469594.0                    12942.0
# 202   2016-11  2016        4              469594.0                    12942.0
# 203   2016-12  2016        4              469594.0                    12942.0
# 204   2017-01  2017        1              436046.0                    20744.0
# 205   2017-02  2017        1              436046.0                    20744.0
#
#     Atlantic (Thousands) Pacific (Thousands)  International (Thousands)  \
# 201              119,041              31,270                        NaN
# 202              119,041              31,270                        NaN
# 203              119,041              31,270                        NaN
# 204              110,446              48,677                        NaN
# 205              110,446              48,677                        NaN
#
#      Total (Thousands)
# 201           632847.0
# 202           632847.0
# 203           632847.0
# 204           615913.0
# 205           615913.0
#     timestamp  Year  Quarter  Domestic (Thousands)  Latin America (Thousands)  \
# 201   2016-10  2016        4             6963690.0                   609625.0
# 202   2016-11  2016        4             6963690.0                   609625.0
# 203   2016-12  2016        4             6963690.0                   609625.0
# 204   2017-01  2017        1             6701934.0                   784483.0
# 205   2017-02  2017        1             6701934.0                   784483.0
#
#      Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 201             1275429.0             662359.0                        NaN
# 202             1275429.0             662359.0                        NaN
# 203             1275429.0             662359.0                        NaN
# 204             1056823.0             652839.0                        NaN
# 205             1056823.0             652839.0                        NaN
#
#      Total (Thousands)
# 201          9511103.0
# 202          9511103.0
# 203          9511103.0
# 204          9196079.0
# 205          9196079.0
#      timestamp  Year Month    DOMESTIC  INTERNATIONAL       TOTAL
# 182 2016-10-31  2016    10  10384814.0      1741881.0  12126695.0
# 183 2016-11-30  2016    11   9858408.0      1459191.0  11317599.0
# 184 2016-12-31  2016    12   9373077.0      1838715.0  11211792.0
# 186 2017-01-31  2017     1   8526218.0      1870711.0  10396929.0
# 187 2017-02-28  2017     2   8243904.0      1611400.0   9855304.0
#      timestamp  Year Month  Domestic (Thousands)  International (Thousands)  \
# 182 2016-10-31  2016    10             9346211.0                  6211653.0
# 183 2016-11-30  2016    11             8847710.0                  4907438.0
# 184 2016-12-31  2016    12             9016191.0                  5853457.0
# 186 2017-01-31  2017     1             8195822.0                  5752770.0
# 187 2017-02-28  2017     2             7740279.0                  4838045.0
#
#      Total (Thousands)
# 182         15557864.0
# 183         13755148.0
# 184         14869648.0
# 186         13948592.0
# 187         12578323.0
#    timestamp  Year  Quarter  Total (Thousands)
# 9    2016-10  2016        4           213297.0
# 10   2016-11  2016        4           213297.0
# 11   2016-12  2016        4           213297.0
# 12   2017-01  2017        1           203507.0
# 13   2017-02  2017        1           203507.0
#      timestamp    DAL  DAL_rolling_7_day_avg  DAL_rolling_14_day_avg  \
# 375 2018-04-02  51.95              54.082857               55.197143
# 376 2018-04-03  53.72              53.947143               54.992143
# 377 2018-04-04  53.86              53.941429               54.828571
# 378 2018-04-05  54.21              53.820000               54.676429
# 379 2018-04-06  53.67              53.735714               54.460714
#
#      DAL_rolling_30_day_avg  DAL_rolling_90_day_avg  DAL_7_days_ago  \
# 375               54.470667               54.640222           55.06
# 376               54.499667               54.683889           54.26
# 377               54.546000               54.719333           53.93
# 378               54.581000               54.761556           54.81
# 379               54.618333               54.801111             NaN
#
#      DAL_14_days_ago  DAL_30_days_ago  DAL_90_days_ago  DAL_log_price  \
# 375            55.96              NaN            56.74       3.950282
# 376            56.50              NaN            55.69       3.983785
# 377            55.95            53.79            55.69       3.986388
# 378            54.67            53.84            55.97       3.992865
# 379            53.90            53.53              NaN       3.982854
#
#      DAL_pct_change_7_days  DAL_pct_change_14_days  DAL_pct_change_30_days  \
# 375              -0.056484               -0.071658                     NaN
# 376              -0.009952               -0.049204                     NaN
# 377              -0.001298               -0.037355                0.001301
# 378              -0.010947               -0.008414                0.006872
# 379                    NaN               -0.004267                0.002615
#
#      DAL_pct_change_90_days
# 375               -0.084420
# 376               -0.035374
# 377               -0.032860
# 378               -0.031445
# 379                     NaN

# %%
dal_asm_df.dtypes
# Out:
# timestamp                    datetime64[ns]
# Year                                  int64
# Month                                object
# Domestic (Thousands)                float64
# International (Thousands)           float64
# Total (Thousands)                   float64
# dtype: object

# %%
dal_flight_vol_df.dtypes
# Out:
# timestamp        datetime64[ns]
# Year                      int64
# Month                    object
# DOMESTIC                float64
# INTERNATIONAL           float64
# TOTAL                   float64
# dtype: object

# %%
dal_fuel_df.dtypes
# Out:
# timestamp                                       datetime64[ns]
# Year                                                    object
# Month                                                    int64
# Domestic Consumption (thousand gallons)                float64
# Domestic Cost (thousand dollars)                       float64
# Domestic Cost per Gallon (Dollars)                     float64
# International Consumption (thousand gallons)           float64
# International Cost (thousand dollars)                  float64
# International Cost per Gallon (Dollars)                float64
# Total Consumption (thousand gallons)                   float64
# Total Cost (thousand dollars)                          float64
# Total Cost per Gallon (Dollars)                        float64
# dtype: object

# %%
dal_load_factor_df.dtypes
# Out:
# timestamp        datetime64[ns]
# Year                      int64
# Month                    object
# DOMESTIC                float64
# INTERNATIONAL           float64
# TOTAL                   float64
# dtype: object

# %%
dal_income_df.dtypes
# Out:
# timestamp                    period[M]
# Year                             int64
# Quarter                          int64
# Domestic (Thousands)           float64
# Latin America (Thousands)      float64
# Atlantic (Thousands)            object
# Pacific (Thousands)             object
# International (Thousands)      float64
# Total (Thousands)              float64
# dtype: object

# %%
dal_operating_revenue_df.dtypes
# Out:
# timestamp                    period[M]
# Year                             int64
# Quarter                          int64
# Domestic (Thousands)           float64
# Latin America (Thousands)      float64
# Atlantic (Thousands)           float64
# Pacific (Thousands)            float64
# International (Thousands)      float64
# Total (Thousands)              float64
# dtype: object

# %%
dal_passenger_vol_df.dtypes
# Out:
# timestamp        datetime64[ns]
# Year                      int64
# Month                    object
# DOMESTIC                float64
# INTERNATIONAL           float64
# TOTAL                   float64
# dtype: object

# %%
dal_rpm_df.dtypes
# Out:
# timestamp                    datetime64[ns]
# Year                                  int64
# Month                                object
# Domestic (Thousands)                float64
# International (Thousands)           float64
# Total (Thousands)                   float64
# dtype: object

# %%
dal_baggage_df.dtypes
# Out:
# timestamp            period[M]
# Year                     int64
# Quarter                  int64
# Total (Thousands)      float64
# dtype: object

# %%
dal_stock_df.dtypes
# Out:
# timestamp                 datetime64[ns]
# DAL                              float64
# DAL_rolling_7_day_avg            float64
# DAL_rolling_14_day_avg           float64
# DAL_rolling_30_day_avg           float64
# DAL_rolling_90_day_avg           float64
# DAL_7_days_ago                   float64
# DAL_14_days_ago                  float64
# DAL_30_days_ago                  float64
# DAL_90_days_ago                  float64
# DAL_log_price                    float64
# DAL_pct_change_7_days            float64
# DAL_pct_change_14_days           float64
# DAL_pct_change_30_days           float64
# DAL_pct_change_90_days           float64
# dtype: object

# %% [markdown]
# # Analysis

# %%
avail_seat_miles = dal_asm_df
baggage_fees = dal_baggage_df
fuel = dal_fuel_df
load_factor = dal_load_factor_df
net_income = dal_income_df
operating_revenue = dal_operating_revenue_df
passengers = dal_passenger_vol_df
revenue_passenger_miles = dal_rpm_df
flights = dal_flight_vol_df




prices = dal_stock_df[dal_stock_df['timestamp'].dt.day < 4]
prices = prices[['timestamp','DAL']]
prices.set_index('timestamp',inplace = True)
price = prices.resample('M').mean()
price = price.values
p = []
for i in range(len(price)):
    p.append(price[i][0])
price = numpy.array(p)

# %% [markdown]
# Correlation/Plots for Available Seat Miles

# %%
# time series plots for domestic, intl, and total asm
avail_seat_miles.set_index('timestamp', inplace = True)
avail_seat_miles['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Available Seat Miles (Thousands)')
plt.title('Time Series of Total Available Seat Miles')
plt.grid(True)
plt.show()

avail_seat_miles['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Available Seat Miles (Thousands)')
plt.title('Time Series of Domestic Available Seat Miles')
plt.grid(True)
plt.show()

avail_seat_miles['International (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Available Seat Miles (Thousands)')
plt.title('Time Series of International Available Seat Miles')
plt.grid(True)
plt.show()

# %%
# available seat miles versus stock price plots
total = avail_seat_miles['Total (Thousands)'].values
domestic = avail_seat_miles['Domestic (Thousands)'].values
intl = avail_seat_miles['International (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Available Seat Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Available Seat Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('International Available Seat Miles vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients for asm

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Available Seat Miles to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Available Seat Miles to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Available Seat Miles to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Available Seat Miles to Stock Price is :0.21412377740697902
# The correlation coefficent for Domestic Available Seat Miles to Stock Price is :0.26612091974631347
# The correlation coefficent for International Available Seat Miles to Stock Price is :0.15425957547531927

# %% [markdown]
# Correlation/Plots for Baggage Fees

# %%
# time series plot of baggage fees
baggage_fees.set_index('timestamp', inplace = True)
baggage_fees['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Total Fees ($Thousands)')
plt.title('Time Series of Total Baggage Fees')
plt.grid(True)
plt.show()

# %%
# available seat miles versus stock price plots
fees = baggage_fees['Total (Thousands)'].values


plt.scatter(fees, price)
plt.xlabel('Baggage Fees ($Thousands)')
plt.ylabel('Stock Price')
plt.title('Baggage Fees vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficient for baggage fees

fee_r = numpy.corrcoef(fees,price)[0,1]
print("The correlation coefficent for Baggage Fees to Stock Price is :" + str(total_r))
# Out:
# The correlation coefficent for Baggage Fees to Stock Price is :0.21412377740697902

# %% [markdown]
# Correlation/Plots for Fuel

# %%
# time series plots for domestic, intl, and total fuel
fuel.set_index('timestamp', inplace = True)
fuel['Domestic Consumption (thousand gallons)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Consumption (thousand gallons)')
plt.title('Time Series of Domestic Fuel Consumption')
plt.grid(True)
plt.show()

fuel['International Consumption (thousand gallons)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Consumption (thousand gallons)')
plt.title('Time Series of International Fuel Consumption')
plt.grid(True)
plt.show()

fuel['Total Consumption (thousand gallons)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Consumption (thousand gallons)')
plt.title('Time Series of Total Consumption')
plt.grid(True)
plt.show()

fuel['Domestic Cost (thousand dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Cost (thousand dollars)')
plt.title('Time Series of Domestic Fuel Cost')
plt.grid(True)
plt.show()

fuel['International Cost (thousand dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Cost (thousand dollars)')
plt.title('Time Series of International Fuel Cost')
plt.grid(True)
plt.show()

fuel['Total Cost (thousand dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Cost (thousand dollars)')
plt.title('Time Series of Total Fuel Cost')
plt.grid(True)
plt.show()

fuel['Domestic Cost per Gallon (Dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Cost per Gallon (Dollars)')
plt.title('Time Series of Domestic Cost per Gallon')
plt.grid(True)
plt.show()

fuel['International Cost per Gallon (Dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Cost per Gallon (Dollars)')
plt.title('Time Series of International Cost per Gallon')
plt.grid(True)
plt.show()

fuel['Total Cost per Gallon (Dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Cost per Gallon (Dollars)')
plt.title('Time Series of Cost per Gallon')
plt.grid(True)
plt.show()

# %%
# fuel versus stock price plots
total_consumption = fuel['Total Consumption (thousand gallons)'].values
domestic_consumption = fuel['Domestic Consumption (thousand gallons)'].values
intl_consumption = fuel['International Consumption (thousand gallons)'].values
total_cost =fuel['Total Cost (thousand dollars)'].values
domestic_cost = fuel['Domestic Cost (thousand dollars)'].values
intl_cost =fuel['International Cost (thousand dollars)'].values
total_cpg = fuel['Total Cost per Gallon (Dollars)'].values
domestic_cpg =fuel['Domestic Cost per Gallon (Dollars)'].values
intl_cpg =fuel['International Cost per Gallon (Dollars)'].values


plt.figure()
plt.scatter(total_consumption, price)
plt.xlabel('Consumption (thousand gallons)')
plt.ylabel('Stock Price')
plt.title('Total Fuel Consumption (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic_consumption, price)
plt.xlabel('Consumption (thousand gallons)')
plt.ylabel('Stock Price')
plt.title('Domestic Fuel Consumption (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl_consumption, price)
plt.xlabel('Consumption (thousand gallons)')
plt.ylabel('Stock Price')
plt.title('International Fuel Consumption (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(total_cost, price)
plt.xlabel('Cost (thousand dollars)')
plt.ylabel('Stock Price')
plt.title('Total Fuel Cost (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic_cost, price)
plt.xlabel('Cost (thousand dollars)')
plt.ylabel('Stock Price')
plt.title('Domestic Fuel Cost (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl_cost, price)
plt.xlabel('Cost (thousand dollars)')
plt.ylabel('Stock Price')
plt.title('International Fuel Cost (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(total_cpg, price)
plt.xlabel('Cost per Gallon (Dollars)')
plt.ylabel('Stock Price')
plt.title('Total Fuel Cost per Gallon (Dollars) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic_cpg, price)
plt.xlabel('Cost per Gallon (Dollars)')
plt.ylabel('Stock Price')
plt.title('Domestic Fuel Cost per Gallon (Dollars) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl_cpg, price)
plt.xlabel('Cost per Gallon (Dollars)')
plt.ylabel('Stock Price')
plt.title('International Fuel Cost per Gallon (Dollars) vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients for fuel

r1 = numpy.corrcoef(total_consumption, price)[0,1]
print("The correlation coefficent for Total Fuel Consumption (thousand gallons) vs Stock Price is :" + str(r1))
r2 = numpy.corrcoef(domestic_consumption ,price)[0,1]
print("The correlation coefficent for Domestic Fuel Consumption (thousand gallons) vs Stock Price is :" + str(r2))
r3 = numpy.corrcoef(intl_consumption,price)[0,1]
print("The correlation coefficent for International Fuel Consumption (thousand gallons) vs Stock Price is:" + str(r3))

r4 = numpy.corrcoef(total_cost, price)[0,1]
print("The correlation coefficent for Total Fuel Cost (thousand gallons) vs Stock Price is:" + str(r4))
r5 = numpy.corrcoef(domestic_cost ,price)[0,1]
print("The correlation coefficent for Domestic Fuel Cost (thousand gallons) vs Stock Price :" + str(r5))
r6 = numpy.corrcoef(intl_cost,price)[0,1]
print("The correlation coefficent for International Fuel Cost (thousand gallons) vs Stock Price:" + str(r6))

r7 = numpy.corrcoef(total_cpg, price)[0,1]
print("The correlation coefficent for Total Fuel Cost per Gallon (Dollars) vs Stock Price :" + str(r7))
r8 = numpy.corrcoef(domestic_cpg ,price)[0,1]
print("The correlation coefficent for Domestic Fuel Cost per Gallon (Dollars) vs Stock Price :" + str(r8))
r9 = numpy.corrcoef(intl_cpg,price)[0,1]
print("The correlation coefficent for International Fuel Cost per Gallon (Dollars) vs Stock Price :" + str(r9))
# Out:
# The correlation coefficent for Total Fuel Consumption (thousand gallons) vs Stock Price is :0.17546273368110205
# The correlation coefficent for Domestic Fuel Consumption (thousand gallons) vs Stock Price is :0.2619263910202641
# The correlation coefficent for International Fuel Consumption (thousand gallons) vs Stock Price is:0.08907939991601452
# The correlation coefficent for Total Fuel Cost (thousand gallons) vs Stock Price is:0.6339162531331511
# The correlation coefficent for Domestic Fuel Cost (thousand gallons) vs Stock Price :0.6826950087258937
# The correlation coefficent for International Fuel Cost (thousand gallons) vs Stock Price:0.4875436773587462
# The correlation coefficent for Total Fuel Cost per Gallon (Dollars) vs Stock Price :0.6011219079698538
# The correlation coefficent for Domestic Fuel Cost per Gallon (Dollars) vs Stock Price :nan
# The correlation coefficent for International Fuel Cost per Gallon (Dollars) vs Stock Price :nan
# /Users/liamoshaughnessy/anaconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/liamoshaughnessy/anaconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %% [markdown]
# Correlation/Plots for Load Factor

# %%
# time series plots for domestic, intl, and total load factor
load_factor.set_index('timestamp', inplace = True)
load_factor['DOMESTIC'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Load Factor')
plt.title('Time Series of Domestic Load Factor')
plt.grid(True)
plt.show()

load_factor['INTERNATIONAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Load Factor')
plt.title('Time Series of International Load Factor')
plt.grid(True)
plt.show()

load_factor['TOTAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Load Factor')
plt.title('Time Series of Total Load Factor')
plt.grid(True)
plt.show()

# %%
# load factor versus stock price plots
total = load_factor['TOTAL'].values
domestic = load_factor['DOMESTIC'].values
intl = load_factor['INTERNATIONAL'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Load Factor')
plt.ylabel('Stock Price')
plt.title('Total Load Factor vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Load Factor')
plt.ylabel('Stock Price')
plt.title('Domestic Load Factor vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Load Factor')
plt.ylabel('Stock Price')
plt.title('International Load Factor vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients
total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Load Factor to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Load Factor to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Load Factor to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Load Factor to Stock Price is :-0.12734415107874567
# The correlation coefficent for Domestic Load Factor to Stock Price is :-0.3541534098249245
# The correlation coefficent for International Load Factor to Stock Price is :0.17566161028626537

# %% [markdown]
# Correlation/Plots for Net Income

# %%
# time series plots for domestic and total net income
net_income.set_index('timestamp', inplace = True)
net_income['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Net Income (Thousands)')
plt.title('Time Series of Domestic Net Income')
plt.grid(True)
plt.show()

net_income['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Net Income (Thousands)')
plt.title('Time Series of Total Net Income')
plt.grid(True)
plt.show()

# %%
# net income versus stock price plots
total = net_income['Domestic (Thousands)'].values
domestic = net_income['Total (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Net Income (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Net Income vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Net Income (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Net Income vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Net Income to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Net Income to Stock Price is :" + str(domestic_r))
# Out:
# The correlation coefficent for Total Net Income to Stock Price is :-0.24027838233053592
# The correlation coefficent for Domestic Net Income to Stock Price is :-0.04538213923583174

# %% [markdown]
# Correlation/Plots for Operating Revenue

# %%
# time series plots for domestic and total operating revenue
operating_revenue.set_index('timestamp', inplace = True)
operating_revenue['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Operating Revenue (Thousands)')
plt.title('Time Series of Total Operating Revenue')
plt.grid(True)
plt.show()


avail_seat_miles['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Operating Revenue (Thousands)')
plt.title('Time Series of Domestic Operating Revenue')
plt.grid(True)
plt.show()

# %%
# operating revenue versus stock price plots
total = operating_revenue['Total (Thousands)'].values
domestic = operating_revenue['Domestic (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Operating Revenue (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Operating Revenue vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Operating Revenue (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Operating Revenue vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Operating Revenue to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Operating Revenue to Stock Price is :" + str(domestic_r))
# Out:
# The correlation coefficent for Total Operating Revenue to Stock Price is :0.2822866798807896
# The correlation coefficent for Domestic Operating Revenue to Stock Price is :0.24783175099416707

# %% [markdown]
# Correlations/Plots for Passengers

# %%
# time series plots for domestic, intl, and total passengers
passengers.set_index('timestamp', inplace = True)
passengers['TOTAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.title('Time Series of Total Passengers')
plt.grid(True)
plt.show()

passengers['DOMESTIC'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.title('Time Series of Domestic Passengers')
plt.grid(True)
plt.show()

passengers['INTERNATIONAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.title('Time Series of International Passengers')
plt.grid(True)
plt.show()

# %%
# passengers versus stock price plots
total = passengers['TOTAL'].values
domestic = passengers['DOMESTIC'].values
intl = passengers['INTERNATIONAL'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Passengers')
plt.ylabel('Stock Price')
plt.title('Total Passengers vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Passengers')
plt.ylabel('Stock Price')
plt.title('Domestic Passengers vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Passengers')
plt.ylabel('Stock Price')
plt.title('International Passengers vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Passengers to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Passengers to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Passengers to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Passengers to Stock Price is :0.04056653461957584
# The correlation coefficent for Domestic Passengers to Stock Price is :-0.060757631836411495
# The correlation coefficent for International Passengers to Stock Price is :0.3628582596805342

# %% [markdown]
# Correlations/Plots for Revenue Passenger-Miles

# %%
# time series plots for domestic, intl, and total rpm
revenue_passenger_miles.set_index('timestamp', inplace = True)
revenue_passenger_miles['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Revenue Passenger-Miles (Thousands)')
plt.title('Time Series of Total Revenue Passenger-Miles')
plt.grid(True)
plt.show()

revenue_passenger_miles['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Revenue Passenger-Miles (Thousands)')
plt.title('Time Series of Domestic Revenue Passenger-Miles')
plt.grid(True)
plt.show()

revenue_passenger_miles['International (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Revenue Passenger-Miles (Thousands)')
plt.title('Time Series of International Revenue Passenger-Miles')
plt.grid(True)
plt.show()

# %%
# revenue passenger miles versus stock price plots
total = revenue_passenger_miles['Total (Thousands)'].values
domestic = revenue_passenger_miles['Domestic (Thousands)'].values
intl = revenue_passenger_miles['International (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Revenue Passenger Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Revenue Passenger Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Revenue Passenger Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Revenue Passenger Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('International Revenue Passenger Miles vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients for rpm

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Revenue Passenger Miles to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Revenue Passenger Miless to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Revenue Passenger Miles to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Revenue Passenger Miles to Stock Price is :0.155541968276285
# The correlation coefficent for Domestic Revenue Passenger Miless to Stock Price is :0.13305875328883857
# The correlation coefficent for International Revenue Passenger Miles to Stock Price is :0.164392572190762

# %% [markdown]
# Correlations/Plots for Flights

# %%
# time series plots for domestic, intl, and total flights
flights.set_index('timestamp', inplace = True)
flights['TOTAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Flights')
plt.title('Time Series of Total Flights')
plt.grid(True)
plt.show()

flights['DOMESTIC'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Flights')
plt.title('Time Series of Domestic Flights')
plt.grid(True)
plt.show()

flights['INTERNATIONAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Flights')
plt.title('Time Series of International Flights')
plt.grid(True)
plt.show()

# %%
# flights versus stock price plots
total = flights['TOTAL'].values
domestic = flights['DOMESTIC'].values
intl = flights['INTERNATIONAL'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('# of Flights')
plt.ylabel('Stock Price')
plt.title('Total # of Flights vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('# of Flights')
plt.ylabel('Stock Price')
plt.title('Domestic # of Flights vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('# of Flights')
plt.ylabel('Stock Price')
plt.title('International # of Flights vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total # of Flights to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic # of Flights to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International # of Flights to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total # of Flights to Stock Price is :0.06867492204568625
# The correlation coefficent for Domestic # of Flights to Stock Price is :-0.0428226478968328
# The correlation coefficent for International # of Flights to Stock Price is :0.5356662960771917
