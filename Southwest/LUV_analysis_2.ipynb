# %% [markdown]
# # LUV Clean

# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 300)

luv_asm_df = pd.read_csv('Available Seat-Miles - All Airports - Southwest.csv')
luv_flight_vol_df = pd.read_csv('Flights - All Airports - Southwest.csv')
luv_fuel_df = pd.read_csv('Fuel - All Service - Southwest.csv')
luv_load_factor_df = pd.read_csv('Load Factor - All Airports - Southwest.csv')
luv_income_df = pd.read_csv('Net Income - All Regions - Southwest.csv')
luv_operating_revenue_df = pd.read_csv('Operating Revenue - All Regions - Southwest.csv')
luv_passenger_vol_df = pd.read_csv('Passengers - All Airports - Southwest.csv')
luv_rpm_df = pd.read_csv('Revenue Passager-Miles - All Airports - Southwest.csv')
luv_stock_df = pd.read_csv('LUV_stock_data.csv')
luv_baggage_df = pd.read_csv('Baggage Fees - All Airports - Southwest.csv')

display(luv_asm_df.head())
display(luv_flight_vol_df.head())
display(luv_fuel_df.head())
display(luv_load_factor_df.head())
display(luv_income_df.head())
display(luv_operating_revenue_df.head())
display(luv_passenger_vol_df.head())
display(luv_rpm_df.head())
display(luv_stock_df.tail())
# Out:
#    Year  Month Domestic (Thousands) International (Thousands)  \
# 0  2002     10            6,006,555                       NaN
# 1  2002     11            5,681,559                       NaN
# 2  2002     12            5,899,788                       NaN
# 3  2002  TOTAL           68,909,312                         0
# 4  2003      1            5,991,225                       NaN
#
#   Total (Thousands)
# 0         6,006,555
# 1         5,681,559
# 2         5,899,788
# 3        68,909,312
# 4         5,991,225
#    Year  Month DOMESTIC INTERNATIONAL    TOTAL
# 0  2002     10   81,876           NaN   81,876
# 1  2002     11   76,818           NaN   76,818
# 2  2002     12   79,481           NaN   79,481
# 3  2002  TOTAL  947,490             0  947,490
# 4  2003      1   80,620           NaN   80,620
#    Year     Month Domestic Consumption\n(thousand gallons)  \
# 0  2012   January                                  116,577
# 1  2012  February                                  113,100
# 2  2012     March                                  131,254
# 3  2012     April                                  156,616
# 4  2012       May                                  162,498
#
#   Domestic Cost (thousand dollars) Domestic Cost per Gallon (Dollars)  \
# 0                          376,709                               3.23
# 1                          379,849                               3.36
# 2                          424,925                               3.24
# 3                          516,003                               3.29
# 4                          509,213                               3.13
#
#   International Consumption\n(thousand gallons)  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                           750
# 4                                           695
#
#   International Cost (thousand dollars)  \
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                 2,595
# 4                                 2,465
#
#   International Cost per Gallon (Dollars)  \
# 0                                       -
# 1                                       -
# 2                                       -
# 3                                       3
# 4                                       4
#
#   Total Consumption\n(thousand gallons) Total Cost (thousand dollars)  \
# 0                               116,577                       376,709
# 1                               113,100                       379,849
# 2                               131,254                       424,925
# 3                               157,366                       518,599
# 4                               163,193                       511,678
#
#   Total Cost per Gallon (Dollars)
# 0                            3.23
# 1                            3.36
# 2                            3.24
# 3                             3.3
# 4                            3.14
#    Year  Month  DOMESTIC  INTERNATIONAL  TOTAL
# 0  2002     10     62.50            NaN  62.50
# 1  2002     11     60.54            NaN  60.54
# 2  2002     12     65.96            NaN  65.96
# 3  2002  TOTAL     65.88            NaN  65.88
# 4  2003      1     57.99            NaN  57.99
#    Year Quarter Domestic (Thousands) Latin America (Thousands)  \
# 0  2000       1               73,512                       NaN
# 1  2000       2              190,623                       NaN
# 2  2000       3              184,298                       NaN
# 3  2000       4              154,660                       NaN
# 4  2000   TOTAL              603,093                         0
#
#    Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 0                   NaN                  NaN                        NaN
# 1                   NaN                  NaN                        NaN
# 2                   NaN                  NaN                        NaN
# 3                   NaN                  NaN                        NaN
# 4                   0.0                  0.0                        0.0
#
#   Total (Thousands)
# 0            73,512
# 1           190,623
# 2           184,298
# 3           154,660
# 4           603,093
#    Year Quarter Domestic (Thousands) Latin America (Thousands)  \
# 0  2000       1            1,242,662                       NaN
# 1  2000       2            1,460,691                       NaN
# 2  2000       3            1,478,848                       NaN
# 3  2000       4            1,467,420                       NaN
# 4  2000   TOTAL            5,649,621                         0
#
#    Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 0                   NaN                  NaN                        NaN
# 1                   NaN                  NaN                        NaN
# 2                   NaN                  NaN                        NaN
# 3                   NaN                  NaN                        NaN
# 4                   0.0                  0.0                        0.0
#
#   Total (Thousands)
# 0         1,242,662
# 1         1,460,691
# 2         1,478,848
# 3         1,467,420
# 4         5,649,621
#    Year  Month    DOMESTIC INTERNATIONAL       TOTAL
# 0  2002     10   6,063,128           NaN   6,063,128
# 1  2002     11   5,598,102           NaN   5,598,102
# 2  2002     12   6,104,562           NaN   6,104,562
# 3  2002  TOTAL  72,447,995             0  72,447,995
# 4  2003      1   5,484,294           NaN   5,484,294
#    Year  Month Domestic (Thousands) International (Thousands)  \
# 0  2002     10            3,754,364                       NaN
# 1  2002     11            3,439,403                       NaN
# 2  2002     12            3,891,291                       NaN
# 3  2002  TOTAL           45,397,266                         0
# 4  2003      1            3,474,326                       NaN
#
#   Total (Thousands)
# 0         3,754,364
# 1         3,439,403
# 2         3,891,291
# 3        45,397,266
# 4         3,474,326
#       timestamp     LUV  LUV_rolling_7_day_avg  LUV_rolling_14_day_avg  \
# 375  2018-04-02  54.340              56.552857               58.266429
# 376  2018-04-03  55.970              56.405714               57.955000
# 377  2018-04-04  56.360              56.354286               57.722143
# 378  2018-04-05  56.860              56.250000               57.502143
# 379  2018-04-06  55.865              56.132143               57.142500
#
#      LUV_rolling_30_day_avg  LUV_rolling_90_day_avg  LUV_7_days_ago  \
# 375               58.291333               60.563778           57.59
# 376               58.214667               60.578444           56.69
# 377               58.169000               60.588778           56.25
# 378               58.130000               60.608444           57.28
# 379               58.081500               60.616500             NaN
#
#      LUV_14_days_ago  LUV_30_days_ago  LUV_90_days_ago  LUV_log_price  \
# 375            60.60              NaN            66.29       3.995261
# 376            60.69              NaN            64.91       4.024816
# 377            57.78            58.38            64.70       4.031760
# 378            57.00            58.25            64.32       4.040592
# 379            56.72            57.57              NaN       4.022938
#
#      LUV_pct_change_7_days  LUV_pct_change_14_days  LUV_pct_change_30_days  \
# 375              -0.056433               -0.103300                     NaN
# 376              -0.012701               -0.077772                     NaN
# 377               0.001956               -0.024576               -0.034601
# 378              -0.007332               -0.002456               -0.023863
# 379                    NaN               -0.015074               -0.029616
#
#      LUV_pct_change_90_days
# 375               -0.180269
# 376               -0.137729
# 377               -0.128903
# 378               -0.115983
# 379                     NaN

# %%
# clean baggage

# dictionary to map quarters to their corresponding month and day
quarter_end_dates = {
    1: '03-31',
    2: '06-30',
    3: '09-30',
    4: '12-31'
}

# drop the total columns in order to convert to datetime. aggregation can easily replace total
luv_baggage_df = luv_baggage_df.loc[luv_baggage_df['Quarter'] != "TOTAL"].copy()

# convert quarter to numeric in order to use mapping 
luv_baggage_df['Quarter'] = pd.to_numeric(luv_baggage_df['Quarter'])

# convert to quarters, then resample to months
luv_baggage_df['date_str'] = luv_baggage_df['Year'].astype(str) + '-' + luv_baggage_df['Quarter'].map(quarter_end_dates)
luv_baggage_df['timestamp'] = pd.PeriodIndex(luv_baggage_df['date_str'], freq='Q')
luv_baggage_df.set_index('timestamp', inplace=True)
luv_baggage_df = luv_baggage_df.resample('M').ffill()


#drop placeholder date_str
luv_baggage_df.drop(columns=['date_str'], inplace=True)

# select the rows with dates corresponding to other data (October 2016-April 2018)
luv_baggage_df = luv_baggage_df.reset_index()
start_date = pd.Period('2016-10-01', freq = 'M')
end_date = pd.Period('2018-05-01', freq='M')
luv_baggage_df = luv_baggage_df.loc[(luv_baggage_df['timestamp'] >= start_date) & (luv_baggage_df['timestamp'] < end_date)]


# clean dtypes
luv_baggage_df['Total (Thousands)'] = luv_baggage_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# clean asm

# drop the total columns in order to convert to datetime. aggregation can easily replace total
luv_asm_df = luv_asm_df.loc[luv_asm_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
luv_asm_df['date_str'] = luv_asm_df['Year'].astype(str) + '-' + luv_asm_df['Month'].astype(str) + '-01'
luv_asm_df['timestamp'] = pd.to_datetime(luv_asm_df['date_str'])

# put time stamp as first column for clarity
luv_asm_df = luv_asm_df[['timestamp'] + [col for col in luv_asm_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
luv_asm_df['timestamp'] = luv_asm_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
luv_asm_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
luv_asm_df = luv_asm_df.loc[(luv_asm_df['timestamp'] >= start_date) & (luv_asm_df['timestamp'] < end_date)]

# convert dtypes
luv_asm_df['Domestic (Thousands)'] = luv_asm_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
luv_asm_df['International (Thousands)'] = luv_asm_df['International (Thousands)'].str.replace(",", "").astype(float)
luv_asm_df['Total (Thousands)'] = luv_asm_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# clean flight vol

# drop the total columns in order to convert to datetime. aggregation can easily replace total
luv_flight_vol_df = luv_flight_vol_df.loc[luv_flight_vol_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
luv_flight_vol_df['date_str'] = luv_flight_vol_df['Year'].astype(str) + '-' + luv_flight_vol_df['Month'].astype(str) + '-01'
luv_flight_vol_df['timestamp'] = pd.to_datetime(luv_flight_vol_df['date_str'])

# put time stamp as first column for clarity
luv_flight_vol_df = luv_flight_vol_df[['timestamp'] + [col for col in luv_flight_vol_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
luv_flight_vol_df['timestamp'] = luv_flight_vol_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
luv_flight_vol_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
luv_flight_vol_df = luv_flight_vol_df.loc[(luv_flight_vol_df['timestamp'] >= start_date) & (luv_flight_vol_df['timestamp'] < end_date)]

# clean dtypes
luv_flight_vol_df['DOMESTIC'] = luv_flight_vol_df['DOMESTIC'].str.replace(",", "").astype(float)
luv_flight_vol_df['INTERNATIONAL'] = luv_flight_vol_df['INTERNATIONAL'].str.replace(",", "").astype(float)
luv_flight_vol_df['TOTAL'] = luv_flight_vol_df['TOTAL'].str.replace(",", "").astype(float)

# %%
# clean fuel df 

luv_fuel_df.dtypes

month_name_to_number = {
    'January': 1,
    'February': 2,
    'March': 3,
    'April': 4,
    'May': 5,
    'June': 6,
    'July': 7,
    'August': 8,
    'September': 9,
    'October': 10,
    'November': 11,
    'December': 12
}

luv_fuel_df['Month'] = luv_fuel_df['Month'].astype(str)
luv_fuel_df = luv_fuel_df.loc[luv_fuel_df['Month'] != "nan"].copy()
luv_fuel_df['Month'] = luv_fuel_df['Month'].map(month_name_to_number)

# create datetime column to index compare to stock. 
luv_fuel_df['date_str'] = luv_fuel_df['Year'].astype(str) + '-' + luv_fuel_df['Month'].astype(str) + '-01'
luv_fuel_df['timestamp'] = pd.to_datetime(luv_fuel_df['date_str'])

# put time stamp as first column for clarity
luv_fuel_df = luv_fuel_df[['timestamp'] + [col for col in luv_fuel_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
luv_fuel_df['timestamp'] = luv_fuel_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
luv_fuel_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
luv_fuel_df = luv_fuel_df.loc[(luv_fuel_df['timestamp'] >= start_date) & (luv_fuel_df['timestamp'] < end_date)]

# clean dtypes
luv_fuel_df['Domestic Consumption\n(thousand gallons)'] = luv_fuel_df['Domestic Consumption\n(thousand gallons)'].str.replace(",", "").astype(float)
luv_fuel_df['Domestic Cost (thousand dollars)'] = luv_fuel_df['Domestic Cost (thousand dollars)'].str.replace(",", "").astype(float)
luv_fuel_df['Domestic Cost per Gallon (Dollars)'] = luv_fuel_df['Domestic Cost per Gallon (Dollars)'].str.replace(",", "").astype(float)
luv_fuel_df['International Consumption\n(thousand gallons)'] = luv_fuel_df['International Consumption\n(thousand gallons)'].str.replace(",", "").astype(float)
luv_fuel_df['International Cost (thousand dollars)'] = luv_fuel_df['International Cost (thousand dollars)'].str.replace(",", "").astype(float)
luv_fuel_df['International Cost per Gallon (Dollars)'] = luv_fuel_df['International Cost per Gallon (Dollars)'].str.replace(",", "").astype(float)
luv_fuel_df['Total Consumption\n(thousand gallons)'] = luv_fuel_df['Total Consumption\n(thousand gallons)'].str.replace(",", "").astype(float)
luv_fuel_df['Total Cost (thousand dollars)'] = luv_fuel_df['Total Cost (thousand dollars)'].str.replace(",", "").astype(float)
luv_fuel_df['Total Cost per Gallon (Dollars)'] = luv_fuel_df['Total Cost per Gallon (Dollars)'].str.replace(",", "").astype(float)

#rename certain columns
luv_fuel_df.rename(columns={'Domestic Consumption\n(thousand gallons)': 'Domestic Consumption (thousand gallons)'}, inplace=True)
luv_fuel_df.rename(columns={'International Consumption\n(thousand gallons)': 'International Consumption (thousand gallons)'}, inplace=True)
luv_fuel_df.rename(columns={'Total Consumption\n(thousand gallons)': 'Total Consumption (thousand gallons)'}, inplace=True)

# %%
# clean load factor 

# drop the total columns in order to convert to datetime. aggregation can easily replace total
luv_load_factor_df = luv_load_factor_df.loc[luv_load_factor_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
luv_load_factor_df['date_str'] = luv_load_factor_df['Year'].astype(str) + '-' + luv_load_factor_df['Month'].astype(str) + '-01'
luv_load_factor_df['timestamp'] = pd.to_datetime(luv_load_factor_df['date_str'])

# put time stamp as first column for clarity
luv_load_factor_df = luv_load_factor_df[['timestamp'] + [col for col in luv_load_factor_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
luv_load_factor_df['timestamp'] = luv_load_factor_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
luv_load_factor_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
luv_load_factor_df = luv_load_factor_df.loc[(luv_load_factor_df['timestamp'] >= start_date) & (luv_load_factor_df['timestamp'] < end_date)]

# dtypes came clean

# %%
# clean net income 

# dictionary to map quarters to their corresponding month and day
quarter_end_dates = {
    1: '03-31',
    2: '06-30',
    3: '09-30',
    4: '12-31'
}

# drop the total columns in order to convert to datetime. aggregation can easily replace total
luv_income_df = luv_income_df.loc[luv_income_df['Quarter'] != "TOTAL"].copy()

# convert quarter to numeric in order to use mapping 
luv_income_df['Quarter'] = pd.to_numeric(luv_income_df['Quarter'])

# convert to quarters, then resample to months
luv_income_df['date_str'] = luv_income_df['Year'].astype(str) + '-' + luv_income_df['Quarter'].map(quarter_end_dates)
luv_income_df['timestamp'] = pd.PeriodIndex(luv_income_df['date_str'], freq='Q')
luv_income_df.set_index('timestamp', inplace=True)
luv_income_df = luv_income_df.resample('M').ffill()

#drop placeholder date_str
luv_income_df.drop(columns=['date_str'], inplace=True)

# select the rows with dates corresponding to other data (October 2016-April 2018)
luv_income_df = luv_income_df.reset_index()
start_date = pd.Period('2016-10-01', freq = 'M')
end_date = pd.Period('2018-05-01', freq='M')
luv_income_df = luv_income_df.loc[(luv_income_df['timestamp'] >= start_date) & (luv_income_df['timestamp'] < end_date)]

# clean dtypes
luv_income_df['Domestic (Thousands)'] = luv_income_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
luv_income_df['Latin America (Thousands)'] = luv_income_df['Latin America (Thousands)'].str.replace(",", "").astype(float)
luv_income_df['Total (Thousands)'] = luv_income_df['Total (Thousands)'].str.replace(",", "").astype(float)

# dtypes came clean
display(luv_income_df)
# Out:
#     timestamp  Year  Quarter  Domestic (Thousands)  Latin America (Thousands)  \
# 201   2016-10  2016        4              512887.0                     9453.0
# 202   2016-11  2016        4              512887.0                     9453.0
# 203   2016-12  2016        4              512887.0                     9453.0
# 204   2017-01  2017        1              344047.0                     7417.0
# 205   2017-02  2017        1              344047.0                     7417.0
# 206   2017-03  2017        1              344047.0                     7417.0
# 207   2017-04  2017        2              727976.0                    18056.0
# 208   2017-05  2017        2              727976.0                    18056.0
# 209   2017-06  2017        2              727976.0                    18056.0
# 210   2017-07  2017        3              490293.0                    12312.0
# 211   2017-08  2017        3              490293.0                    12312.0
# 212   2017-09  2017        3              490293.0                    12312.0
# 213   2017-10  2017        4             1846065.0                    42299.0
# 214   2017-11  2017        4             1846065.0                    42299.0
# 215   2017-12  2017        4             1846065.0                    42299.0
# 216   2018-01  2018        1              450336.0                    12260.0
# 217   2018-02  2018        1              450336.0                    12260.0
# 218   2018-03  2018        1              450336.0                    12260.0
# 219   2018-04  2018        2              713303.0                    19420.0
#
#      Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 201                   NaN                  NaN                        NaN
# 202                   NaN                  NaN                        NaN
# 203                   NaN                  NaN                        NaN
# 204                   NaN                  NaN                        NaN
# 205                   NaN                  NaN                        NaN
# 206                   NaN                  NaN                        NaN
# 207                   NaN                  NaN                        NaN
# 208                   NaN                  NaN                        NaN
# 209                   NaN                  NaN                        NaN
# 210                   NaN                  NaN                        NaN
# 211                   NaN                  NaN                        NaN
# 212                   NaN                  NaN                        NaN
# 213                   NaN                  NaN                        NaN
# 214                   NaN                  NaN                        NaN
# 215                   NaN                  NaN                        NaN
# 216                   NaN                  NaN                        NaN
# 217                   NaN                  NaN                        NaN
# 218                   NaN                  NaN                        NaN
# 219                   NaN                  NaN                        NaN
#
#      Total (Thousands)
# 201           522340.0
# 202           522340.0
# 203           522340.0
# 204           351464.0
# 205           351464.0
# 206           351464.0
# 207           746032.0
# 208           746032.0
# 209           746032.0
# 210           502605.0
# 211           502605.0
# 212           502605.0
# 213          1888364.0
# 214          1888364.0
# 215          1888364.0
# 216           462596.0
# 217           462596.0
# 218           462596.0
# 219           732723.0

# %%
# clean operating revenue

# drop the total columns in order to convert to datetime. aggregation can easily replace total
luv_operating_revenue_df = luv_operating_revenue_df.loc[luv_operating_revenue_df['Quarter'] != "TOTAL"].copy()

# convert quarter to numeric in order to use mapping 
luv_operating_revenue_df['Quarter'] = pd.to_numeric(luv_operating_revenue_df['Quarter'])

# convert to quarters, then resample to months
luv_operating_revenue_df['date_str'] = luv_operating_revenue_df['Year'].astype(str) + '-' + luv_operating_revenue_df['Quarter'].map(quarter_end_dates)
luv_operating_revenue_df['timestamp'] = pd.PeriodIndex(luv_operating_revenue_df['date_str'], freq='Q')
luv_operating_revenue_df.set_index('timestamp', inplace=True)
luv_operating_revenue_df = luv_operating_revenue_df.resample('M').ffill()

#drop placeholder date_str
luv_operating_revenue_df.drop(columns=['date_str'], inplace=True)

# select the rows with dates corresponding to other data (October 2016-April 2018)
luv_operating_revenue_df = luv_operating_revenue_df.reset_index()
start_date = pd.Period('2016-10-01', freq = 'M')
end_date = pd.Period('2018-05-01', freq='M')
luv_operating_revenue_df = luv_operating_revenue_df.loc[(luv_operating_revenue_df['timestamp'] >= start_date) & (luv_operating_revenue_df['timestamp'] < end_date)]

luv_operating_revenue_df['Domestic (Thousands)'] = luv_operating_revenue_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
luv_operating_revenue_df['Latin America (Thousands)'] = luv_operating_revenue_df['Latin America (Thousands)'].str.replace(",", "").astype(float)
luv_operating_revenue_df['Total (Thousands)'] = luv_operating_revenue_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# clean passenger volume df

# drop the total columns in order to convert to datetime. aggregation can easily replace total
luv_passenger_vol_df = luv_passenger_vol_df.loc[luv_passenger_vol_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
luv_passenger_vol_df['date_str'] = luv_passenger_vol_df['Year'].astype(str) + '-' + luv_passenger_vol_df['Month'].astype(str) + '-01'
luv_passenger_vol_df['timestamp'] = pd.to_datetime(luv_passenger_vol_df['date_str'])

# put time stamp as first column for clarity
luv_passenger_vol_df = luv_passenger_vol_df[['timestamp'] + [col for col in luv_passenger_vol_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
luv_passenger_vol_df['timestamp'] = luv_passenger_vol_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
luv_passenger_vol_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
luv_passenger_vol_df = luv_passenger_vol_df.loc[(luv_passenger_vol_df['timestamp'] >= start_date) & (luv_passenger_vol_df['timestamp'] < end_date)]

# clean dtypes
luv_passenger_vol_df['DOMESTIC'] = luv_passenger_vol_df['DOMESTIC'].str.replace(",", "").astype(float)
luv_passenger_vol_df['INTERNATIONAL'] = luv_passenger_vol_df['INTERNATIONAL'].str.replace(",", "").astype(float)
luv_passenger_vol_df['TOTAL'] = luv_passenger_vol_df['TOTAL'].str.replace(",", "").astype(float)

# %%
# clean rpm df 

# drop the total columns in order to convert to datetime. aggregation can easily replace total
luv_rpm_df = luv_rpm_df.loc[luv_rpm_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
luv_rpm_df['date_str'] = luv_rpm_df['Year'].astype(str) + '-' + luv_rpm_df['Month'].astype(str) + '-01'
luv_rpm_df['timestamp'] = pd.to_datetime(luv_rpm_df['date_str'])

# put time stamp as first column for clarity
luv_rpm_df = luv_rpm_df[['timestamp'] + [col for col in luv_rpm_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
luv_rpm_df['timestamp'] = luv_rpm_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
luv_rpm_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
luv_rpm_df = luv_rpm_df.loc[(luv_rpm_df['timestamp'] >= start_date) & (luv_rpm_df['timestamp'] < end_date)]

# clean dtypes
luv_rpm_df['Domestic (Thousands)'] = luv_rpm_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
luv_rpm_df['International (Thousands)'] = luv_rpm_df['International (Thousands)'].str.replace(",", "").astype(float)
luv_rpm_df['Total (Thousands)'] = luv_rpm_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# luv stock dtype clean
luv_stock_df['timestamp'] = pd.to_datetime(luv_stock_df['timestamp'])

# %%
display(luv_asm_df.head())
display(luv_flight_vol_df.head())
display(luv_fuel_df.head())
display(luv_load_factor_df.head())
display(luv_income_df.head())
display(luv_operating_revenue_df.head())
display(luv_passenger_vol_df.head())
display(luv_rpm_df.head())
display(luv_baggage_df.head())
display(luv_stock_df.tail())
# Out:
#      timestamp  Year Month  Domestic (Thousands)  International (Thousands)  \
# 182 2016-10-31  2016    10            11931399.0                   296064.0
# 183 2016-11-30  2016    11            11919554.0                   354702.0
# 184 2016-12-31  2016    12            12191400.0                   454646.0
# 186 2017-01-31  2017     1            11799123.0                   466562.0
# 187 2017-02-28  2017     2            10561828.0                   435886.0
#
#      Total (Thousands)
# 182         12227463.0
# 183         12274256.0
# 184         12646046.0
# 186         12265685.0
# 187         10997714.0
#      timestamp  Year Month  DOMESTIC  INTERNATIONAL     TOTAL
# 182 2016-10-31  2016    10  107429.0         1686.0  109115.0
# 183 2016-11-30  2016    11  106840.0         2018.0  108858.0
# 184 2016-12-31  2016    12  109111.0         2654.0  111765.0
# 186 2017-01-31  2017     1  105683.0         2754.0  108437.0
# 187 2017-02-28  2017     2   94593.0         2563.0   97156.0
#     timestamp  Year  Month  Domestic Consumption (thousand gallons)  \
# 65 2016-10-31  2016     10                                 163531.0
# 66 2016-11-30  2016     11                                 162797.0
# 67 2016-12-31  2016     12                                 168866.0
# 70 2017-01-31  2017      1                                 162341.0
# 71 2017-02-28  2017      2                                 144820.0
#
#     Domestic Cost (thousand dollars)  Domestic Cost per Gallon (Dollars)  \
# 65                          298242.0                                1.82
# 66                          296169.0                                1.82
# 67                          309725.0                                1.83
# 70                          288449.0                                1.78
# 71                          266514.0                                1.84
#
#     International Consumption (thousand gallons)  \
# 65                                         948.0
# 66                                        1164.0
# 67                                        1582.0
# 70                                        1328.0
# 71                                        1357.0
#
#     International Cost (thousand dollars)  \
# 65                                 1802.0
# 66                                 2177.0
# 67                                 3017.0
# 70                                 2697.0
# 71                                 2756.0
#
#     International Cost per Gallon (Dollars)  \
# 65                                      2.0
# 66                                      2.0
# 67                                      2.0
# 70                                      2.0
# 71                                      2.0
#
#     Total Consumption (thousand gallons)  Total Cost (thousand dollars)  \
# 65                              164479.0                       300044.0
# 66                              163961.0                       298346.0
# 67                              170448.0                       312742.0
# 70                              163668.0                       291146.0
# 71                              146177.0                       269271.0
#
#     Total Cost per Gallon (Dollars)
# 65                             1.82
# 66                             1.82
# 67                             1.83
# 70                             1.78
# 71                             1.84
#      timestamp  Year Month  DOMESTIC  INTERNATIONAL  TOTAL
# 182 2016-10-31  2016    10     85.87          78.62  85.69
# 183 2016-11-30  2016    11     85.21          80.59  85.08
# 184 2016-12-31  2016    12     82.71          79.58  82.60
# 186 2017-01-31  2017     1     76.34          74.10  76.25
# 187 2017-02-28  2017     2     79.28          72.17  79.00
#     timestamp  Year  Quarter  Domestic (Thousands)  Latin America (Thousands)  \
# 201   2016-10  2016        4              512887.0                     9453.0
# 202   2016-11  2016        4              512887.0                     9453.0
# 203   2016-12  2016        4              512887.0                     9453.0
# 204   2017-01  2017        1              344047.0                     7417.0
# 205   2017-02  2017        1              344047.0                     7417.0
#
#      Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 201                   NaN                  NaN                        NaN
# 202                   NaN                  NaN                        NaN
# 203                   NaN                  NaN                        NaN
# 204                   NaN                  NaN                        NaN
# 205                   NaN                  NaN                        NaN
#
#      Total (Thousands)
# 201           522340.0
# 202           522340.0
# 203           522340.0
# 204           351464.0
# 205           351464.0
#     timestamp  Year  Quarter  Domestic (Thousands)  Latin America (Thousands)  \
# 201   2016-10  2016        4             4983801.0                    91869.0
# 202   2016-11  2016        4             4983801.0                    91869.0
# 203   2016-12  2016        4             4983801.0                    91869.0
# 204   2017-01  2017        1             4779641.0                   103023.0
# 205   2017-02  2017        1             4779641.0                   103023.0
#
#      Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 201                   NaN                  NaN                        NaN
# 202                   NaN                  NaN                        NaN
# 203                   NaN                  NaN                        NaN
# 204                   NaN                  NaN                        NaN
# 205                   NaN                  NaN                        NaN
#
#      Total (Thousands)
# 201          5075670.0
# 202          5075670.0
# 203          5075670.0
# 204          4882664.0
# 205          4882664.0
#      timestamp  Year Month    DOMESTIC  INTERNATIONAL       TOTAL
# 182 2016-10-31  2016    10  12821619.0       192548.0  13014167.0
# 183 2016-11-30  2016    11  12689307.0       231216.0  12920523.0
# 184 2016-12-31  2016    12  12547225.0       298023.0  12845248.0
# 186 2017-01-31  2017     1  11037315.0       287068.0  11324383.0
# 187 2017-02-28  2017     2  10406350.0       256495.0  10662845.0
#      timestamp  Year Month  Domestic (Thousands)  International (Thousands)  \
# 182 2016-10-31  2016    10            10245380.0                   232762.0
# 183 2016-11-30  2016    11            10157213.0                   285862.0
# 184 2016-12-31  2016    12            10083870.0                   361830.0
# 186 2017-01-31  2017     1             9007205.0                   345733.0
# 187 2017-02-28  2017     2             8373485.0                   314571.0
#
#      Total (Thousands)
# 182         10478142.0
# 183         10443076.0
# 184         10445700.0
# 186          9352938.0
# 187          8688056.0
#    timestamp  Year  Quarter  Total (Thousands)
# 9    2016-10  2016        4            10158.0
# 10   2016-11  2016        4            10158.0
# 11   2016-12  2016        4            10158.0
# 12   2017-01  2017        1            10419.0
# 13   2017-02  2017        1            10419.0
#      timestamp     LUV  LUV_rolling_7_day_avg  LUV_rolling_14_day_avg  \
# 375 2018-04-02  54.340              56.552857               58.266429
# 376 2018-04-03  55.970              56.405714               57.955000
# 377 2018-04-04  56.360              56.354286               57.722143
# 378 2018-04-05  56.860              56.250000               57.502143
# 379 2018-04-06  55.865              56.132143               57.142500
#
#      LUV_rolling_30_day_avg  LUV_rolling_90_day_avg  LUV_7_days_ago  \
# 375               58.291333               60.563778           57.59
# 376               58.214667               60.578444           56.69
# 377               58.169000               60.588778           56.25
# 378               58.130000               60.608444           57.28
# 379               58.081500               60.616500             NaN
#
#      LUV_14_days_ago  LUV_30_days_ago  LUV_90_days_ago  LUV_log_price  \
# 375            60.60              NaN            66.29       3.995261
# 376            60.69              NaN            64.91       4.024816
# 377            57.78            58.38            64.70       4.031760
# 378            57.00            58.25            64.32       4.040592
# 379            56.72            57.57              NaN       4.022938
#
#      LUV_pct_change_7_days  LUV_pct_change_14_days  LUV_pct_change_30_days  \
# 375              -0.056433               -0.103300                     NaN
# 376              -0.012701               -0.077772                     NaN
# 377               0.001956               -0.024576               -0.034601
# 378              -0.007332               -0.002456               -0.023863
# 379                    NaN               -0.015074               -0.029616
#
#      LUV_pct_change_90_days
# 375               -0.180269
# 376               -0.137729
# 377               -0.128903
# 378               -0.115983
# 379                     NaN

# %%
luv_asm_df.dtypes
# Out:
# timestamp                    datetime64[ns]
# Year                                  int64
# Month                                object
# Domestic (Thousands)                float64
# International (Thousands)           float64
# Total (Thousands)                   float64
# dtype: object

# %%
luv_flight_vol_df.dtypes
# Out:
# timestamp        datetime64[ns]
# Year                      int64
# Month                    object
# DOMESTIC                float64
# INTERNATIONAL           float64
# TOTAL                   float64
# dtype: object

# %%
luv_fuel_df.dtypes
# Out:
# timestamp                                       datetime64[ns]
# Year                                                    object
# Month                                                    int64
# Domestic Consumption (thousand gallons)                float64
# Domestic Cost (thousand dollars)                       float64
# Domestic Cost per Gallon (Dollars)                     float64
# International Consumption (thousand gallons)           float64
# International Cost (thousand dollars)                  float64
# International Cost per Gallon (Dollars)                float64
# Total Consumption (thousand gallons)                   float64
# Total Cost (thousand dollars)                          float64
# Total Cost per Gallon (Dollars)                        float64
# dtype: object

# %%
luv_load_factor_df.dtypes
# Out:
# timestamp        datetime64[ns]
# Year                      int64
# Month                    object
# DOMESTIC                float64
# INTERNATIONAL           float64
# TOTAL                   float64
# dtype: object

# %%
luv_income_df.dtypes
# Out:
# timestamp                    period[M]
# Year                             int64
# Quarter                          int64
# Domestic (Thousands)           float64
# Latin America (Thousands)      float64
# Atlantic (Thousands)           float64
# Pacific (Thousands)            float64
# International (Thousands)      float64
# Total (Thousands)              float64
# dtype: object

# %%
luv_operating_revenue_df.dtypes
# Out:
# timestamp                    period[M]
# Year                             int64
# Quarter                          int64
# Domestic (Thousands)           float64
# Latin America (Thousands)      float64
# Atlantic (Thousands)           float64
# Pacific (Thousands)            float64
# International (Thousands)      float64
# Total (Thousands)              float64
# dtype: object

# %%
luv_passenger_vol_df.dtypes
# Out:
# timestamp        datetime64[ns]
# Year                      int64
# Month                    object
# DOMESTIC                float64
# INTERNATIONAL           float64
# TOTAL                   float64
# dtype: object

# %%
luv_rpm_df.dtypes
# Out:
# timestamp                    datetime64[ns]
# Year                                  int64
# Month                                object
# Domestic (Thousands)                float64
# International (Thousands)           float64
# Total (Thousands)                   float64
# dtype: object

# %%
luv_baggage_df.dtypes
# Out:
# timestamp            period[M]
# Year                     int64
# Quarter                  int64
# Total (Thousands)      float64
# dtype: object

# %%
luv_stock_df.dtypes
# Out:
# timestamp                 datetime64[ns]
# LUV                              float64
# LUV_rolling_7_day_avg            float64
# LUV_rolling_14_day_avg           float64
# LUV_rolling_30_day_avg           float64
# LUV_rolling_90_day_avg           float64
# LUV_7_days_ago                   float64
# LUV_14_days_ago                  float64
# LUV_30_days_ago                  float64
# LUV_90_days_ago                  float64
# LUV_log_price                    float64
# LUV_pct_change_7_days            float64
# LUV_pct_change_14_days           float64
# LUV_pct_change_30_days           float64
# LUV_pct_change_90_days           float64
# dtype: object

# %% [markdown]
# # Analysis

# %%
avail_seat_miles = luv_asm_df
baggage_fees = luv_baggage_df
fuel = luv_fuel_df
load_factor = luv_load_factor_df
net_income = luv_income_df
operating_revenue = luv_operating_revenue_df
passengers = luv_passenger_vol_df
revenue_passenger_miles = luv_rpm_df
flights = luv_flight_vol_df




prices = luv_stock_df[luv_stock_df['timestamp'].dt.day < 4]
prices = prices[['timestamp','LUV']]
prices.set_index('timestamp',inplace = True)
price = prices.resample('M').mean()
price = price.values
p = []
for i in range(len(price)):
    p.append(price[i][0])
price = numpy.array(p)

# %% [markdown]
# Correlation/Plots for Available Seat Miles

# %%
# time series plots for domestic, intl, and total asm
avail_seat_miles.set_index('timestamp', inplace = True)
avail_seat_miles['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Available Seat Miles (Thousands)')
plt.title('Time Series of Total Available Seat Miles')
plt.grid(True)
plt.show()

avail_seat_miles['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Available Seat Miles (Thousands)')
plt.title('Time Series of Domestic Available Seat Miles')
plt.grid(True)
plt.show()

avail_seat_miles['International (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Available Seat Miles (Thousands)')
plt.title('Time Series of International Available Seat Miles')
plt.grid(True)
plt.show()

# %%
# available seat miles versus stock price plots
total = avail_seat_miles['Total (Thousands)'].values
domestic = avail_seat_miles['Domestic (Thousands)'].values
intl = avail_seat_miles['International (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Available Seat Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Available Seat Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('International Available Seat Miles vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients for asm

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Available Seat Miles to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Available Seat Miles to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Available Seat Miles to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Available Seat Miles to Stock Price is :0.3400932039888402
# The correlation coefficent for Domestic Available Seat Miles to Stock Price is :0.3003300588447635
# The correlation coefficent for International Available Seat Miles to Stock Price is :0.6397629586263485

# %% [markdown]
# Correlation/Plots for Baggage Fees

# %%
# time series plot of baggage fees
baggage_fees.set_index('timestamp', inplace = True)
baggage_fees['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Total Fees ($Thousands)')
plt.title('Time Series of Total Baggage Fees')
plt.grid(True)
plt.show()

# %%
# available seat miles versus stock price plots
fees = baggage_fees['Total (Thousands)'].values


plt.scatter(fees, price)
plt.xlabel('Baggage Fees ($Thousands)')
plt.ylabel('Stock Price')
plt.title('Baggage Fees vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficient for baggage fees

fee_r = numpy.corrcoef(fees,price)[0,1]
print("The correlation coefficent for Baggage Fees to Stock Price is :" + str(total_r))
# Out:
# The correlation coefficent for Baggage Fees to Stock Price is :0.3400932039888402

# %% [markdown]
# Correlation/Plots for Fuel

# %%
# time series plots for domestic, intl, and total fuel
fuel.set_index('timestamp', inplace = True)
fuel['Domestic Consumption (thousand gallons)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Consumption (thousand gallons)')
plt.title('Time Series of Domestic Fuel Consumption')
plt.grid(True)
plt.show()

fuel['International Consumption (thousand gallons)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Consumption (thousand gallons)')
plt.title('Time Series of International Fuel Consumption')
plt.grid(True)
plt.show()

fuel['Total Consumption (thousand gallons)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Consumption (thousand gallons)')
plt.title('Time Series of Total Consumption')
plt.grid(True)
plt.show()

fuel['Domestic Cost (thousand dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Cost (thousand dollars)')
plt.title('Time Series of Domestic Fuel Cost')
plt.grid(True)
plt.show()

fuel['International Cost (thousand dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Cost (thousand dollars)')
plt.title('Time Series of International Fuel Cost')
plt.grid(True)
plt.show()

fuel['Total Cost (thousand dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Cost (thousand dollars)')
plt.title('Time Series of Total Fuel Cost')
plt.grid(True)
plt.show()

fuel['Domestic Cost per Gallon (Dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Cost per Gallon (Dollars)')
plt.title('Time Series of Domestic Cost per Gallon')
plt.grid(True)
plt.show()

fuel['International Cost per Gallon (Dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Cost per Gallon (Dollars)')
plt.title('Time Series of International Cost per Gallon')
plt.grid(True)
plt.show()

fuel['Total Cost per Gallon (Dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Cost per Gallon (Dollars)')
plt.title('Time Series of Cost per Gallon')
plt.grid(True)
plt.show()

# %%
# fuel versus stock price plots
total_consumption = fuel['Total Consumption (thousand gallons)'].values
domestic_consumption = fuel['Domestic Consumption (thousand gallons)'].values
intl_consumption = fuel['International Consumption (thousand gallons)'].values
total_cost =fuel['Total Cost (thousand dollars)'].values
domestic_cost = fuel['Domestic Cost (thousand dollars)'].values
intl_cost =fuel['International Cost (thousand dollars)'].values
total_cpg = fuel['Total Cost per Gallon (Dollars)'].values
domestic_cpg =fuel['Domestic Cost per Gallon (Dollars)'].values
intl_cpg =fuel['International Cost per Gallon (Dollars)'].values


plt.figure()
plt.scatter(total_consumption, price)
plt.xlabel('Consumption (thousand gallons)')
plt.ylabel('Stock Price')
plt.title('Total Fuel Consumption (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic_consumption, price)
plt.xlabel('Consumption (thousand gallons)')
plt.ylabel('Stock Price')
plt.title('Domestic Fuel Consumption (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl_consumption, price)
plt.xlabel('Consumption (thousand gallons)')
plt.ylabel('Stock Price')
plt.title('International Fuel Consumption (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(total_cost, price)
plt.xlabel('Cost (thousand dollars)')
plt.ylabel('Stock Price')
plt.title('Total Fuel Cost (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic_cost, price)
plt.xlabel('Cost (thousand dollars)')
plt.ylabel('Stock Price')
plt.title('Domestic Fuel Cost (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl_cost, price)
plt.xlabel('Cost (thousand dollars)')
plt.ylabel('Stock Price')
plt.title('International Fuel Cost (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(total_cpg, price)
plt.xlabel('Cost per Gallon (Dollars)')
plt.ylabel('Stock Price')
plt.title('Total Fuel Cost per Gallon (Dollars) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic_cpg, price)
plt.xlabel('Cost per Gallon (Dollars)')
plt.ylabel('Stock Price')
plt.title('Domestic Fuel Cost per Gallon (Dollars) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl_cpg, price)
plt.xlabel('Cost per Gallon (Dollars)')
plt.ylabel('Stock Price')
plt.title('International Fuel Cost per Gallon (Dollars) vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients for fuel

r1 = numpy.corrcoef(total_consumption, price)[0,1]
print("The correlation coefficent for Total Fuel Consumption (thousand gallons) vs Stock Price is :" + str(r1))
r2 = numpy.corrcoef(domestic_consumption ,price)[0,1]
print("The correlation coefficent for Domestic Fuel Consumption (thousand gallons) vs Stock Price is :" + str(r2))
r3 = numpy.corrcoef(intl_consumption,price)[0,1]
print("The correlation coefficent for International Fuel Consumption (thousand gallons) vs Stock Price is:" + str(r3))

r4 = numpy.corrcoef(total_cost, price)[0,1]
print("The correlation coefficent for Total Fuel Cost (thousand gallons) vs Stock Price is:" + str(r4))
r5 = numpy.corrcoef(domestic_cost ,price)[0,1]
print("The correlation coefficent for Domestic Fuel Cost (thousand gallons) vs Stock Price :" + str(r5))
r6 = numpy.corrcoef(intl_cost,price)[0,1]
print("The correlation coefficent for International Fuel Cost (thousand gallons) vs Stock Price:" + str(r6))

r7 = numpy.corrcoef(total_cpg, price)[0,1]
print("The correlation coefficent for Total Fuel Cost per Gallon (Dollars) vs Stock Price :" + str(r7))
r8 = numpy.corrcoef(domestic_cpg ,price)[0,1]
print("The correlation coefficent for Domestic Fuel Cost per Gallon (Dollars) vs Stock Price :" + str(r8))
r9 = numpy.corrcoef(intl_cpg,price)[0,1]
print("The correlation coefficent for International Fuel Cost per Gallon (Dollars) vs Stock Price :" + str(r9))
# Out:
# The correlation coefficent for Total Fuel Consumption (thousand gallons) vs Stock Price is :0.2775058656699888
# The correlation coefficent for Domestic Fuel Consumption (thousand gallons) vs Stock Price is :0.2539743031856667
# The correlation coefficent for International Fuel Consumption (thousand gallons) vs Stock Price is:0.6891644810904647
# The correlation coefficent for Total Fuel Cost (thousand gallons) vs Stock Price is:0.3773351585965139
# The correlation coefficent for Domestic Fuel Cost (thousand gallons) vs Stock Price :0.34986928294102193
# The correlation coefficent for International Fuel Cost (thousand gallons) vs Stock Price:0.7273181171126246
# The correlation coefficent for Total Fuel Cost per Gallon (Dollars) vs Stock Price :0.13184187336892703
# The correlation coefficent for Domestic Fuel Cost per Gallon (Dollars) vs Stock Price :0.11651375213087486
# The correlation coefficent for International Fuel Cost per Gallon (Dollars) vs Stock Price :nan
# /Users/liamoshaughnessy/anaconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/liamoshaughnessy/anaconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %% [markdown]
# Correlation/Plots for Load Factor

# %%
# time series plots for domestic, intl, and total load factor
load_factor.set_index('timestamp', inplace = True)
load_factor['DOMESTIC'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Load Factor')
plt.title('Time Series of Domestic Load Factor')
plt.grid(True)
plt.show()

load_factor['INTERNATIONAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Load Factor')
plt.title('Time Series of International Load Factor')
plt.grid(True)
plt.show()

load_factor['TOTAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Load Factor')
plt.title('Time Series of Total Load Factor')
plt.grid(True)
plt.show()

# %%
# load factor versus stock price plots
total = load_factor['TOTAL'].values
domestic = load_factor['DOMESTIC'].values
intl = load_factor['INTERNATIONAL'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Load Factor')
plt.ylabel('Stock Price')
plt.title('Total Load Factor vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Load Factor')
plt.ylabel('Stock Price')
plt.title('Domestic Load Factor vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Load Factor')
plt.ylabel('Stock Price')
plt.title('International Load Factor vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients
total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Load Factor to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Load Factor to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Load Factor to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Load Factor to Stock Price is :-0.026784952566574656
# The correlation coefficent for Domestic Load Factor to Stock Price is :-0.037202432613272045
# The correlation coefficent for International Load Factor to Stock Price is :0.24370089291195743

# %% [markdown]
# Correlation/Plots for Net Income

# %%
# time series plots for domestic and total net income
net_income.set_index('timestamp', inplace = True)
net_income['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Net Income (Thousands)')
plt.title('Time Series of Domestic Net Income')
plt.grid(True)
plt.show()

net_income['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Net Income (Thousands)')
plt.title('Time Series of Total Net Income')
plt.grid(True)
plt.show()

# %%
# net income versus stock price plots
total = net_income['Domestic (Thousands)'].values
domestic = net_income['Total (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Net Income (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Net Income vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Net Income (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Net Income vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Net Income to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Net Income to Stock Price is :" + str(domestic_r))
# Out:
# The correlation coefficent for Total Net Income to Stock Price is :0.16529183959870433
# The correlation coefficent for Domestic Net Income to Stock Price is :0.16752120209837185

# %% [markdown]
# Correlation/Plots for Operating Revenue

# %%
# time series plots for domestic and total operating revenue
operating_revenue.set_index('timestamp', inplace = True)
operating_revenue['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Operating Revenue (Thousands)')
plt.title('Time Series of Total Operating Revenue')
plt.grid(True)
plt.show()


avail_seat_miles['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Operating Revenue (Thousands)')
plt.title('Time Series of Domestic Operating Revenue')
plt.grid(True)
plt.show()

# %%
# operating revenue versus stock price plots
total = operating_revenue['Total (Thousands)'].values
domestic = operating_revenue['Domestic (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Operating Revenue (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Operating Revenue vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Operating Revenue (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Operating Revenue vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Operating Revenue to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Operating Revenue to Stock Price is :" + str(domestic_r))
# Out:
# The correlation coefficent for Total Operating Revenue to Stock Price is :0.16087131774185687
# The correlation coefficent for Domestic Operating Revenue to Stock Price is :0.12604171480373402

# %% [markdown]
# Correlations/Plots for Passengers

# %%
# time series plots for domestic, intl, and total passengers
passengers.set_index('timestamp', inplace = True)
passengers['TOTAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.title('Time Series of Total Passengers')
plt.grid(True)
plt.show()

passengers['DOMESTIC'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.title('Time Series of Domestic Passengers')
plt.grid(True)
plt.show()

passengers['INTERNATIONAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.title('Time Series of International Passengers')
plt.grid(True)
plt.show()

# %%
# passengers versus stock price plots
total = passengers['TOTAL'].values
domestic = passengers['DOMESTIC'].values
intl = passengers['INTERNATIONAL'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Passengers')
plt.ylabel('Stock Price')
plt.title('Total Passengers vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Passengers')
plt.ylabel('Stock Price')
plt.title('Domestic Passengers vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Passengers')
plt.ylabel('Stock Price')
plt.title('International Passengers vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Passengers to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Passengers to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Passengers to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Passengers to Stock Price is :0.21166460449767366
# The correlation coefficent for Domestic Passengers to Stock Price is :0.17377952923372433
# The correlation coefficent for International Passengers to Stock Price is :0.6920544542604006

# %% [markdown]
# Correlations/Plots for Revenue Passenger-Miles

# %%
# time series plots for domestic, intl, and total rpm
revenue_passenger_miles.set_index('timestamp', inplace = True)
revenue_passenger_miles['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Revenue Passenger-Miles (Thousands)')
plt.title('Time Series of Total Revenue Passenger-Miles')
plt.grid(True)
plt.show()

revenue_passenger_miles['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Revenue Passenger-Miles (Thousands)')
plt.title('Time Series of Domestic Revenue Passenger-Miles')
plt.grid(True)
plt.show()

revenue_passenger_miles['International (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Revenue Passenger-Miles (Thousands)')
plt.title('Time Series of International Revenue Passenger-Miles')
plt.grid(True)
plt.show()

# %%
# revenue passenger miles versus stock price plots
total = revenue_passenger_miles['Total (Thousands)'].values
domestic = revenue_passenger_miles['Domestic (Thousands)'].values
intl = revenue_passenger_miles['International (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Revenue Passenger Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Revenue Passenger Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Revenue Passenger Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Revenue Passenger Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('International Revenue Passenger Miles vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients for rpm

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Revenue Passenger Miles to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Revenue Passenger Miless to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Revenue Passenger Miles to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Revenue Passenger Miles to Stock Price is :0.24499170077838153
# The correlation coefficent for Domestic Revenue Passenger Miless to Stock Price is :0.20966407859218886
# The correlation coefficent for International Revenue Passenger Miles to Stock Price is :0.5982217075376783

# %% [markdown]
# Correlations/Plots for Flights

# %%
# time series plots for domestic, intl, and total flights
flights.set_index('timestamp', inplace = True)
flights['TOTAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Flights')
plt.title('Time Series of Total Flights')
plt.grid(True)
plt.show()

flights['DOMESTIC'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Flights')
plt.title('Time Series of Domestic Flights')
plt.grid(True)
plt.show()

flights['INTERNATIONAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Flights')
plt.title('Time Series of International Flights')
plt.grid(True)
plt.show()

# %%
# flights versus stock price plots
total = flights['TOTAL'].values
domestic = flights['DOMESTIC'].values
intl = flights['INTERNATIONAL'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('# of Flights')
plt.ylabel('Stock Price')
plt.title('Total # of Flights vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('# of Flights')
plt.ylabel('Stock Price')
plt.title('Domestic # of Flights vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('# of Flights')
plt.ylabel('Stock Price')
plt.title('International # of Flights vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total # of Flights to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic # of Flights to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International # of Flights to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total # of Flights to Stock Price is :0.29230865793148675
# The correlation coefficent for Domestic # of Flights to Stock Price is :0.23964002671792084
# The correlation coefficent for International # of Flights to Stock Price is :0.7732559847576435
