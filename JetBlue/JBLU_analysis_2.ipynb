# %% [markdown]
# # JBLU Clean

# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 300)

jblu_asm_df = pd.read_csv('Available Seat-Miles - All Airports - JetBlue.csv')
jblu_flight_vol_df = pd.read_csv('Flights - All Airports - JetBlue.csv')
jblu_fuel_df = pd.read_csv('Fuel - All Service - JetBlue.csv')
jblu_load_factor_df = pd.read_csv('Load Factor - All Airports - JetBlue.csv')
jblu_income_df = pd.read_csv('Net Income - All Regions - JetBlue.csv')
jblu_operating_revenue_df = pd.read_csv('Operating Revenue - All Regions - JetBlue.csv')
jblu_passenger_vol_df = pd.read_csv('Passengers - All Airports - JetBlue.csv')
jblu_rpm_df = pd.read_csv('Revenue Passager-Miles - All Airports - JetBlue.csv')
jblu_stock_df = pd.read_csv('JBLU_stock_data.csv')
jblu_baggage_df = pd.read_csv('Baggage Fees - All Airports - JetBlue.csv')

display(jblu_asm_df.head())
display(jblu_flight_vol_df.head())
display(jblu_fuel_df.head())
display(jblu_load_factor_df.head())
display(jblu_income_df.head())
display(jblu_operating_revenue_df.head())
display(jblu_passenger_vol_df.head())
display(jblu_rpm_df.head())
display(jblu_stock_df.tail())
# Out:
#    Year  Month Domestic (Thousands) International (Thousands)  \
# 0  2002     10              780,200                       NaN
# 1  2002     11              788,014                       NaN
# 2  2002     12              889,420                       NaN
# 3  2002  TOTAL            8,227,463                         0
# 4  2003      1              939,498                       NaN
#
#   Total (Thousands)
# 0           780,200
# 1           788,014
# 2           889,420
# 3         8,227,463
# 4           939,498
#    Year  Month DOMESTIC INTERNATIONAL   TOTAL
# 0  2002     10    4,276           NaN   4,276
# 1  2002     11    4,287           NaN   4,287
# 2  2002     12    4,776           NaN   4,776
# 3  2002  TOTAL   44,113             0  44,113
# 4  2003      1    5,006           NaN   5,006
#    Year     Month Domestic Consumption\n(thousand gallons)  \
# 0  2012   January                                   36,836
# 1  2012  February                                   35,634
# 2  2012     March                                   40,446
# 3  2012     April                                   39,417
# 4  2012       May                                   39,012
#
#   Domestic Cost (thousand dollars) Domestic Cost per Gallon (Dollars)  \
# 0                          116,032                               3.15
# 1                          115,529                               3.24
# 2                          134,985                               3.34
# 3                          133,018                               3.37
# 4                          127,770                               3.28
#
#   International Consumption\n(thousand gallons)  \
# 0                                         6,660
# 1                                         6,387
# 2                                         7,398
# 3                                         7,319
# 4                                         6,516
#
#   International Cost (thousand dollars)  \
# 0                                20,977
# 1                                20,707
# 2                                24,691
# 3                                24,700
# 4                                21,340
#
#   International Cost per Gallon (Dollars)  \
# 0                                       3
# 1                                       3
# 2                                       3
# 3                                       3
# 4                                       3
#
#   Total Consumption\n(thousand gallons) Total Cost (thousand dollars)  \
# 0                                43,496                       137,009
# 1                                42,021                       136,236
# 2                                47,844                       159,676
# 3                                46,736                       157,718
# 4                                45,528                       149,110
#
#   Total Cost per Gallon (Dollars)
# 0                            3.15
# 1                            3.24
# 2                            3.34
# 3                            3.37
# 4                            3.28
#    Year  Month  DOMESTIC  INTERNATIONAL  TOTAL
# 0  2002     10     80.97            NaN  80.97
# 1  2002     11     79.20            NaN  79.20
# 2  2002     12     84.38            NaN  84.38
# 3  2002  TOTAL     82.89            NaN  82.89
# 4  2003      1     82.16            NaN  82.16
#    Year Quarter Domestic (Thousands) Latin America (Thousands)  \
# 0  2000       1               -7,690                       NaN
# 1  2000       2               -6,155                       NaN
# 2  2000       3               -2,029                       NaN
# 3  2000       4                   37                       NaN
# 4  2000   TOTAL              -15,837                         0
#
#   Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 0                  NaN                  NaN                        NaN
# 1                  NaN                  NaN                        NaN
# 2                  NaN                  NaN                        NaN
# 3                  NaN                  NaN                        NaN
# 4                    0                  0.0                        0.0
#
#   Total (Thousands)
# 0            -7,690
# 1            -6,155
# 2            -2,029
# 3                37
# 4           -15,837
#    Year Quarter Domestic (Thousands) Latin America (Thousands)  \
# 0  2000       1                6,469                       NaN
# 1  2000       2               16,192                       NaN
# 2  2000       3               33,434                       NaN
# 3  2000       4               49,153                       NaN
# 4  2000   TOTAL              105,248                         0
#
#   Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 0                  NaN                  NaN                        NaN
# 1                  NaN                  NaN                        NaN
# 2                  NaN                  NaN                        NaN
# 3                  NaN                  NaN                        NaN
# 4                    0                  0.0                        0.0
#
#   Total (Thousands)
# 0             6,469
# 1            16,192
# 2            33,434
# 3            49,153
# 4           105,248
#    Year  Month   DOMESTIC INTERNATIONAL      TOTAL
# 0  2002     10    546,693           NaN    546,693
# 1  2002     11    542,247           NaN    542,247
# 2  2002     12    637,705           NaN    637,705
# 3  2002  TOTAL  5,672,028             0  5,672,028
# 4  2003      1    644,223           NaN    644,223
#    Year  Month Domestic (Thousands) International (Thousands)  \
# 0  2002     10              631,742                       NaN
# 1  2002     11              624,101                       NaN
# 2  2002     12              750,453                       NaN
# 3  2002  TOTAL            6,819,927                         0
# 4  2003      1              771,921                       NaN
#
#   Total (Thousands)
# 0           631,742
# 1           624,101
# 2           750,453
# 3         6,819,927
# 4           771,921
#       timestamp   JBLU  JBLU_rolling_7_day_avg  JBLU_rolling_14_day_avg  \
# 375  2018-04-02  19.73               20.394286                21.325000
# 376  2018-04-03  20.15               20.234286                21.167857
# 377  2018-04-04  20.48               20.182857                21.035000
# 378  2018-04-05  20.64               20.205714                20.919286
# 379  2018-04-06  20.12               20.230000                20.742857
#
#      JBLU_rolling_30_day_avg  JBLU_rolling_90_day_avg  JBLU_7_days_ago  \
# 375                21.274667                21.298167            20.48
# 376                21.269667                21.302278            19.95
# 377                21.285000                21.307833            20.17
# 378                21.281667                21.316056            20.32
# 379                21.257333                21.319167              NaN
#
#      JBLU_14_days_ago  JBLU_30_days_ago  JBLU_90_days_ago  JBLU_log_price  \
# 375             22.17               NaN             22.38        2.982140
# 376             22.30               NaN             21.59        3.003204
# 377             21.78             21.27             21.69        3.019449
# 378             21.27             21.44             21.38        3.027231
# 379             20.84             21.50               NaN        3.001714
#
#      JBLU_pct_change_7_days  JBLU_pct_change_14_days  JBLU_pct_change_30_days  \
# 375               -0.036621                -0.110059                      NaN
# 376                0.010025                -0.096413                      NaN
# 377                0.015369                -0.059688                -0.037142
# 378                0.015748                -0.029619                -0.037313
# 379                     NaN                -0.034549                -0.064186
#
#      JBLU_pct_change_90_days
# 375                -0.118409
# 376                -0.066698
# 377                -0.055786
# 378                -0.034612
# 379                      NaN

# %%
# clean baggage

# dictionary to map quarters to their corresponding month and day
quarter_end_dates = {
    1: '03-31',
    2: '06-30',
    3: '09-30',
    4: '12-31'
}

# drop the total columns in order to convert to datetime. aggregation can easily replace total
jblu_baggage_df = jblu_baggage_df.loc[jblu_baggage_df['Quarter'] != "TOTAL"].copy()

# convert quarter to numeric in order to use mapping 
jblu_baggage_df['Quarter'] = pd.to_numeric(jblu_baggage_df['Quarter'])

# convert to quarters, then resample to months
jblu_baggage_df['date_str'] = jblu_baggage_df['Year'].astype(str) + '-' + jblu_baggage_df['Quarter'].map(quarter_end_dates)
jblu_baggage_df['timestamp'] = pd.PeriodIndex(jblu_baggage_df['date_str'], freq='Q')
jblu_baggage_df.set_index('timestamp', inplace=True)
jblu_baggage_df = jblu_baggage_df.resample('M').ffill()


#drop placeholder date_str
jblu_baggage_df.drop(columns=['date_str'], inplace=True)

# select the rows with dates corresponding to other data (October 2016-April 2018)
jblu_baggage_df = jblu_baggage_df.reset_index()
start_date = pd.Period('2016-10-01', freq = 'M')
end_date = pd.Period('2018-05-01', freq='M')
jblu_baggage_df = jblu_baggage_df.loc[(jblu_baggage_df['timestamp'] >= start_date) & (jblu_baggage_df['timestamp'] < end_date)]


# clean dtypes
jblu_baggage_df['Total (Thousands)'] = jblu_baggage_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# clean asm

# drop the total columns in order to convert to datetime. aggregation can easily replace total
jblu_asm_df = jblu_asm_df.loc[jblu_asm_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
jblu_asm_df['date_str'] = jblu_asm_df['Year'].astype(str) + '-' + jblu_asm_df['Month'].astype(str) + '-01'
jblu_asm_df['timestamp'] = pd.to_datetime(jblu_asm_df['date_str'])

# put time stamp as first column for clarity
jblu_asm_df = jblu_asm_df[['timestamp'] + [col for col in jblu_asm_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
jblu_asm_df['timestamp'] = jblu_asm_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
jblu_asm_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
jblu_asm_df = jblu_asm_df.loc[(jblu_asm_df['timestamp'] >= start_date) & (jblu_asm_df['timestamp'] < end_date)]

# convert dtypes
jblu_asm_df['Domestic (Thousands)'] = jblu_asm_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
jblu_asm_df['International (Thousands)'] = jblu_asm_df['International (Thousands)'].str.replace(",", "").astype(float)
jblu_asm_df['Total (Thousands)'] = jblu_asm_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# clean flight vol

# drop the total columns in order to convert to datetime. aggregation can easily replace total
jblu_flight_vol_df = jblu_flight_vol_df.loc[jblu_flight_vol_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
jblu_flight_vol_df['date_str'] = jblu_flight_vol_df['Year'].astype(str) + '-' + jblu_flight_vol_df['Month'].astype(str) + '-01'
jblu_flight_vol_df['timestamp'] = pd.to_datetime(jblu_flight_vol_df['date_str'])

# put time stamp as first column for clarity
jblu_flight_vol_df = jblu_flight_vol_df[['timestamp'] + [col for col in jblu_flight_vol_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
jblu_flight_vol_df['timestamp'] = jblu_flight_vol_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
jblu_flight_vol_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
jblu_flight_vol_df = jblu_flight_vol_df.loc[(jblu_flight_vol_df['timestamp'] >= start_date) & (jblu_flight_vol_df['timestamp'] < end_date)]

# clean dtypes
jblu_flight_vol_df['DOMESTIC'] = jblu_flight_vol_df['DOMESTIC'].str.replace(",", "").astype(float)
jblu_flight_vol_df['INTERNATIONAL'] = jblu_flight_vol_df['INTERNATIONAL'].str.replace(",", "").astype(float)
jblu_flight_vol_df['TOTAL'] = jblu_flight_vol_df['TOTAL'].str.replace(",", "").astype(float)

# %%
# clean fuel df 

jblu_fuel_df.dtypes

month_name_to_number = {
    'January': 1,
    'February': 2,
    'March': 3,
    'April': 4,
    'May': 5,
    'June': 6,
    'July': 7,
    'August': 8,
    'September': 9,
    'October': 10,
    'November': 11,
    'December': 12
}

jblu_fuel_df['Month'] = jblu_fuel_df['Month'].astype(str)
jblu_fuel_df = jblu_fuel_df.loc[jblu_fuel_df['Month'] != "nan"].copy()
jblu_fuel_df['Month'] = jblu_fuel_df['Month'].map(month_name_to_number)

# create datetime column to index compare to stock. 
jblu_fuel_df['date_str'] = jblu_fuel_df['Year'].astype(str) + '-' + jblu_fuel_df['Month'].astype(str) + '-01'
jblu_fuel_df['timestamp'] = pd.to_datetime(jblu_fuel_df['date_str'])

# put time stamp as first column for clarity
jblu_fuel_df = jblu_fuel_df[['timestamp'] + [col for col in jblu_fuel_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
jblu_fuel_df['timestamp'] = jblu_fuel_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
jblu_fuel_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
jblu_fuel_df = jblu_fuel_df.loc[(jblu_fuel_df['timestamp'] >= start_date) & (jblu_fuel_df['timestamp'] < end_date)]

# clean dtypes
jblu_fuel_df['Domestic Consumption\n(thousand gallons)'] = jblu_fuel_df['Domestic Consumption\n(thousand gallons)'].str.replace(",", "").astype(float)
jblu_fuel_df['Domestic Cost (thousand dollars)'] = jblu_fuel_df['Domestic Cost (thousand dollars)'].str.replace(",", "").astype(float)
jblu_fuel_df['Domestic Cost per Gallon (Dollars)'] = jblu_fuel_df['Domestic Cost per Gallon (Dollars)'].str.replace(",", "").astype(float)
jblu_fuel_df['International Consumption\n(thousand gallons)'] = jblu_fuel_df['International Consumption\n(thousand gallons)'].str.replace(",", "").astype(float)
jblu_fuel_df['International Cost (thousand dollars)'] = jblu_fuel_df['International Cost (thousand dollars)'].str.replace(",", "").astype(float)
jblu_fuel_df['International Cost per Gallon (Dollars)'] = jblu_fuel_df['International Cost per Gallon (Dollars)'].str.replace(",", "").astype(float)
jblu_fuel_df['Total Consumption\n(thousand gallons)'] = jblu_fuel_df['Total Consumption\n(thousand gallons)'].str.replace(",", "").astype(float)
jblu_fuel_df['Total Cost (thousand dollars)'] = jblu_fuel_df['Total Cost (thousand dollars)'].str.replace(",", "").astype(float)
jblu_fuel_df['Total Cost per Gallon (Dollars)'] = jblu_fuel_df['Total Cost per Gallon (Dollars)'].str.replace(",", "").astype(float)

#rename certain columns
jblu_fuel_df.rename(columns={'Domestic Consumption\n(thousand gallons)': 'Domestic Consumption (thousand gallons)'}, inplace=True)
jblu_fuel_df.rename(columns={'International Consumption\n(thousand gallons)': 'International Consumption (thousand gallons)'}, inplace=True)
jblu_fuel_df.rename(columns={'Total Consumption\n(thousand gallons)': 'Total Consumption (thousand gallons)'}, inplace=True)

# %%
# clean load factor 

# drop the total columns in order to convert to datetime. aggregation can easily replace total
jblu_load_factor_df = jblu_load_factor_df.loc[jblu_load_factor_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
jblu_load_factor_df['date_str'] = jblu_load_factor_df['Year'].astype(str) + '-' + jblu_load_factor_df['Month'].astype(str) + '-01'
jblu_load_factor_df['timestamp'] = pd.to_datetime(jblu_load_factor_df['date_str'])

# put time stamp as first column for clarity
jblu_load_factor_df = jblu_load_factor_df[['timestamp'] + [col for col in jblu_load_factor_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
jblu_load_factor_df['timestamp'] = jblu_load_factor_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
jblu_load_factor_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
jblu_load_factor_df = jblu_load_factor_df.loc[(jblu_load_factor_df['timestamp'] >= start_date) & (jblu_load_factor_df['timestamp'] < end_date)]

# dtypes came clean

# %%
# clean net income 

# dictionary to map quarters to their corresponding month and day
quarter_end_dates = {
    1: '03-31',
    2: '06-30',
    3: '09-30',
    4: '12-31'
}

# drop the total columns in order to convert to datetime. aggregation can easily replace total
jblu_income_df = jblu_income_df.loc[jblu_income_df['Quarter'] != "TOTAL"].copy()

# convert quarter to numeric in order to use mapping 
jblu_income_df['Quarter'] = pd.to_numeric(jblu_income_df['Quarter'])

# convert to quarters, then resample to months
jblu_income_df['date_str'] = jblu_income_df['Year'].astype(str) + '-' + jblu_income_df['Quarter'].map(quarter_end_dates)
jblu_income_df['timestamp'] = pd.PeriodIndex(jblu_income_df['date_str'], freq='Q')
jblu_income_df.set_index('timestamp', inplace=True)
jblu_income_df = jblu_income_df.resample('M').ffill()

#drop placeholder date_str
jblu_income_df.drop(columns=['date_str'], inplace=True)

# select the rows with dates corresponding to other data (October 2016-April 2018)
jblu_income_df = jblu_income_df.reset_index()
start_date = pd.Period('2016-10-01', freq = 'M')
end_date = pd.Period('2018-05-01', freq='M')
jblu_income_df = jblu_income_df.loc[(jblu_income_df['timestamp'] >= start_date) & (jblu_income_df['timestamp'] < end_date)]

# clean dtypes
jblu_income_df['Domestic (Thousands)'] = jblu_income_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
jblu_income_df['Latin America (Thousands)'] = jblu_income_df['Latin America (Thousands)'].str.replace(",", "").astype(float)
jblu_income_df['Total (Thousands)'] = jblu_income_df['Total (Thousands)'].str.replace(",", "").astype(float)

# dtypes came clean
display(jblu_income_df)
# Out:
#     timestamp  Year  Quarter  Domestic (Thousands)  Latin America (Thousands)  \
# 201   2016-10  2016        4              133305.0                    46714.0
# 202   2016-11  2016        4              133305.0                    46714.0
# 203   2016-12  2016        4              133305.0                    46714.0
# 204   2017-01  2017        1               46500.0                    38776.0
# 205   2017-02  2017        1               46500.0                    38776.0
# 206   2017-03  2017        1               46500.0                    38776.0
# 207   2017-04  2017        2              148373.0                    62432.0
# 208   2017-05  2017        2              148373.0                    62432.0
# 209   2017-06  2017        2              148373.0                    62432.0
# 210   2017-07  2017        3               87649.0                    91136.0
# 211   2017-08  2017        3               87649.0                    91136.0
# 212   2017-09  2017        3               87649.0                    91136.0
# 213   2017-10  2017        4              639702.0                    32707.0
# 214   2017-11  2017        4              639702.0                    32707.0
# 215   2017-12  2017        4              639702.0                    32707.0
# 216   2018-01  2018        1               32262.0                    56060.0
# 217   2018-02  2018        1               32262.0                    56060.0
# 218   2018-03  2018        1               32262.0                    56060.0
# 219   2018-04  2018        2             -114836.0                    -5056.0
#
#     Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 201                  NaN                  NaN                        NaN
# 202                  NaN                  NaN                        NaN
# 203                  NaN                  NaN                        NaN
# 204                  NaN                  NaN                        NaN
# 205                  NaN                  NaN                        NaN
# 206                  NaN                  NaN                        NaN
# 207                  NaN                  NaN                        NaN
# 208                  NaN                  NaN                        NaN
# 209                  NaN                  NaN                        NaN
# 210                  NaN                  NaN                        NaN
# 211                  NaN                  NaN                        NaN
# 212                  NaN                  NaN                        NaN
# 213                  NaN                  NaN                        NaN
# 214                  NaN                  NaN                        NaN
# 215                  NaN                  NaN                        NaN
# 216                  NaN                  NaN                        NaN
# 217                  NaN                  NaN                        NaN
# 218                  NaN                  NaN                        NaN
# 219                  NaN                  NaN                        NaN
#
#      Total (Thousands)
# 201           180020.0
# 202           180020.0
# 203           180020.0
# 204            85276.0
# 205            85276.0
# 206            85276.0
# 207           210805.0
# 208           210805.0
# 209           210805.0
# 210           178785.0
# 211           178785.0
# 212           178785.0
# 213           672409.0
# 214           672409.0
# 215           672409.0
# 216            88322.0
# 217            88322.0
# 218            88322.0
# 219          -119892.0

# %%
# clean operating revenue

# drop the total columns in order to convert to datetime. aggregation can easily replace total
jblu_operating_revenue_df = jblu_operating_revenue_df.loc[jblu_operating_revenue_df['Quarter'] != "TOTAL"].copy()

# convert quarter to numeric in order to use mapping 
jblu_operating_revenue_df['Quarter'] = pd.to_numeric(jblu_operating_revenue_df['Quarter'])

# convert to quarters, then resample to months
jblu_operating_revenue_df['date_str'] = jblu_operating_revenue_df['Year'].astype(str) + '-' + jblu_operating_revenue_df['Quarter'].map(quarter_end_dates)
jblu_operating_revenue_df['timestamp'] = pd.PeriodIndex(jblu_operating_revenue_df['date_str'], freq='Q')
jblu_operating_revenue_df.set_index('timestamp', inplace=True)
jblu_operating_revenue_df = jblu_operating_revenue_df.resample('M').ffill()

#drop placeholder date_str
jblu_operating_revenue_df.drop(columns=['date_str'], inplace=True)

# select the rows with dates corresponding to other data (October 2016-April 2018)
jblu_operating_revenue_df = jblu_operating_revenue_df.reset_index()
start_date = pd.Period('2016-10-01', freq = 'M')
end_date = pd.Period('2018-05-01', freq='M')
jblu_operating_revenue_df = jblu_operating_revenue_df.loc[(jblu_operating_revenue_df['timestamp'] >= start_date) & (jblu_operating_revenue_df['timestamp'] < end_date)]

jblu_operating_revenue_df['Domestic (Thousands)'] = jblu_operating_revenue_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
jblu_operating_revenue_df['Total (Thousands)'] = jblu_operating_revenue_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# clean passenger volume df

# drop the total columns in order to convert to datetime. aggregation can easily replace total
jblu_passenger_vol_df = jblu_passenger_vol_df.loc[jblu_passenger_vol_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
jblu_passenger_vol_df['date_str'] = jblu_passenger_vol_df['Year'].astype(str) + '-' + jblu_passenger_vol_df['Month'].astype(str) + '-01'
jblu_passenger_vol_df['timestamp'] = pd.to_datetime(jblu_passenger_vol_df['date_str'])

# put time stamp as first column for clarity
jblu_passenger_vol_df = jblu_passenger_vol_df[['timestamp'] + [col for col in jblu_passenger_vol_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
jblu_passenger_vol_df['timestamp'] = jblu_passenger_vol_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
jblu_passenger_vol_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
jblu_passenger_vol_df = jblu_passenger_vol_df.loc[(jblu_passenger_vol_df['timestamp'] >= start_date) & (jblu_passenger_vol_df['timestamp'] < end_date)]

# clean dtypes
jblu_passenger_vol_df['DOMESTIC'] = jblu_passenger_vol_df['DOMESTIC'].str.replace(",", "").astype(float)
jblu_passenger_vol_df['INTERNATIONAL'] = jblu_passenger_vol_df['INTERNATIONAL'].str.replace(",", "").astype(float)
jblu_passenger_vol_df['TOTAL'] = jblu_passenger_vol_df['TOTAL'].str.replace(",", "").astype(float)

# %%
# clean rpm df 

# drop the total columns in order to convert to datetime. aggregation can easily replace total
jblu_rpm_df = jblu_rpm_df.loc[jblu_rpm_df['Month'] != "TOTAL"].copy()

# create datetime column to index compare to stock. 
jblu_rpm_df['date_str'] = jblu_rpm_df['Year'].astype(str) + '-' + jblu_rpm_df['Month'].astype(str) + '-01'
jblu_rpm_df['timestamp'] = pd.to_datetime(jblu_rpm_df['date_str'])

# put time stamp as first column for clarity
jblu_rpm_df = jblu_rpm_df[['timestamp'] + [col for col in jblu_rpm_df.columns if col != 'timestamp']]

# since these are monthly aggregates, set date to end of month
jblu_rpm_df['timestamp'] = jblu_rpm_df['timestamp'] + pd.offsets.MonthEnd(0)

#drop placeholder date_str
jblu_rpm_df.drop(columns=['date_str'], inplace=True)

# filter df for dates that align with stock data
start_date = pd.to_datetime('2016-10-01')
end_date = pd.to_datetime('2018-05-01')
jblu_rpm_df = jblu_rpm_df.loc[(jblu_rpm_df['timestamp'] >= start_date) & (jblu_rpm_df['timestamp'] < end_date)]

# clean dtypes
jblu_rpm_df['Domestic (Thousands)'] = jblu_rpm_df['Domestic (Thousands)'].str.replace(",", "").astype(float)
jblu_rpm_df['International (Thousands)'] = jblu_rpm_df['International (Thousands)'].str.replace(",", "").astype(float)
jblu_rpm_df['Total (Thousands)'] = jblu_rpm_df['Total (Thousands)'].str.replace(",", "").astype(float)

# %%
# jblu stock dtype clean
jblu_stock_df['timestamp'] = pd.to_datetime(jblu_stock_df['timestamp'])

# %%
display(jblu_asm_df.head())
display(jblu_flight_vol_df.head())
display(jblu_fuel_df.head())
display(jblu_load_factor_df.head())
display(jblu_income_df.head())
display(jblu_operating_revenue_df.head())
display(jblu_passenger_vol_df.head())
display(jblu_rpm_df.head())
display(jblu_baggage_df.head())
display(jblu_stock_df.tail())
# Out:
#      timestamp  Year Month  Domestic (Thousands)  International (Thousands)  \
# 182 2016-10-31  2016    10             3419889.0                   797225.0
# 183 2016-11-30  2016    11             3451239.0                   810270.0
# 184 2016-12-31  2016    12             3671912.0                  1057628.0
# 186 2017-01-31  2017     1             3638354.0                   996623.0
# 187 2017-02-28  2017     2             3287787.0                   894149.0
#
#      Total (Thousands)
# 182          4217115.0
# 183          4261509.0
# 184          4729539.0
# 186          4634978.0
# 187          4181937.0
#      timestamp  Year Month  DOMESTIC  INTERNATIONAL    TOTAL
# 182 2016-10-31  2016    10   22753.0         4242.0  26995.0
# 183 2016-11-30  2016    11   22967.0         4419.0  27386.0
# 184 2016-12-31  2016    12   24181.0         5588.0  29769.0
# 186 2017-01-31  2017     1   24189.0         5239.0  29428.0
# 187 2017-02-28  2017     2   21632.0         4631.0  26263.0
#     timestamp  Year  Month  Domestic Consumption (thousand gallons)  \
# 65 2016-10-31  2016     10                                  49796.0
# 66 2016-11-30  2016     11                                  49643.0
# 67 2016-12-31  2016     12                                  53163.0
# 70 2017-01-31  2017      1                                  52620.0
# 71 2017-02-28  2017      2                                  47247.0
#
#     Domestic Cost (thousand dollars)  Domestic Cost per Gallon (Dollars)  \
# 65                           76518.0                                1.54
# 66                           76488.0                                1.54
# 67                           84586.0                                1.59
# 70                           88828.0                                1.69
# 71                           80631.0                                1.71
#
#     International Consumption (thousand gallons)  \
# 65                                       10360.0
# 66                                       10577.0
# 67                                       13512.0
# 70                                       12623.0
# 71                                       11090.0
#
#     International Cost (thousand dollars)  \
# 65                                15943.0
# 66                                16309.0
# 67                                21498.0
# 70                                21309.0
# 71                                18925.0
#
#     International Cost per Gallon (Dollars)  \
# 65                                      2.0
# 66                                      2.0
# 67                                      2.0
# 70                                      2.0
# 71                                      2.0
#
#     Total Consumption (thousand gallons)  Total Cost (thousand dollars)  \
# 65                               60157.0                        92461.0
# 66                               60220.0                        92797.0
# 67                               66675.0                       106084.0
# 70                               65244.0                       110137.0
# 71                               58336.0                        99556.0
#
#     Total Cost per Gallon (Dollars)
# 65                             1.54
# 66                             1.54
# 67                             1.59
# 70                             1.69
# 71                             1.71
#      timestamp  Year Month  DOMESTIC  INTERNATIONAL  TOTAL
# 182 2016-10-31  2016    10     85.15          82.87  84.71
# 183 2016-11-30  2016    11     85.93          83.39  85.45
# 184 2016-12-31  2016    12     84.90          80.84  83.99
# 186 2017-01-31  2017     1     83.52          82.72  83.35
# 187 2017-02-28  2017     2     83.35          80.16  82.67
#     timestamp  Year  Quarter  Domestic (Thousands)  Latin America (Thousands)  \
# 201   2016-10  2016        4              133305.0                    46714.0
# 202   2016-11  2016        4              133305.0                    46714.0
# 203   2016-12  2016        4              133305.0                    46714.0
# 204   2017-01  2017        1               46500.0                    38776.0
# 205   2017-02  2017        1               46500.0                    38776.0
#
#     Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 201                  NaN                  NaN                        NaN
# 202                  NaN                  NaN                        NaN
# 203                  NaN                  NaN                        NaN
# 204                  NaN                  NaN                        NaN
# 205                  NaN                  NaN                        NaN
#
#      Total (Thousands)
# 201           180020.0
# 202           180020.0
# 203           180020.0
# 204            85276.0
# 205            85276.0
#     timestamp  Year  Quarter  Domestic (Thousands) Latin America (Thousands)  \
# 201   2016-10  2016        4             1333830.0                   307,120
# 202   2016-11  2016        4             1333830.0                   307,120
# 203   2016-12  2016        4             1333830.0                   307,120
# 204   2017-01  2017        1             1292562.0                   311,296
# 205   2017-02  2017        1             1292562.0                   311,296
#
#     Atlantic (Thousands)  Pacific (Thousands)  International (Thousands)  \
# 201                  NaN                  NaN                        NaN
# 202                  NaN                  NaN                        NaN
# 203                  NaN                  NaN                        NaN
# 204                  NaN                  NaN                        NaN
# 205                  NaN                  NaN                        NaN
#
#      Total (Thousands)
# 201          1640949.0
# 202          1640949.0
# 203          1640949.0
# 204          1603858.0
# 205          1603858.0
#      timestamp  Year Month   DOMESTIC  INTERNATIONAL      TOTAL
# 182 2016-10-31  2016    10  2532802.0       501919.0  3034721.0
# 183 2016-11-30  2016    11  2597905.0       521952.0  3119857.0
# 184 2016-12-31  2016    12  2714148.0       661789.0  3375937.0
# 186 2017-01-31  2017     1  2648950.0       637665.0  3286615.0
# 187 2017-02-28  2017     2  2383341.0       547698.0  2931039.0
#      timestamp  Year Month  Domestic (Thousands)  International (Thousands)  \
# 182 2016-10-31  2016    10             2911905.0                   660623.0
# 183 2016-11-30  2016    11             2965686.0                   675702.0
# 184 2016-12-31  2016    12             3117300.0                   854937.0
# 186 2017-01-31  2017     1             3038917.0                   824371.0
# 187 2017-02-28  2017     2             2740393.0                   716728.0
#
#      Total (Thousands)
# 182          3572528.0
# 183          3641388.0
# 184          3972236.0
# 186          3863288.0
# 187          3457121.0
#    timestamp  Year  Quarter  Total (Thousands)
# 9    2016-10  2016        4            56578.0
# 10   2016-11  2016        4            56578.0
# 11   2016-12  2016        4            56578.0
# 12   2017-01  2017        1            61994.0
# 13   2017-02  2017        1            61994.0
#      timestamp   JBLU  JBLU_rolling_7_day_avg  JBLU_rolling_14_day_avg  \
# 375 2018-04-02  19.73               20.394286                21.325000
# 376 2018-04-03  20.15               20.234286                21.167857
# 377 2018-04-04  20.48               20.182857                21.035000
# 378 2018-04-05  20.64               20.205714                20.919286
# 379 2018-04-06  20.12               20.230000                20.742857
#
#      JBLU_rolling_30_day_avg  JBLU_rolling_90_day_avg  JBLU_7_days_ago  \
# 375                21.274667                21.298167            20.48
# 376                21.269667                21.302278            19.95
# 377                21.285000                21.307833            20.17
# 378                21.281667                21.316056            20.32
# 379                21.257333                21.319167              NaN
#
#      JBLU_14_days_ago  JBLU_30_days_ago  JBLU_90_days_ago  JBLU_log_price  \
# 375             22.17               NaN             22.38        2.982140
# 376             22.30               NaN             21.59        3.003204
# 377             21.78             21.27             21.69        3.019449
# 378             21.27             21.44             21.38        3.027231
# 379             20.84             21.50               NaN        3.001714
#
#      JBLU_pct_change_7_days  JBLU_pct_change_14_days  JBLU_pct_change_30_days  \
# 375               -0.036621                -0.110059                      NaN
# 376                0.010025                -0.096413                      NaN
# 377                0.015369                -0.059688                -0.037142
# 378                0.015748                -0.029619                -0.037313
# 379                     NaN                -0.034549                -0.064186
#
#      JBLU_pct_change_90_days
# 375                -0.118409
# 376                -0.066698
# 377                -0.055786
# 378                -0.034612
# 379                      NaN

# %%
jblu_asm_df.dtypes
# Out:
# timestamp                    datetime64[ns]
# Year                                  int64
# Month                                object
# Domestic (Thousands)                float64
# International (Thousands)           float64
# Total (Thousands)                   float64
# dtype: object

# %%
jblu_flight_vol_df.dtypes
# Out:
# timestamp        datetime64[ns]
# Year                      int64
# Month                    object
# DOMESTIC                float64
# INTERNATIONAL           float64
# TOTAL                   float64
# dtype: object

# %%
jblu_fuel_df.dtypes
# Out:
# timestamp                                       datetime64[ns]
# Year                                                    object
# Month                                                    int64
# Domestic Consumption (thousand gallons)                float64
# Domestic Cost (thousand dollars)                       float64
# Domestic Cost per Gallon (Dollars)                     float64
# International Consumption (thousand gallons)           float64
# International Cost (thousand dollars)                  float64
# International Cost per Gallon (Dollars)                float64
# Total Consumption (thousand gallons)                   float64
# Total Cost (thousand dollars)                          float64
# Total Cost per Gallon (Dollars)                        float64
# dtype: object

# %%
jblu_load_factor_df.dtypes
# Out:
# timestamp        datetime64[ns]
# Year                      int64
# Month                    object
# DOMESTIC                float64
# INTERNATIONAL           float64
# TOTAL                   float64
# dtype: object

# %%
jblu_income_df.dtypes
# Out:
# timestamp                    period[M]
# Year                             int64
# Quarter                          int64
# Domestic (Thousands)           float64
# Latin America (Thousands)      float64
# Atlantic (Thousands)            object
# Pacific (Thousands)            float64
# International (Thousands)      float64
# Total (Thousands)              float64
# dtype: object

# %%
jblu_operating_revenue_df.dtypes
# Out:
# timestamp                    period[M]
# Year                             int64
# Quarter                          int64
# Domestic (Thousands)           float64
# Latin America (Thousands)       object
# Atlantic (Thousands)            object
# Pacific (Thousands)            float64
# International (Thousands)      float64
# Total (Thousands)              float64
# dtype: object

# %%
jblu_passenger_vol_df.dtypes
# Out:
# timestamp        datetime64[ns]
# Year                      int64
# Month                    object
# DOMESTIC                float64
# INTERNATIONAL           float64
# TOTAL                   float64
# dtype: object

# %%
jblu_rpm_df.dtypes
# Out:
# timestamp                    datetime64[ns]
# Year                                  int64
# Month                                object
# Domestic (Thousands)                float64
# International (Thousands)           float64
# Total (Thousands)                   float64
# dtype: object

# %%
jblu_baggage_df.dtypes
# Out:
# timestamp            period[M]
# Year                     int64
# Quarter                  int64
# Total (Thousands)      float64
# dtype: object

# %%
jblu_stock_df.dtypes
# Out:
# timestamp                  datetime64[ns]
# JBLU                              float64
# JBLU_rolling_7_day_avg            float64
# JBLU_rolling_14_day_avg           float64
# JBLU_rolling_30_day_avg           float64
# JBLU_rolling_90_day_avg           float64
# JBLU_7_days_ago                   float64
# JBLU_14_days_ago                  float64
# JBLU_30_days_ago                  float64
# JBLU_90_days_ago                  float64
# JBLU_log_price                    float64
# JBLU_pct_change_7_days            float64
# JBLU_pct_change_14_days           float64
# JBLU_pct_change_30_days           float64
# JBLU_pct_change_90_days           float64
# dtype: object

# %% [markdown]
# # Analysis

# %%
avail_seat_miles = jblu_asm_df
baggage_fees = jblu_baggage_df
fuel = jblu_fuel_df
load_factor = jblu_load_factor_df
net_income = jblu_income_df
operating_revenue = jblu_operating_revenue_df
passengers = jblu_passenger_vol_df
revenue_passenger_miles = jblu_rpm_df
flights = jblu_flight_vol_df




prices = jblu_stock_df[jblu_stock_df['timestamp'].dt.day < 4]
prices = prices[['timestamp','JBLU']]
prices.set_index('timestamp',inplace = True)
price = prices.resample('M').mean()
price = price.values
p = []
for i in range(len(price)):
    p.append(price[i][0])
price = numpy.array(p)

# %% [markdown]
# Correlation/Plots for Available Seat Miles

# %%
# time series plots for domestic, intl, and total asm
avail_seat_miles.set_index('timestamp', inplace = True)
avail_seat_miles['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Available Seat Miles (Thousands)')
plt.title('Time Series of Total Available Seat Miles')
plt.grid(True)
plt.show()

avail_seat_miles['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Available Seat Miles (Thousands)')
plt.title('Time Series of Domestic Available Seat Miles')
plt.grid(True)
plt.show()

avail_seat_miles['International (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Available Seat Miles (Thousands)')
plt.title('Time Series of International Available Seat Miles')
plt.grid(True)
plt.show()

# %%
# available seat miles versus stock price plots
total = avail_seat_miles['Total (Thousands)'].values
domestic = avail_seat_miles['Domestic (Thousands)'].values
intl = avail_seat_miles['International (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Available Seat Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Available Seat Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('International Available Seat Miles vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients for asm

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Available Seat Miles to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Available Seat Miles to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Available Seat Miles to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Available Seat Miles to Stock Price is :0.6805161086898671
# The correlation coefficent for Domestic Available Seat Miles to Stock Price is :0.5965983110616757
# The correlation coefficent for International Available Seat Miles to Stock Price is :0.75653246760071

# %% [markdown]
# Correlation/Plots for Baggage Fees

# %%
# time series plot of baggage fees
baggage_fees.set_index('timestamp', inplace = True)
baggage_fees['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Total Fees ($Thousands)')
plt.title('Time Series of Total Baggage Fees')
plt.grid(True)
plt.show()

# %%
# available seat miles versus stock price plots
fees = baggage_fees['Total (Thousands)'].values


plt.scatter(fees, price)
plt.xlabel('Baggage Fees ($Thousands)')
plt.ylabel('Stock Price')
plt.title('Baggage Fees vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficient for baggage fees

fee_r = numpy.corrcoef(fees,price)[0,1]
print("The correlation coefficent for Baggage Fees to Stock Price is :" + str(total_r))
# Out:
# The correlation coefficent for Baggage Fees to Stock Price is :0.6805161086898671

# %% [markdown]
# Correlation/Plots for Fuel

# %%
# time series plots for domestic, intl, and total fuel
fuel.set_index('timestamp', inplace = True)
fuel['Domestic Consumption (thousand gallons)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Consumption (thousand gallons)')
plt.title('Time Series of Domestic Fuel Consumption')
plt.grid(True)
plt.show()

fuel['International Consumption (thousand gallons)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Consumption (thousand gallons)')
plt.title('Time Series of International Fuel Consumption')
plt.grid(True)
plt.show()

fuel['Total Consumption (thousand gallons)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Consumption (thousand gallons)')
plt.title('Time Series of Total Consumption')
plt.grid(True)
plt.show()

fuel['Domestic Cost (thousand dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Cost (thousand dollars)')
plt.title('Time Series of Domestic Fuel Cost')
plt.grid(True)
plt.show()

fuel['International Cost (thousand dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Cost (thousand dollars)')
plt.title('Time Series of International Fuel Cost')
plt.grid(True)
plt.show()

fuel['Total Cost (thousand dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Fuel Cost (thousand dollars)')
plt.title('Time Series of Total Fuel Cost')
plt.grid(True)
plt.show()

fuel['Domestic Cost per Gallon (Dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Cost per Gallon (Dollars)')
plt.title('Time Series of Domestic Cost per Gallon')
plt.grid(True)
plt.show()

fuel['International Cost per Gallon (Dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Cost per Gallon (Dollars)')
plt.title('Time Series of International Cost per Gallon')
plt.grid(True)
plt.show()

fuel['Total Cost per Gallon (Dollars)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Cost per Gallon (Dollars)')
plt.title('Time Series of Cost per Gallon')
plt.grid(True)
plt.show()

# %%
# fuel versus stock price plots
total_consumption = fuel['Total Consumption (thousand gallons)'].values
domestic_consumption = fuel['Domestic Consumption (thousand gallons)'].values
intl_consumption = fuel['International Consumption (thousand gallons)'].values
total_cost =fuel['Total Cost (thousand dollars)'].values
domestic_cost = fuel['Domestic Cost (thousand dollars)'].values
intl_cost =fuel['International Cost (thousand dollars)'].values
total_cpg = fuel['Total Cost per Gallon (Dollars)'].values
domestic_cpg =fuel['Domestic Cost per Gallon (Dollars)'].values
intl_cpg =fuel['International Cost per Gallon (Dollars)'].values


plt.figure()
plt.scatter(total_consumption, price)
plt.xlabel('Consumption (thousand gallons)')
plt.ylabel('Stock Price')
plt.title('Total Fuel Consumption (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic_consumption, price)
plt.xlabel('Consumption (thousand gallons)')
plt.ylabel('Stock Price')
plt.title('Domestic Fuel Consumption (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl_consumption, price)
plt.xlabel('Consumption (thousand gallons)')
plt.ylabel('Stock Price')
plt.title('International Fuel Consumption (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(total_cost, price)
plt.xlabel('Cost (thousand dollars)')
plt.ylabel('Stock Price')
plt.title('Total Fuel Cost (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic_cost, price)
plt.xlabel('Cost (thousand dollars)')
plt.ylabel('Stock Price')
plt.title('Domestic Fuel Cost (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl_cost, price)
plt.xlabel('Cost (thousand dollars)')
plt.ylabel('Stock Price')
plt.title('International Fuel Cost (thousand gallons) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(total_cpg, price)
plt.xlabel('Cost per Gallon (Dollars)')
plt.ylabel('Stock Price')
plt.title('Total Fuel Cost per Gallon (Dollars) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic_cpg, price)
plt.xlabel('Cost per Gallon (Dollars)')
plt.ylabel('Stock Price')
plt.title('Domestic Fuel Cost per Gallon (Dollars) vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl_cpg, price)
plt.xlabel('Cost per Gallon (Dollars)')
plt.ylabel('Stock Price')
plt.title('International Fuel Cost per Gallon (Dollars) vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients for fuel

r1 = numpy.corrcoef(total_consumption, price)[0,1]
print("The correlation coefficent for Total Fuel Consumption (thousand gallons) vs Stock Price is :" + str(r1))
r2 = numpy.corrcoef(domestic_consumption ,price)[0,1]
print("The correlation coefficent for Domestic Fuel Consumption (thousand gallons) vs Stock Price is :" + str(r2))
r3 = numpy.corrcoef(intl_consumption,price)[0,1]
print("The correlation coefficent for International Fuel Consumption (thousand gallons) vs Stock Price is:" + str(r3))

r4 = numpy.corrcoef(total_cost, price)[0,1]
print("The correlation coefficent for Total Fuel Cost (thousand gallons) vs Stock Price is:" + str(r4))
r5 = numpy.corrcoef(domestic_cost ,price)[0,1]
print("The correlation coefficent for Domestic Fuel Cost (thousand gallons) vs Stock Price :" + str(r5))
r6 = numpy.corrcoef(intl_cost,price)[0,1]
print("The correlation coefficent for International Fuel Cost (thousand gallons) vs Stock Price:" + str(r6))

r7 = numpy.corrcoef(total_cpg, price)[0,1]
print("The correlation coefficent for Total Fuel Cost per Gallon (Dollars) vs Stock Price :" + str(r7))
r8 = numpy.corrcoef(domestic_cpg ,price)[0,1]
print("The correlation coefficent for Domestic Fuel Cost per Gallon (Dollars) vs Stock Price :" + str(r8))
r9 = numpy.corrcoef(intl_cpg,price)[0,1]
print("The correlation coefficent for International Fuel Cost per Gallon (Dollars) vs Stock Price :" + str(r9))
# Out:
# The correlation coefficent for Total Fuel Consumption (thousand gallons) vs Stock Price is :0.7167450777365741
# The correlation coefficent for Domestic Fuel Consumption (thousand gallons) vs Stock Price is :0.6601955469687074
# The correlation coefficent for International Fuel Consumption (thousand gallons) vs Stock Price is:0.7665523446690655
# The correlation coefficent for Total Fuel Cost (thousand gallons) vs Stock Price is:0.36019422138921964
# The correlation coefficent for Domestic Fuel Cost (thousand gallons) vs Stock Price :0.30628553160778277
# The correlation coefficent for International Fuel Cost (thousand gallons) vs Stock Price:0.527750572513478
# The correlation coefficent for Total Fuel Cost per Gallon (Dollars) vs Stock Price :0.057544180490084904
# The correlation coefficent for Domestic Fuel Cost per Gallon (Dollars) vs Stock Price :0.057544180490084904
# The correlation coefficent for International Fuel Cost per Gallon (Dollars) vs Stock Price :nan
# /Users/liamoshaughnessy/anaconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /Users/liamoshaughnessy/anaconda3/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %% [markdown]
# Correlation/Plots for Load Factor

# %%
# time series plots for domestic, intl, and total load factor
load_factor.set_index('timestamp', inplace = True)
load_factor['DOMESTIC'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Load Factor')
plt.title('Time Series of Domestic Load Factor')
plt.grid(True)
plt.show()

load_factor['INTERNATIONAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Load Factor')
plt.title('Time Series of International Load Factor')
plt.grid(True)
plt.show()

load_factor['TOTAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Load Factor')
plt.title('Time Series of Total Load Factor')
plt.grid(True)
plt.show()

# %%
# load factor versus stock price plots
total = load_factor['TOTAL'].values
domestic = load_factor['DOMESTIC'].values
intl = load_factor['INTERNATIONAL'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Load Factor')
plt.ylabel('Stock Price')
plt.title('Total Load Factor vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Load Factor')
plt.ylabel('Stock Price')
plt.title('Domestic Load Factor vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Load Factor')
plt.ylabel('Stock Price')
plt.title('International Load Factor vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients
total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Load Factor to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Load Factor to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Load Factor to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Load Factor to Stock Price is :0.16635880205584927
# The correlation coefficent for Domestic Load Factor to Stock Price is :0.06087428799179844
# The correlation coefficent for International Load Factor to Stock Price is :0.40627328760958487

# %% [markdown]
# Correlation/Plots for Net Income

# %%
# time series plots for domestic and total net income
net_income.set_index('timestamp', inplace = True)
net_income['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Net Income (Thousands)')
plt.title('Time Series of Domestic Net Income')
plt.grid(True)
plt.show()

net_income['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Net Income (Thousands)')
plt.title('Time Series of Total Net Income')
plt.grid(True)
plt.show()

# %%
# net income versus stock price plots
total = net_income['Domestic (Thousands)'].values
domestic = net_income['Total (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Net Income (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Net Income vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Net Income (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Net Income vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Net Income to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Net Income to Stock Price is :" + str(domestic_r))
# Out:
# The correlation coefficent for Total Net Income to Stock Price is :-0.19901489104171277
# The correlation coefficent for Domestic Net Income to Stock Price is :-0.1583768795067639

# %% [markdown]
# Correlation/Plots for Operating Revenue

# %%
# time series plots for domestic and total operating revenue
operating_revenue.set_index('timestamp', inplace = True)
operating_revenue['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Operating Revenue (Thousands)')
plt.title('Time Series of Total Operating Revenue')
plt.grid(True)
plt.show()


avail_seat_miles['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Operating Revenue (Thousands)')
plt.title('Time Series of Domestic Operating Revenue')
plt.grid(True)
plt.show()

# %%
# operating revenue versus stock price plots
total = operating_revenue['Total (Thousands)'].values
domestic = operating_revenue['Domestic (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Operating Revenue (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Operating Revenue vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Operating Revenue (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Operating Revenue vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Operating Revenue to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Operating Revenue to Stock Price is :" + str(domestic_r))
# Out:
# The correlation coefficent for Total Operating Revenue to Stock Price is :0.36959405914133175
# The correlation coefficent for Domestic Operating Revenue to Stock Price is :0.20305304926023146

# %% [markdown]
# Correlations/Plots for Passengers

# %%
# time series plots for domestic, intl, and total passengers
passengers.set_index('timestamp', inplace = True)
passengers['TOTAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.title('Time Series of Total Passengers')
plt.grid(True)
plt.show()

passengers['DOMESTIC'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.title('Time Series of Domestic Passengers')
plt.grid(True)
plt.show()

passengers['INTERNATIONAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.title('Time Series of International Passengers')
plt.grid(True)
plt.show()

# %%
# passengers versus stock price plots
total = passengers['TOTAL'].values
domestic = passengers['DOMESTIC'].values
intl = passengers['INTERNATIONAL'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Passengers')
plt.ylabel('Stock Price')
plt.title('Total Passengers vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Passengers')
plt.ylabel('Stock Price')
plt.title('Domestic Passengers vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Passengers')
plt.ylabel('Stock Price')
plt.title('International Passengers vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Passengers to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Passengers to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Passengers to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Passengers to Stock Price is :0.5730516316444937
# The correlation coefficent for Domestic Passengers to Stock Price is :0.4423946759161258
# The correlation coefficent for International Passengers to Stock Price is :0.7455429520823563

# %% [markdown]
# Correlations/Plots for Revenue Passenger-Miles

# %%
# time series plots for domestic, intl, and total rpm
revenue_passenger_miles.set_index('timestamp', inplace = True)
revenue_passenger_miles['Total (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Revenue Passenger-Miles (Thousands)')
plt.title('Time Series of Total Revenue Passenger-Miles')
plt.grid(True)
plt.show()

revenue_passenger_miles['Domestic (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Revenue Passenger-Miles (Thousands)')
plt.title('Time Series of Domestic Revenue Passenger-Miles')
plt.grid(True)
plt.show()

revenue_passenger_miles['International (Thousands)'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Revenue Passenger-Miles (Thousands)')
plt.title('Time Series of International Revenue Passenger-Miles')
plt.grid(True)
plt.show()

# %%
# revenue passenger miles versus stock price plots
total = revenue_passenger_miles['Total (Thousands)'].values
domestic = revenue_passenger_miles['Domestic (Thousands)'].values
intl = revenue_passenger_miles['International (Thousands)'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('Revenue Passenger Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Total Revenue Passenger Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('Revenue Passenger Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('Domestic Revenue Passenger Miles vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('Available Seat Miles (Thousands)')
plt.ylabel('Stock Price')
plt.title('International Revenue Passenger Miles vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients for rpm

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total Revenue Passenger Miles to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic Revenue Passenger Miless to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International Revenue Passenger Miles to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total Revenue Passenger Miles to Stock Price is :0.6053574906541123
# The correlation coefficent for Domestic Revenue Passenger Miless to Stock Price is :0.5047180159147716
# The correlation coefficent for International Revenue Passenger Miles to Stock Price is :0.7282837757150964

# %% [markdown]
# Correlations/Plots for Flights

# %%
# time series plots for domestic, intl, and total flights
flights.set_index('timestamp', inplace = True)
flights['TOTAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Flights')
plt.title('Time Series of Total Flights')
plt.grid(True)
plt.show()

flights['DOMESTIC'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Flights')
plt.title('Time Series of Domestic Flights')
plt.grid(True)
plt.show()

flights['INTERNATIONAL'].plot(kind='line', marker='o')
plt.xlabel('Date')
plt.ylabel('Flights')
plt.title('Time Series of International Flights')
plt.grid(True)
plt.show()

# %%
# flights versus stock price plots
total = flights['TOTAL'].values
domestic = flights['DOMESTIC'].values
intl = flights['INTERNATIONAL'].values

plt.figure()
plt.scatter(total, price)
plt.xlabel('# of Flights')
plt.ylabel('Stock Price')
plt.title('Total # of Flights vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(domestic, price)
plt.xlabel('# of Flights')
plt.ylabel('Stock Price')
plt.title('Domestic # of Flights vs Stock Price')
plt.grid(True)
plt.show

plt.figure()
plt.scatter(intl, price)
plt.xlabel('# of Flights')
plt.ylabel('Stock Price')
plt.title('International # of Flights vs Stock Price')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# correlation coefficients

total_r = numpy.corrcoef(total,price)[0,1]
print("The correlation coefficent for Total # of Flights to Stock Price is :" + str(total_r))
domestic_r = numpy.corrcoef(domestic,price)[0,1]
print("The correlation coefficent for Domestic # of Flights to Stock Price is :" + str(domestic_r))
intl_r = numpy.corrcoef(intl,price)[0,1]
print("The correlation coefficent for International # of Flights to Stock Price is :" + str(intl_r))
# Out:
# The correlation coefficent for Total # of Flights to Stock Price is :0.6647651389664314
# The correlation coefficent for Domestic # of Flights to Stock Price is :0.5765672278954816
# The correlation coefficent for International # of Flights to Stock Price is :0.7775993667664789
